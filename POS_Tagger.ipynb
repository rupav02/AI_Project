# %% [markdown]
# <a href="https://colab.research.google.com/github/rupav02/AI_Project/blob/main/POS_Tagger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```Notes on Data:```
# - Format is "word/TAG"
# - Single newline indicates new Sentence
# - Double newline indicates new Paragraph
#
# ```Notes on Model:```
# - Must extend or truncate sentences to be of the same size.
# - Special [CLS] token used at start of all sentences for classification.
# - Special [SEP] token added to end of all sentences.
# - Special [PAD] token used to pad sentences.
# - Must use model's own Tokenizer

# %%
import os
from tqdm import tqdm
import numpy as np
import torch
import torch.nn as nn
from torch.utils import data
import torch.optim as optim
from transformers import BertModel, BertConfig, BertForTokenClassification
from torch.utils.data import DataLoader, Dataset
import ssl
import nltk
from nltk.tree import Tree
from nltk.corpus import treebank
import urllib.request
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# #### DO NOT REDISTRIBUTE THE WSJ DATA.
# It is licensed by the Linguistic Data Consortium (LDC) and is not free to distribute.

# %%
# !unzip wsj.zip
# Out:
# Archive:  wsj.zip
#    creating: wsj/
#    creating: wsj/11/
#   inflating: wsj/11/wsj_1138.mrg
#   inflating: wsj/11/wsj_1130.mrg
#   inflating: wsj/11/wsj_1197.mrg
#   inflating: wsj/11/wsj_1178.mrg
#   inflating: wsj/11/wsj_1161.mrg
#   inflating: wsj/11/wsj_1167.mrg
#   inflating: wsj/11/wsj_1175.mrg
#   inflating: wsj/11/wsj_1101.mrg
#   inflating: wsj/11/wsj_1110.mrg
#   inflating: wsj/11/wsj_1119.mrg
#   inflating: wsj/11/wsj_1176.mrg
#   inflating: wsj/11/wsj_1168.mrg
#   inflating: wsj/11/wsj_1174.mrg
#   inflating: wsj/11/wsj_1142.mrg
#   inflating: wsj/11/wsj_1190.mrg
#   inflating: wsj/11/wsj_1170.mrg
#   inflating: wsj/11/wsj_1124.mrg
#   inflating: wsj/11/wsj_1129.mrg
#   inflating: wsj/11/wsj_1154.mrg
#   inflating: wsj/11/wsj_1173.mrg
#   inflating: wsj/11/wsj_1148.mrg
#   inflating: wsj/11/wsj_1135.mrg
#   inflating: wsj/11/wsj_1162.mrg
#   inflating: wsj/11/wsj_1132.mrg
#   inflating: wsj/11/wsj_1181.mrg
#   inflating: wsj/11/wsj_1152.mrg
#   inflating: wsj/11/wsj_1106.mrg
#   inflating: wsj/11/wsj_1194.mrg
#   inflating: wsj/11/wsj_1192.mrg
#   inflating: wsj/11/wsj_1198.mrg
#   inflating: wsj/11/wsj_1107.mrg
#   inflating: wsj/11/wsj_1186.mrg
#   inflating: wsj/11/wsj_1182.mrg
#   inflating: wsj/11/wsj_1105.mrg
#   inflating: wsj/11/wsj_1180.mrg
#   inflating: wsj/11/wsj_1159.mrg
#   inflating: wsj/11/wsj_1191.mrg
#   inflating: wsj/11/wsj_1100.mrg
#   inflating: wsj/11/wsj_1177.mrg
#   inflating: wsj/11/wsj_1183.mrg
#   inflating: wsj/11/wsj_1131.mrg
#   inflating: wsj/11/wsj_1126.mrg
#   inflating: wsj/11/wsj_1185.mrg
#   inflating: wsj/11/wsj_1137.mrg
#   inflating: wsj/11/wsj_1133.mrg
#   inflating: wsj/11/wsj_1165.mrg
#   inflating: wsj/11/wsj_1151.mrg
#   inflating: wsj/11/wsj_1171.mrg
#   inflating: wsj/11/wsj_1116.mrg
#   inflating: wsj/11/wsj_1141.mrg
#   inflating: wsj/11/wsj_1184.mrg
#   inflating: wsj/11/wsj_1112.mrg
#   inflating: wsj/11/wsj_1146.mrg
#   inflating: wsj/11/wsj_1125.mrg
#   inflating: wsj/11/wsj_1172.mrg
#   inflating: wsj/11/wsj_1145.mrg
#   inflating: wsj/11/wsj_1102.mrg
#   inflating: wsj/11/wsj_1179.mrg
#   inflating: wsj/11/wsj_1120.mrg
#   inflating: wsj/11/wsj_1156.mrg
#   inflating: wsj/11/wsj_1128.mrg
#   inflating: wsj/11/wsj_1157.mrg
#   inflating: wsj/11/wsj_1150.mrg
#   inflating: wsj/11/wsj_1158.mrg
#   inflating: wsj/11/wsj_1114.mrg
#   inflating: wsj/11/wsj_1169.mrg
#   inflating: wsj/11/wsj_1164.mrg
#   inflating: wsj/11/wsj_1140.mrg
#   inflating: wsj/11/wsj_1193.mrg
#   inflating: wsj/11/wsj_1189.mrg
#   inflating: wsj/11/wsj_1122.mrg
#   inflating: wsj/11/wsj_1113.mrg
#   inflating: wsj/11/wsj_1139.mrg
#   inflating: wsj/11/wsj_1104.mrg
#   inflating: wsj/11/wsj_1118.mrg
#   inflating: wsj/11/wsj_1160.mrg
#   inflating: wsj/11/wsj_1115.mrg
#   inflating: wsj/11/wsj_1199.mrg
#   inflating: wsj/11/wsj_1123.mrg
#   inflating: wsj/11/wsj_1166.mrg
#   inflating: wsj/11/wsj_1127.mrg
#   inflating: wsj/11/wsj_1103.mrg
#   inflating: wsj/11/wsj_1155.mrg
#   inflating: wsj/11/wsj_1117.mrg
#   inflating: wsj/11/wsj_1109.mrg
#   inflating: wsj/11/wsj_1136.mrg
#   inflating: wsj/11/wsj_1144.mrg
#   inflating: wsj/11/wsj_1153.mrg
#   inflating: wsj/11/wsj_1143.mrg
#   inflating: wsj/11/wsj_1149.mrg
#   inflating: wsj/11/wsj_1195.mrg
#   inflating: wsj/11/wsj_1196.mrg
#   inflating: wsj/11/wsj_1163.mrg
#   inflating: wsj/11/wsj_1108.mrg
#   inflating: wsj/11/wsj_1121.mrg
#   inflating: wsj/11/wsj_1111.mrg
#   inflating: wsj/11/wsj_1147.mrg
#   inflating: wsj/11/wsj_1188.mrg
#   inflating: wsj/11/wsj_1187.mrg
#   inflating: wsj/11/wsj_1134.mrg
#    creating: wsj/07/
#   inflating: wsj/07/wsj_0729.mrg
#   inflating: wsj/07/wsj_0751.mrg
#   inflating: wsj/07/wsj_0749.mrg
#   inflating: wsj/07/wsj_0788.mrg
#   inflating: wsj/07/wsj_0766.mrg
#   inflating: wsj/07/wsj_0746.mrg
#   inflating: wsj/07/wsj_0736.mrg
#   inflating: wsj/07/wsj_0790.mrg
#   inflating: wsj/07/wsj_0739.mrg
#   inflating: wsj/07/wsj_0713.mrg
#   inflating: wsj/07/wsj_0714.mrg
#   inflating: wsj/07/wsj_0789.mrg
#   inflating: wsj/07/wsj_0762.mrg
#   inflating: wsj/07/wsj_0786.mrg
#   inflating: wsj/07/wsj_0708.mrg
#   inflating: wsj/07/wsj_0785.mrg
#   inflating: wsj/07/wsj_0741.mrg
#   inflating: wsj/07/wsj_0765.mrg
#   inflating: wsj/07/wsj_0725.mrg
#   inflating: wsj/07/wsj_0778.mrg
#   inflating: wsj/07/wsj_0721.mrg
#   inflating: wsj/07/wsj_0724.mrg
#   inflating: wsj/07/wsj_0720.mrg
#   inflating: wsj/07/wsj_0792.mrg
#   inflating: wsj/07/wsj_0744.mrg
#   inflating: wsj/07/wsj_0728.mrg
#   inflating: wsj/07/wsj_0753.mrg
#   inflating: wsj/07/wsj_0798.mrg
#   inflating: wsj/07/wsj_0712.mrg
#   inflating: wsj/07/wsj_0759.mrg
#   inflating: wsj/07/wsj_0710.mrg
#   inflating: wsj/07/wsj_0795.mrg
#   inflating: wsj/07/wsj_0752.mrg
#   inflating: wsj/07/wsj_0775.mrg
#   inflating: wsj/07/wsj_0770.mrg
#   inflating: wsj/07/wsj_0771.mrg
#   inflating: wsj/07/wsj_0704.mrg
#   inflating: wsj/07/wsj_0756.mrg
#   inflating: wsj/07/wsj_0715.mrg
#   inflating: wsj/07/wsj_0760.mrg
#   inflating: wsj/07/wsj_0763.mrg
#   inflating: wsj/07/wsj_0707.mrg
#   inflating: wsj/07/wsj_0755.mrg
#   inflating: wsj/07/wsj_0716.mrg
#   inflating: wsj/07/wsj_0754.mrg
#   inflating: wsj/07/wsj_0796.mrg
#   inflating: wsj/07/wsj_0738.mrg
#   inflating: wsj/07/wsj_0747.mrg
#   inflating: wsj/07/wsj_0777.mrg
#   inflating: wsj/07/wsj_0745.mrg
#   inflating: wsj/07/wsj_0705.mrg
#   inflating: wsj/07/wsj_0780.mrg
#   inflating: wsj/07/wsj_0774.mrg
#   inflating: wsj/07/wsj_0711.mrg
#   inflating: wsj/07/wsj_0737.mrg
#   inflating: wsj/07/wsj_0750.mrg
#   inflating: wsj/07/wsj_0700.mrg
#   inflating: wsj/07/wsj_0734.mrg
#   inflating: wsj/07/wsj_0773.mrg
#   inflating: wsj/07/wsj_0703.mrg
#   inflating: wsj/07/wsj_0772.mrg
#   inflating: wsj/07/wsj_0794.mrg
#   inflating: wsj/07/wsj_0791.mrg
#   inflating: wsj/07/wsj_0702.mrg
#   inflating: wsj/07/wsj_0768.mrg
#   inflating: wsj/07/wsj_0781.mrg
#   inflating: wsj/07/wsj_0779.mrg
#   inflating: wsj/07/wsj_0761.mrg
#   inflating: wsj/07/wsj_0730.mrg
#   inflating: wsj/07/wsj_0748.mrg
#   inflating: wsj/07/wsj_0733.mrg
#   inflating: wsj/07/wsj_0727.mrg
#   inflating: wsj/07/wsj_0767.mrg
#   inflating: wsj/07/wsj_0731.mrg
#   inflating: wsj/07/wsj_0719.mrg
#   inflating: wsj/07/wsj_0769.mrg
#   inflating: wsj/07/wsj_0740.mrg
#   inflating: wsj/07/wsj_0722.mrg
#   inflating: wsj/07/wsj_0797.mrg
#   inflating: wsj/07/wsj_0726.mrg
#   inflating: wsj/07/wsj_0764.mrg
#   inflating: wsj/07/wsj_0735.mrg
#   inflating: wsj/07/wsj_0776.mrg
#   inflating: wsj/07/wsj_0758.mrg
#   inflating: wsj/07/wsj_0784.mrg
#   inflating: wsj/07/wsj_0742.mrg
#   inflating: wsj/07/wsj_0757.mrg
#   inflating: wsj/07/wsj_0709.mrg
#   inflating: wsj/07/wsj_0799.mrg
#   inflating: wsj/07/wsj_0718.mrg
#   inflating: wsj/07/wsj_0782.mrg
#   inflating: wsj/07/wsj_0701.mrg
#   inflating: wsj/07/wsj_0723.mrg
#   inflating: wsj/07/wsj_0787.mrg
#   inflating: wsj/07/wsj_0706.mrg
#   inflating: wsj/07/wsj_0793.mrg
#   inflating: wsj/07/wsj_0743.mrg
#   inflating: wsj/07/wsj_0783.mrg
#   inflating: wsj/07/wsj_0717.mrg
#   inflating: wsj/07/wsj_0732.mrg
#    creating: wsj/00/
#   inflating: wsj/00/wsj_0088.mrg
#   inflating: wsj/00/wsj_0047.mrg
#   inflating: wsj/00/wsj_0031.mrg
#   inflating: wsj/00/wsj_0084.mrg
#   inflating: wsj/00/wsj_0028.mrg
#   inflating: wsj/00/wsj_0081.mrg
#   inflating: wsj/00/wsj_0029.mrg
#   inflating: wsj/00/wsj_0069.mrg
#   inflating: wsj/00/wsj_0002.mrg
#   inflating: wsj/00/wsj_0085.mrg
#   inflating: wsj/00/wsj_0006.mrg
#   inflating: wsj/00/wsj_0003.mrg
#   inflating: wsj/00/wsj_0008.mrg
#   inflating: wsj/00/wsj_0059.mrg
#   inflating: wsj/00/wsj_0045.mrg
#   inflating: wsj/00/wsj_0039.mrg
#   inflating: wsj/00/wsj_0078.mrg
#   inflating: wsj/00/wsj_0061.mrg
#   inflating: wsj/00/wsj_0099.mrg
#   inflating: wsj/00/wsj_0080.mrg
#   inflating: wsj/00/wsj_0022.mrg
#   inflating: wsj/00/wsj_0057.mrg
#   inflating: wsj/00/wsj_0071.mrg
#   inflating: wsj/00/wsj_0033.mrg
#   inflating: wsj/00/wsj_0024.mrg
#   inflating: wsj/00/wsj_0014.mrg
#   inflating: wsj/00/wsj_0036.mrg
#   inflating: wsj/00/wsj_0020.mrg
#   inflating: wsj/00/wsj_0089.mrg
#   inflating: wsj/00/wsj_0038.mrg
#   inflating: wsj/00/wsj_0063.mrg
#   inflating: wsj/00/wsj_0013.mrg
#   inflating: wsj/00/wsj_0064.mrg
#   inflating: wsj/00/wsj_0004.mrg
#   inflating: wsj/00/wsj_0035.mrg
#   inflating: wsj/00/wsj_0023.mrg
#   inflating: wsj/00/wsj_0054.mrg
#   inflating: wsj/00/wsj_0067.mrg
#   inflating: wsj/00/wsj_0050.mrg
#   inflating: wsj/00/wsj_0021.mrg
#   inflating: wsj/00/wsj_0026.mrg
#   inflating: wsj/00/wsj_0079.mrg
#   inflating: wsj/00/wsj_0074.mrg
#   inflating: wsj/00/wsj_0072.mrg
#   inflating: wsj/00/wsj_0068.mrg
#   inflating: wsj/00/wsj_0032.mrg
#   inflating: wsj/00/wsj_0046.mrg
#   inflating: wsj/00/wsj_0087.mrg
#   inflating: wsj/00/wsj_0066.mrg
#   inflating: wsj/00/wsj_0017.mrg
#   inflating: wsj/00/wsj_0062.mrg
#   inflating: wsj/00/wsj_0048.mrg
#   inflating: wsj/00/wsj_0043.mrg
#   inflating: wsj/00/wsj_0055.mrg
#   inflating: wsj/00/wsj_0007.mrg
#   inflating: wsj/00/wsj_0096.mrg
#   inflating: wsj/00/wsj_0044.mrg
#   inflating: wsj/00/wsj_0091.mrg
#   inflating: wsj/00/wsj_0009.mrg
#   inflating: wsj/00/wsj_0094.mrg
#   inflating: wsj/00/wsj_0019.mrg
#   inflating: wsj/00/wsj_0041.mrg
#   inflating: wsj/00/wsj_0037.mrg
#   inflating: wsj/00/wsj_0093.mrg
#   inflating: wsj/00/wsj_0095.mrg
#   inflating: wsj/00/wsj_0073.mrg
#   inflating: wsj/00/wsj_0051.mrg
#   inflating: wsj/00/wsj_0065.mrg
#   inflating: wsj/00/wsj_0005.mrg
#   inflating: wsj/00/wsj_0018.mrg
#   inflating: wsj/00/wsj_0075.mrg
#   inflating: wsj/00/wsj_0056.mrg
#   inflating: wsj/00/wsj_0049.mrg
#   inflating: wsj/00/wsj_0097.mrg
#   inflating: wsj/00/wsj_0092.mrg
#   inflating: wsj/00/wsj_0098.mrg
#   inflating: wsj/00/wsj_0052.mrg
#   inflating: wsj/00/wsj_0001.mrg
#   inflating: wsj/00/wsj_0070.mrg
#   inflating: wsj/00/wsj_0082.mrg
#   inflating: wsj/00/wsj_0053.mrg
#   inflating: wsj/00/wsj_0011.mrg
#   inflating: wsj/00/wsj_0010.mrg
#   inflating: wsj/00/wsj_0060.mrg
#   inflating: wsj/00/wsj_0042.mrg
#   inflating: wsj/00/wsj_0027.mrg
#   inflating: wsj/00/wsj_0086.mrg
#   inflating: wsj/00/wsj_0025.mrg
#   inflating: wsj/00/wsj_0030.mrg
#   inflating: wsj/00/wsj_0012.mrg
#   inflating: wsj/00/wsj_0016.mrg
#   inflating: wsj/00/wsj_0083.mrg
#   inflating: wsj/00/wsj_0015.mrg
#   inflating: wsj/00/wsj_0076.mrg
#   inflating: wsj/00/wsj_0058.mrg
#   inflating: wsj/00/wsj_0090.mrg
#   inflating: wsj/00/wsj_0034.mrg
#   inflating: wsj/00/wsj_0040.mrg
#   inflating: wsj/00/wsj_0077.mrg
#    creating: wsj/10/
#   inflating: wsj/10/wsj_1089.mrg
#   inflating: wsj/10/wsj_1046.mrg
#   inflating: wsj/10/wsj_1060.mrg
#   inflating: wsj/10/wsj_1056.mrg
#   inflating: wsj/10/wsj_1004.mrg
#   inflating: wsj/10/wsj_1058.mrg
#   inflating: wsj/10/wsj_1048.mrg
#   inflating: wsj/10/wsj_1095.mrg
#   inflating: wsj/10/wsj_1097.mrg
#   inflating: wsj/10/wsj_1059.mrg
#   inflating: wsj/10/wsj_1065.mrg
#   inflating: wsj/10/wsj_1023.mrg
#   inflating: wsj/10/wsj_1055.mrg
#   inflating: wsj/10/wsj_1042.mrg
#   inflating: wsj/10/wsj_1038.mrg
#   inflating: wsj/10/wsj_1003.mrg
#   inflating: wsj/10/wsj_1002.mrg
#   inflating: wsj/10/wsj_1014.mrg
#   inflating: wsj/10/wsj_1018.mrg
#   inflating: wsj/10/wsj_1036.mrg
#   inflating: wsj/10/wsj_1041.mrg
#   inflating: wsj/10/wsj_1085.mrg
#   inflating: wsj/10/wsj_1032.mrg
#   inflating: wsj/10/wsj_1070.mrg
#   inflating: wsj/10/wsj_1062.mrg
#   inflating: wsj/10/wsj_1076.mrg
#   inflating: wsj/10/wsj_1064.mrg
#   inflating: wsj/10/wsj_1051.mrg
#   inflating: wsj/10/wsj_1017.mrg
#   inflating: wsj/10/wsj_1037.mrg
#   inflating: wsj/10/wsj_1019.mrg
#   inflating: wsj/10/wsj_1044.mrg
#   inflating: wsj/10/wsj_1057.mrg
#   inflating: wsj/10/wsj_1043.mrg
#   inflating: wsj/10/wsj_1096.mrg
#   inflating: wsj/10/wsj_1035.mrg
#   inflating: wsj/10/wsj_1080.mrg
#   inflating: wsj/10/wsj_1092.mrg
#   inflating: wsj/10/wsj_1049.mrg
#   inflating: wsj/10/wsj_1000.mrg
#   inflating: wsj/10/wsj_1013.mrg
#   inflating: wsj/10/wsj_1026.mrg
#   inflating: wsj/10/wsj_1079.mrg
#   inflating: wsj/10/wsj_1083.mrg
#   inflating: wsj/10/wsj_1061.mrg
#   inflating: wsj/10/wsj_1015.mrg
#   inflating: wsj/10/wsj_1021.mrg
#   inflating: wsj/10/wsj_1011.mrg
#   inflating: wsj/10/wsj_1020.mrg
#   inflating: wsj/10/wsj_1053.mrg
#   inflating: wsj/10/wsj_1067.mrg
#   inflating: wsj/10/wsj_1066.mrg
#   inflating: wsj/10/wsj_1030.mrg
#   inflating: wsj/10/wsj_1009.mrg
#   inflating: wsj/10/wsj_1078.mrg
#   inflating: wsj/10/wsj_1077.mrg
#   inflating: wsj/10/wsj_1071.mrg
#   inflating: wsj/10/wsj_1006.mrg
#   inflating: wsj/10/wsj_1045.mrg
#   inflating: wsj/10/wsj_1031.mrg
#   inflating: wsj/10/wsj_1007.mrg
#   inflating: wsj/10/wsj_1090.mrg
#   inflating: wsj/10/wsj_1098.mrg
#   inflating: wsj/10/wsj_1005.mrg
#   inflating: wsj/10/wsj_1075.mrg
#   inflating: wsj/10/wsj_1050.mrg
#   inflating: wsj/10/wsj_1072.mrg
#   inflating: wsj/10/wsj_1029.mrg
#   inflating: wsj/10/wsj_1091.mrg
#   inflating: wsj/10/wsj_1010.mrg
#   inflating: wsj/10/wsj_1001.mrg
#   inflating: wsj/10/wsj_1054.mrg
#   inflating: wsj/10/wsj_1088.mrg
#   inflating: wsj/10/wsj_1069.mrg
#   inflating: wsj/10/wsj_1068.mrg
#   inflating: wsj/10/wsj_1034.mrg
#   inflating: wsj/10/wsj_1081.mrg
#   inflating: wsj/10/wsj_1039.mrg
#   inflating: wsj/10/wsj_1063.mrg
#   inflating: wsj/10/wsj_1084.mrg
#   inflating: wsj/10/wsj_1052.mrg
#   inflating: wsj/10/wsj_1040.mrg
#   inflating: wsj/10/wsj_1016.mrg
#   inflating: wsj/10/wsj_1082.mrg
#   inflating: wsj/10/wsj_1028.mrg
#   inflating: wsj/10/wsj_1094.mrg
#   inflating: wsj/10/wsj_1033.mrg
#   inflating: wsj/10/wsj_1012.mrg
#   inflating: wsj/10/wsj_1024.mrg
#   inflating: wsj/10/wsj_1087.mrg
#   inflating: wsj/10/wsj_1047.mrg
#   inflating: wsj/10/wsj_1022.mrg
#   inflating: wsj/10/wsj_1008.mrg
#   inflating: wsj/10/wsj_1025.mrg
#   inflating: wsj/10/wsj_1027.mrg
#   inflating: wsj/10/wsj_1086.mrg
#   inflating: wsj/10/wsj_1093.mrg
#   inflating: wsj/10/wsj_1073.mrg
#   inflating: wsj/10/wsj_1099.mrg
#   inflating: wsj/10/wsj_1074.mrg
#    creating: wsj/24/
#   inflating: wsj/24/wsj_2417.mrg
#   inflating: wsj/24/wsj_2434.mrg
#   inflating: wsj/24/wsj_2444.mrg
#   inflating: wsj/24/wsj_2402.mrg
#   inflating: wsj/24/wsj_2419.mrg
#   inflating: wsj/24/wsj_2416.mrg
#   inflating: wsj/24/wsj_2400.mrg
#   inflating: wsj/24/wsj_2408.mrg
#   inflating: wsj/24/wsj_2445.mrg
#   inflating: wsj/24/wsj_2414.mrg
#   inflating: wsj/24/wsj_2406.mrg
#   inflating: wsj/24/wsj_2441.mrg
#   inflating: wsj/24/wsj_2418.mrg
#   inflating: wsj/24/wsj_2446.mrg
#   inflating: wsj/24/wsj_2410.mrg
#   inflating: wsj/24/wsj_2404.mrg
#   inflating: wsj/24/wsj_2401.mrg
#   inflating: wsj/24/wsj_2430.mrg
#   inflating: wsj/24/wsj_2453.mrg
#   inflating: wsj/24/wsj_2437.mrg
#   inflating: wsj/24/wsj_2439.mrg
#   inflating: wsj/24/wsj_2423.mrg
#   inflating: wsj/24/wsj_2428.mrg
#   inflating: wsj/24/wsj_2424.mrg
#   inflating: wsj/24/wsj_2440.mrg
#   inflating: wsj/24/wsj_2431.mrg
#   inflating: wsj/24/wsj_2422.mrg
#   inflating: wsj/24/wsj_2429.mrg
#   inflating: wsj/24/wsj_2447.mrg
#   inflating: wsj/24/wsj_2448.mrg
#   inflating: wsj/24/wsj_2421.mrg
#   inflating: wsj/24/wsj_2409.mrg
#   inflating: wsj/24/wsj_2415.mrg
#   inflating: wsj/24/wsj_2452.mrg
#   inflating: wsj/24/wsj_2426.mrg
#   inflating: wsj/24/wsj_2436.mrg
#   inflating: wsj/24/wsj_2433.mrg
#   inflating: wsj/24/wsj_2438.mrg
#   inflating: wsj/24/wsj_2451.mrg
#   inflating: wsj/24/wsj_2407.mrg
#   inflating: wsj/24/wsj_2454.mrg
#   inflating: wsj/24/wsj_2427.mrg
#   inflating: wsj/24/wsj_2450.mrg
#   inflating: wsj/24/wsj_2425.mrg
#   inflating: wsj/24/wsj_2432.mrg
#   inflating: wsj/24/wsj_2412.mrg
#   inflating: wsj/24/wsj_2435.mrg
#   inflating: wsj/24/wsj_2442.mrg
#   inflating: wsj/24/wsj_2403.mrg
#   inflating: wsj/24/wsj_2413.mrg
#   inflating: wsj/24/wsj_2443.mrg
#   inflating: wsj/24/wsj_2420.mrg
#   inflating: wsj/24/wsj_2411.mrg
#   inflating: wsj/24/wsj_2405.mrg
#   inflating: wsj/24/wsj_2449.mrg
#    creating: wsj/01/
#   inflating: wsj/01/wsj_0185.mrg
#   inflating: wsj/01/wsj_0186.mrg
#   inflating: wsj/01/wsj_0193.mrg
#   inflating: wsj/01/wsj_0107.mrg
#   inflating: wsj/01/wsj_0123.mrg
#   inflating: wsj/01/wsj_0121.mrg
#   inflating: wsj/01/wsj_0148.mrg
#   inflating: wsj/01/wsj_0151.mrg
#   inflating: wsj/01/wsj_0173.mrg
#   inflating: wsj/01/wsj_0137.mrg
#   inflating: wsj/01/wsj_0176.mrg
#   inflating: wsj/01/wsj_0110.mrg
#   inflating: wsj/01/wsj_0133.mrg
#   inflating: wsj/01/wsj_0194.mrg
#   inflating: wsj/01/wsj_0120.mrg
#   inflating: wsj/01/wsj_0147.mrg
#   inflating: wsj/01/wsj_0125.mrg
#   inflating: wsj/01/wsj_0153.mrg
#   inflating: wsj/01/wsj_0124.mrg
#   inflating: wsj/01/wsj_0184.mrg
#   inflating: wsj/01/wsj_0179.mrg
#   inflating: wsj/01/wsj_0104.mrg
#   inflating: wsj/01/wsj_0105.mrg
#   inflating: wsj/01/wsj_0113.mrg
#   inflating: wsj/01/wsj_0175.mrg
#   inflating: wsj/01/wsj_0149.mrg
#   inflating: wsj/01/wsj_0119.mrg
#   inflating: wsj/01/wsj_0146.mrg
#   inflating: wsj/01/wsj_0117.mrg
#   inflating: wsj/01/wsj_0163.mrg
#   inflating: wsj/01/wsj_0167.mrg
#   inflating: wsj/01/wsj_0135.mrg
#   inflating: wsj/01/wsj_0191.mrg
#   inflating: wsj/01/wsj_0131.mrg
#   inflating: wsj/01/wsj_0144.mrg
#   inflating: wsj/01/wsj_0156.mrg
#   inflating: wsj/01/wsj_0111.mrg
#   inflating: wsj/01/wsj_0118.mrg
#   inflating: wsj/01/wsj_0140.mrg
#   inflating: wsj/01/wsj_0196.mrg
#   inflating: wsj/01/wsj_0178.mrg
#   inflating: wsj/01/wsj_0152.mrg
#   inflating: wsj/01/wsj_0160.mrg
#   inflating: wsj/01/wsj_0141.mrg
#   inflating: wsj/01/wsj_0136.mrg
#   inflating: wsj/01/wsj_0169.mrg
#   inflating: wsj/01/wsj_0127.mrg
#   inflating: wsj/01/wsj_0155.mrg
#   inflating: wsj/01/wsj_0159.mrg
#   inflating: wsj/01/wsj_0126.mrg
#   inflating: wsj/01/wsj_0101.mrg
#   inflating: wsj/01/wsj_0106.mrg
#   inflating: wsj/01/wsj_0168.mrg
#   inflating: wsj/01/wsj_0112.mrg
#   inflating: wsj/01/wsj_0115.mrg
#   inflating: wsj/01/wsj_0197.mrg
#   inflating: wsj/01/wsj_0192.mrg
#   inflating: wsj/01/wsj_0195.mrg
#   inflating: wsj/01/wsj_0166.mrg
#   inflating: wsj/01/wsj_0143.mrg
#   inflating: wsj/01/wsj_0189.mrg
#   inflating: wsj/01/wsj_0142.mrg
#   inflating: wsj/01/wsj_0116.mrg
#   inflating: wsj/01/wsj_0161.mrg
#   inflating: wsj/01/wsj_0130.mrg
#   inflating: wsj/01/wsj_0122.mrg
#   inflating: wsj/01/wsj_0139.mrg
#   inflating: wsj/01/wsj_0183.mrg
#   inflating: wsj/01/wsj_0103.mrg
#   inflating: wsj/01/wsj_0190.mrg
#   inflating: wsj/01/wsj_0108.mrg
#   inflating: wsj/01/wsj_0100.mrg
#   inflating: wsj/01/wsj_0187.mrg
#   inflating: wsj/01/wsj_0171.mrg
#   inflating: wsj/01/wsj_0132.mrg
#   inflating: wsj/01/wsj_0162.mrg
#   inflating: wsj/01/wsj_0181.mrg
#   inflating: wsj/01/wsj_0129.mrg
#   inflating: wsj/01/wsj_0165.mrg
#   inflating: wsj/01/wsj_0198.mrg
#   inflating: wsj/01/wsj_0150.mrg
#   inflating: wsj/01/wsj_0114.mrg
#   inflating: wsj/01/wsj_0182.mrg
#   inflating: wsj/01/wsj_0164.mrg
#   inflating: wsj/01/wsj_0158.mrg
#   inflating: wsj/01/wsj_0138.mrg
#   inflating: wsj/01/wsj_0172.mrg
#   inflating: wsj/01/wsj_0109.mrg
#   inflating: wsj/01/wsj_0170.mrg
#   inflating: wsj/01/wsj_0177.mrg
#   inflating: wsj/01/wsj_0180.mrg
#   inflating: wsj/01/wsj_0145.mrg
#   inflating: wsj/01/wsj_0157.mrg
#   inflating: wsj/01/wsj_0199.mrg
#   inflating: wsj/01/wsj_0154.mrg
#   inflating: wsj/01/wsj_0102.mrg
#   inflating: wsj/01/wsj_0134.mrg
#   inflating: wsj/01/wsj_0128.mrg
#   inflating: wsj/01/wsj_0174.mrg
#   inflating: wsj/01/wsj_0188.mrg
#    creating: wsj/19/
#   inflating: wsj/19/wsj_1943.mrg
#   inflating: wsj/19/wsj_1948.mrg
#   inflating: wsj/19/wsj_1919.mrg
#   inflating: wsj/19/wsj_1944.mrg
#   inflating: wsj/19/wsj_1909.mrg
#   inflating: wsj/19/wsj_1934.mrg
#   inflating: wsj/19/wsj_1965.mrg
#   inflating: wsj/19/wsj_1959.mrg
#   inflating: wsj/19/wsj_1914.mrg
#   inflating: wsj/19/wsj_1942.mrg
#   inflating: wsj/19/wsj_1952.mrg
#   inflating: wsj/19/wsj_1982.mrg
#   inflating: wsj/19/wsj_1970.mrg
#   inflating: wsj/19/wsj_1902.mrg
#   inflating: wsj/19/wsj_1928.mrg
#   inflating: wsj/19/wsj_1994.mrg
#   inflating: wsj/19/wsj_1999.mrg
#   inflating: wsj/19/wsj_1956.mrg
#   inflating: wsj/19/wsj_1964.mrg
#   inflating: wsj/19/wsj_1967.mrg
#   inflating: wsj/19/wsj_1933.mrg
#   inflating: wsj/19/wsj_1915.mrg
#   inflating: wsj/19/wsj_1979.mrg
#   inflating: wsj/19/wsj_1972.mrg
#   inflating: wsj/19/wsj_1978.mrg
#   inflating: wsj/19/wsj_1945.mrg
#   inflating: wsj/19/wsj_1912.mrg
#   inflating: wsj/19/wsj_1950.mrg
#   inflating: wsj/19/wsj_1963.mrg
#   inflating: wsj/19/wsj_1971.mrg
#   inflating: wsj/19/wsj_1997.mrg
#   inflating: wsj/19/wsj_1946.mrg
#   inflating: wsj/19/wsj_1962.mrg
#   inflating: wsj/19/wsj_1941.mrg
#   inflating: wsj/19/wsj_1929.mrg
#   inflating: wsj/19/wsj_1987.mrg
#   inflating: wsj/19/wsj_1977.mrg
#   inflating: wsj/19/wsj_1936.mrg
#   inflating: wsj/19/wsj_1988.mrg
#   inflating: wsj/19/wsj_1931.mrg
#   inflating: wsj/19/wsj_1930.mrg
#   inflating: wsj/19/wsj_1980.mrg
#   inflating: wsj/19/wsj_1918.mrg
#   inflating: wsj/19/wsj_1938.mrg
#   inflating: wsj/19/wsj_1910.mrg
#   inflating: wsj/19/wsj_1974.mrg
#   inflating: wsj/19/wsj_1975.mrg
#   inflating: wsj/19/wsj_1995.mrg
#   inflating: wsj/19/wsj_1991.mrg
#   inflating: wsj/19/wsj_1901.mrg
#   inflating: wsj/19/wsj_1932.mrg
#   inflating: wsj/19/wsj_1908.mrg
#   inflating: wsj/19/wsj_1990.mrg
#   inflating: wsj/19/wsj_1916.mrg
#   inflating: wsj/19/wsj_1961.mrg
#   inflating: wsj/19/wsj_1985.mrg
#   inflating: wsj/19/wsj_1907.mrg
#   inflating: wsj/19/wsj_1953.mrg
#   inflating: wsj/19/wsj_1922.mrg
#   inflating: wsj/19/wsj_1986.mrg
#   inflating: wsj/19/wsj_1949.mrg
#   inflating: wsj/19/wsj_1958.mrg
#   inflating: wsj/19/wsj_1947.mrg
#   inflating: wsj/19/wsj_1904.mrg
#   inflating: wsj/19/wsj_1993.mrg
#   inflating: wsj/19/wsj_1935.mrg
#   inflating: wsj/19/wsj_1903.mrg
#   inflating: wsj/19/wsj_1925.mrg
#   inflating: wsj/19/wsj_1973.mrg
#   inflating: wsj/19/wsj_1998.mrg
#   inflating: wsj/19/wsj_1981.mrg
#   inflating: wsj/19/wsj_1976.mrg
#   inflating: wsj/19/wsj_1969.mrg
#   inflating: wsj/19/wsj_1960.mrg
#   inflating: wsj/19/wsj_1921.mrg
#   inflating: wsj/19/wsj_1951.mrg
#   inflating: wsj/19/wsj_1926.mrg
#   inflating: wsj/19/wsj_1989.mrg
#   inflating: wsj/19/wsj_1983.mrg
#   inflating: wsj/19/wsj_1905.mrg
#   inflating: wsj/19/wsj_1966.mrg
#   inflating: wsj/19/wsj_1923.mrg
#   inflating: wsj/19/wsj_1913.mrg
#   inflating: wsj/19/wsj_1920.mrg
#   inflating: wsj/19/wsj_1955.mrg
#   inflating: wsj/19/wsj_1927.mrg
#   inflating: wsj/19/wsj_1917.mrg
#   inflating: wsj/19/wsj_1992.mrg
#   inflating: wsj/19/wsj_1940.mrg
#   inflating: wsj/19/wsj_1954.mrg
#   inflating: wsj/19/wsj_1924.mrg
#   inflating: wsj/19/wsj_1968.mrg
#   inflating: wsj/19/wsj_1957.mrg
#   inflating: wsj/19/wsj_1900.mrg
#   inflating: wsj/19/wsj_1939.mrg
#   inflating: wsj/19/wsj_1984.mrg
#   inflating: wsj/19/wsj_1911.mrg
#   inflating: wsj/19/wsj_1937.mrg
#   inflating: wsj/19/wsj_1996.mrg
#   inflating: wsj/19/wsj_1906.mrg
#    creating: wsj/08/
#   inflating: wsj/08/wsj_0816.mrg
#   inflating: wsj/08/wsj_0803.mrg
#   inflating: wsj/08/wsj_0820.mrg
#   inflating: wsj/08/wsj_0806.mrg
#   inflating: wsj/08/wsj_0800.mrg
#   inflating: wsj/08/wsj_0804.mrg
#   inflating: wsj/08/wsj_0805.mrg
#   inflating: wsj/08/wsj_0813.mrg
#   inflating: wsj/08/wsj_0801.mrg
#   inflating: wsj/08/wsj_0812.mrg
#   inflating: wsj/08/wsj_0807.mrg
#   inflating: wsj/08/wsj_0819.mrg
#   inflating: wsj/08/wsj_0809.mrg
#   inflating: wsj/08/wsj_0802.mrg
#   inflating: wsj/08/wsj_0808.mrg
#   inflating: wsj/08/wsj_0811.mrg
#   inflating: wsj/08/wsj_0815.mrg
#   inflating: wsj/08/wsj_0814.mrg
#   inflating: wsj/08/wsj_0818.mrg
#   inflating: wsj/08/wsj_0817.mrg
#   inflating: wsj/08/wsj_0810.mrg
#    creating: wsj/20/
#   inflating: wsj/20/wsj_2083.mrg
#   inflating: wsj/20/wsj_2086.mrg
#   inflating: wsj/20/wsj_2017.mrg
#   inflating: wsj/20/wsj_2096.mrg
#   inflating: wsj/20/wsj_2033.mrg
#   inflating: wsj/20/wsj_2069.mrg
#   inflating: wsj/20/wsj_2014.mrg
#   inflating: wsj/20/wsj_2018.mrg
#   inflating: wsj/20/wsj_2044.mrg
#   inflating: wsj/20/wsj_2011.mrg
#   inflating: wsj/20/wsj_2024.mrg
#   inflating: wsj/20/wsj_2051.mrg
#   inflating: wsj/20/wsj_2040.mrg
#   inflating: wsj/20/wsj_2073.mrg
#   inflating: wsj/20/wsj_2061.mrg
#   inflating: wsj/20/wsj_2034.mrg
#   inflating: wsj/20/wsj_2008.mrg
#   inflating: wsj/20/wsj_2046.mrg
#   inflating: wsj/20/wsj_2006.mrg
#   inflating: wsj/20/wsj_2019.mrg
#   inflating: wsj/20/wsj_2099.mrg
#   inflating: wsj/20/wsj_2060.mrg
#   inflating: wsj/20/wsj_2068.mrg
#   inflating: wsj/20/wsj_2066.mrg
#   inflating: wsj/20/wsj_2041.mrg
#   inflating: wsj/20/wsj_2000.mrg
#   inflating: wsj/20/wsj_2082.mrg
#   inflating: wsj/20/wsj_2092.mrg
#   inflating: wsj/20/wsj_2079.mrg
#   inflating: wsj/20/wsj_2012.mrg
#   inflating: wsj/20/wsj_2088.mrg
#   inflating: wsj/20/wsj_2021.mrg
#   inflating: wsj/20/wsj_2062.mrg
#   inflating: wsj/20/wsj_2020.mrg
#   inflating: wsj/20/wsj_2043.mrg
#   inflating: wsj/20/wsj_2098.mrg
#   inflating: wsj/20/wsj_2029.mrg
#   inflating: wsj/20/wsj_2036.mrg
#   inflating: wsj/20/wsj_2091.mrg
#   inflating: wsj/20/wsj_2015.mrg
#   inflating: wsj/20/wsj_2063.mrg
#   inflating: wsj/20/wsj_2054.mrg
#   inflating: wsj/20/wsj_2047.mrg
#   inflating: wsj/20/wsj_2050.mrg
#   inflating: wsj/20/wsj_2031.mrg
#   inflating: wsj/20/wsj_2097.mrg
#   inflating: wsj/20/wsj_2045.mrg
#   inflating: wsj/20/wsj_2032.mrg
#   inflating: wsj/20/wsj_2087.mrg
#   inflating: wsj/20/wsj_2093.mrg
#   inflating: wsj/20/wsj_2004.mrg
#   inflating: wsj/20/wsj_2003.mrg
#   inflating: wsj/20/wsj_2042.mrg
#   inflating: wsj/20/wsj_2090.mrg
#   inflating: wsj/20/wsj_2081.mrg
#   inflating: wsj/20/wsj_2078.mrg
#   inflating: wsj/20/wsj_2064.mrg
#   inflating: wsj/20/wsj_2065.mrg
#   inflating: wsj/20/wsj_2038.mrg
#   inflating: wsj/20/wsj_2075.mrg
#   inflating: wsj/20/wsj_2057.mrg
#   inflating: wsj/20/wsj_2002.mrg
#   inflating: wsj/20/wsj_2022.mrg
#   inflating: wsj/20/wsj_2023.mrg
#   inflating: wsj/20/wsj_2053.mrg
#   inflating: wsj/20/wsj_2001.mrg
#   inflating: wsj/20/wsj_2058.mrg
#   inflating: wsj/20/wsj_2080.mrg
#   inflating: wsj/20/wsj_2089.mrg
#   inflating: wsj/20/wsj_2005.mrg
#   inflating: wsj/20/wsj_2055.mrg
#   inflating: wsj/20/wsj_2076.mrg
#   inflating: wsj/20/wsj_2013.mrg
#   inflating: wsj/20/wsj_2026.mrg
#   inflating: wsj/20/wsj_2084.mrg
#   inflating: wsj/20/wsj_2094.mrg
#   inflating: wsj/20/wsj_2072.mrg
#   inflating: wsj/20/wsj_2070.mrg
#   inflating: wsj/20/wsj_2039.mrg
#   inflating: wsj/20/wsj_2071.mrg
#   inflating: wsj/20/wsj_2056.mrg
#   inflating: wsj/20/wsj_2048.mrg
#   inflating: wsj/20/wsj_2030.mrg
#   inflating: wsj/20/wsj_2052.mrg
#   inflating: wsj/20/wsj_2009.mrg
#   inflating: wsj/20/wsj_2067.mrg
#   inflating: wsj/20/wsj_2059.mrg
#   inflating: wsj/20/wsj_2095.mrg
#   inflating: wsj/20/wsj_2077.mrg
#   inflating: wsj/20/wsj_2049.mrg
#   inflating: wsj/20/wsj_2035.mrg
#   inflating: wsj/20/wsj_2025.mrg
#   inflating: wsj/20/wsj_2007.mrg
#   inflating: wsj/20/wsj_2016.mrg
#   inflating: wsj/20/wsj_2085.mrg
#   inflating: wsj/20/wsj_2074.mrg
#   inflating: wsj/20/wsj_2028.mrg
#   inflating: wsj/20/wsj_2027.mrg
#   inflating: wsj/20/wsj_2010.mrg
#   inflating: wsj/20/wsj_2037.mrg
#    creating: wsj/14/
#   inflating: wsj/14/wsj_1462.mrg
#   inflating: wsj/14/wsj_1425.mrg
#   inflating: wsj/14/wsj_1479.mrg
#   inflating: wsj/14/wsj_1495.mrg
#   inflating: wsj/14/wsj_1456.mrg
#   inflating: wsj/14/wsj_1430.mrg
#   inflating: wsj/14/wsj_1428.mrg
#   inflating: wsj/14/wsj_1496.mrg
#   inflating: wsj/14/wsj_1445.mrg
#   inflating: wsj/14/wsj_1471.mrg
#   inflating: wsj/14/wsj_1460.mrg
#   inflating: wsj/14/wsj_1491.mrg
#   inflating: wsj/14/wsj_1494.mrg
#   inflating: wsj/14/wsj_1468.mrg
#   inflating: wsj/14/wsj_1448.mrg
#   inflating: wsj/14/wsj_1470.mrg
#   inflating: wsj/14/wsj_1443.mrg
#   inflating: wsj/14/wsj_1444.mrg
#   inflating: wsj/14/wsj_1483.mrg
#   inflating: wsj/14/wsj_1440.mrg
#   inflating: wsj/14/wsj_1410.mrg
#   inflating: wsj/14/wsj_1408.mrg
#   inflating: wsj/14/wsj_1453.mrg
#   inflating: wsj/14/wsj_1414.mrg
#   inflating: wsj/14/wsj_1486.mrg
#   inflating: wsj/14/wsj_1467.mrg
#   inflating: wsj/14/wsj_1427.mrg
#   inflating: wsj/14/wsj_1465.mrg
#   inflating: wsj/14/wsj_1412.mrg
#   inflating: wsj/14/wsj_1454.mrg
#   inflating: wsj/14/wsj_1480.mrg
#   inflating: wsj/14/wsj_1473.mrg
#   inflating: wsj/14/wsj_1458.mrg
#   inflating: wsj/14/wsj_1490.mrg
#   inflating: wsj/14/wsj_1422.mrg
#   inflating: wsj/14/wsj_1402.mrg
#   inflating: wsj/14/wsj_1419.mrg
#   inflating: wsj/14/wsj_1416.mrg
#   inflating: wsj/14/wsj_1476.mrg
#   inflating: wsj/14/wsj_1492.mrg
#   inflating: wsj/14/wsj_1400.mrg
#   inflating: wsj/14/wsj_1447.mrg
#   inflating: wsj/14/wsj_1472.mrg
#   inflating: wsj/14/wsj_1482.mrg
#   inflating: wsj/14/wsj_1474.mrg
#   inflating: wsj/14/wsj_1452.mrg
#   inflating: wsj/14/wsj_1469.mrg
#   inflating: wsj/14/wsj_1404.mrg
#   inflating: wsj/14/wsj_1484.mrg
#   inflating: wsj/14/wsj_1488.mrg
#   inflating: wsj/14/wsj_1464.mrg
#   inflating: wsj/14/wsj_1423.mrg
#   inflating: wsj/14/wsj_1446.mrg
#   inflating: wsj/14/wsj_1459.mrg
#   inflating: wsj/14/wsj_1441.mrg
#   inflating: wsj/14/wsj_1466.mrg
#   inflating: wsj/14/wsj_1405.mrg
#   inflating: wsj/14/wsj_1442.mrg
#   inflating: wsj/14/wsj_1413.mrg
#   inflating: wsj/14/wsj_1411.mrg
#   inflating: wsj/14/wsj_1481.mrg
#   inflating: wsj/14/wsj_1455.mrg
#   inflating: wsj/14/wsj_1432.mrg
#   inflating: wsj/14/wsj_1409.mrg
#   inflating: wsj/14/wsj_1439.mrg
#   inflating: wsj/14/wsj_1493.mrg
#   inflating: wsj/14/wsj_1407.mrg
#   inflating: wsj/14/wsj_1434.mrg
#   inflating: wsj/14/wsj_1435.mrg
#   inflating: wsj/14/wsj_1426.mrg
#   inflating: wsj/14/wsj_1438.mrg
#   inflating: wsj/14/wsj_1477.mrg
#   inflating: wsj/14/wsj_1463.mrg
#   inflating: wsj/14/wsj_1403.mrg
#   inflating: wsj/14/wsj_1499.mrg
#   inflating: wsj/14/wsj_1401.mrg
#   inflating: wsj/14/wsj_1497.mrg
#   inflating: wsj/14/wsj_1461.mrg
#   inflating: wsj/14/wsj_1489.mrg
#   inflating: wsj/14/wsj_1475.mrg
#   inflating: wsj/14/wsj_1485.mrg
#   inflating: wsj/14/wsj_1457.mrg
#   inflating: wsj/14/wsj_1431.mrg
#   inflating: wsj/14/wsj_1420.mrg
#   inflating: wsj/14/wsj_1449.mrg
#   inflating: wsj/14/wsj_1437.mrg
#   inflating: wsj/14/wsj_1429.mrg
#   inflating: wsj/14/wsj_1418.mrg
#   inflating: wsj/14/wsj_1415.mrg
#   inflating: wsj/14/wsj_1487.mrg
#   inflating: wsj/14/wsj_1433.mrg
#   inflating: wsj/14/wsj_1424.mrg
#   inflating: wsj/14/wsj_1450.mrg
#   inflating: wsj/14/wsj_1417.mrg
#   inflating: wsj/14/wsj_1478.mrg
#   inflating: wsj/14/wsj_1406.mrg
#   inflating: wsj/14/wsj_1436.mrg
#   inflating: wsj/14/wsj_1498.mrg
#   inflating: wsj/14/wsj_1421.mrg
#   inflating: wsj/14/wsj_1451.mrg
#    creating: wsj/17/
#   inflating: wsj/17/wsj_1792.mrg
#   inflating: wsj/17/wsj_1752.mrg
#   inflating: wsj/17/wsj_1754.mrg
#   inflating: wsj/17/wsj_1769.mrg
#   inflating: wsj/17/wsj_1721.mrg
#   inflating: wsj/17/wsj_1734.mrg
#   inflating: wsj/17/wsj_1794.mrg
#   inflating: wsj/17/wsj_1797.mrg
#   inflating: wsj/17/wsj_1773.mrg
#   inflating: wsj/17/wsj_1742.mrg
#   inflating: wsj/17/wsj_1760.mrg
#   inflating: wsj/17/wsj_1791.mrg
#   inflating: wsj/17/wsj_1737.mrg
#   inflating: wsj/17/wsj_1743.mrg
#   inflating: wsj/17/wsj_1738.mrg
#   inflating: wsj/17/wsj_1756.mrg
#   inflating: wsj/17/wsj_1779.mrg
#   inflating: wsj/17/wsj_1704.mrg
#   inflating: wsj/17/wsj_1727.mrg
#   inflating: wsj/17/wsj_1703.mrg
#   inflating: wsj/17/wsj_1768.mrg
#   inflating: wsj/17/wsj_1739.mrg
#   inflating: wsj/17/wsj_1735.mrg
#   inflating: wsj/17/wsj_1746.mrg
#   inflating: wsj/17/wsj_1741.mrg
#   inflating: wsj/17/wsj_1789.mrg
#   inflating: wsj/17/wsj_1772.mrg
#   inflating: wsj/17/wsj_1713.mrg
#   inflating: wsj/17/wsj_1788.mrg
#   inflating: wsj/17/wsj_1733.mrg
#   inflating: wsj/17/wsj_1770.mrg
#   inflating: wsj/17/wsj_1716.mrg
#   inflating: wsj/17/wsj_1710.mrg
#   inflating: wsj/17/wsj_1793.mrg
#   inflating: wsj/17/wsj_1747.mrg
#   inflating: wsj/17/wsj_1736.mrg
#   inflating: wsj/17/wsj_1787.mrg
#   inflating: wsj/17/wsj_1723.mrg
#   inflating: wsj/17/wsj_1707.mrg
#   inflating: wsj/17/wsj_1766.mrg
#   inflating: wsj/17/wsj_1750.mrg
#   inflating: wsj/17/wsj_1726.mrg
#   inflating: wsj/17/wsj_1759.mrg
#   inflating: wsj/17/wsj_1755.mrg
#   inflating: wsj/17/wsj_1731.mrg
#   inflating: wsj/17/wsj_1799.mrg
#   inflating: wsj/17/wsj_1725.mrg
#   inflating: wsj/17/wsj_1740.mrg
#   inflating: wsj/17/wsj_1753.mrg
#   inflating: wsj/17/wsj_1758.mrg
#   inflating: wsj/17/wsj_1778.mrg
#   inflating: wsj/17/wsj_1782.mrg
#   inflating: wsj/17/wsj_1709.mrg
#   inflating: wsj/17/wsj_1795.mrg
#   inflating: wsj/17/wsj_1761.mrg
#   inflating: wsj/17/wsj_1730.mrg
#   inflating: wsj/17/wsj_1781.mrg
#   inflating: wsj/17/wsj_1780.mrg
#   inflating: wsj/17/wsj_1714.mrg
#   inflating: wsj/17/wsj_1702.mrg
#   inflating: wsj/17/wsj_1751.mrg
#   inflating: wsj/17/wsj_1771.mrg
#   inflating: wsj/17/wsj_1706.mrg
#   inflating: wsj/17/wsj_1749.mrg
#   inflating: wsj/17/wsj_1763.mrg
#   inflating: wsj/17/wsj_1745.mrg
#   inflating: wsj/17/wsj_1775.mrg
#   inflating: wsj/17/wsj_1784.mrg
#   inflating: wsj/17/wsj_1729.mrg
#   inflating: wsj/17/wsj_1700.mrg
#   inflating: wsj/17/wsj_1748.mrg
#   inflating: wsj/17/wsj_1712.mrg
#   inflating: wsj/17/wsj_1705.mrg
#   inflating: wsj/17/wsj_1744.mrg
#   inflating: wsj/17/wsj_1776.mrg
#   inflating: wsj/17/wsj_1786.mrg
#   inflating: wsj/17/wsj_1762.mrg
#   inflating: wsj/17/wsj_1765.mrg
#   inflating: wsj/17/wsj_1711.mrg
#   inflating: wsj/17/wsj_1757.mrg
#   inflating: wsj/17/wsj_1708.mrg
#   inflating: wsj/17/wsj_1718.mrg
#   inflating: wsj/17/wsj_1701.mrg
#   inflating: wsj/17/wsj_1720.mrg
#   inflating: wsj/17/wsj_1798.mrg
#   inflating: wsj/17/wsj_1783.mrg
#   inflating: wsj/17/wsj_1724.mrg
#   inflating: wsj/17/wsj_1785.mrg
#   inflating: wsj/17/wsj_1767.mrg
#   inflating: wsj/17/wsj_1790.mrg
#   inflating: wsj/17/wsj_1715.mrg
#   inflating: wsj/17/wsj_1719.mrg
#   inflating: wsj/17/wsj_1777.mrg
#   inflating: wsj/17/wsj_1796.mrg
#   inflating: wsj/17/wsj_1728.mrg
#   inflating: wsj/17/wsj_1722.mrg
#   inflating: wsj/17/wsj_1774.mrg
#   inflating: wsj/17/wsj_1717.mrg
#   inflating: wsj/17/wsj_1732.mrg
#   inflating: wsj/17/wsj_1764.mrg
#    creating: wsj/22/
#   inflating: wsj/22/wsj_2218.mrg
#   inflating: wsj/22/wsj_2254.mrg
#   inflating: wsj/22/wsj_2207.mrg
#   inflating: wsj/22/wsj_2204.mrg
#   inflating: wsj/22/wsj_2271.mrg
#   inflating: wsj/22/wsj_2266.mrg
#   inflating: wsj/22/wsj_2261.mrg
#   inflating: wsj/22/wsj_2234.mrg
#   inflating: wsj/22/wsj_2224.mrg
#   inflating: wsj/22/wsj_2255.mrg
#   inflating: wsj/22/wsj_2203.mrg
#   inflating: wsj/22/wsj_2250.mrg
#   inflating: wsj/22/wsj_2229.mrg
#   inflating: wsj/22/wsj_2226.mrg
#   inflating: wsj/22/wsj_2270.mrg
#   inflating: wsj/22/wsj_2279.mrg
#   inflating: wsj/22/wsj_2277.mrg
#   inflating: wsj/22/wsj_2211.mrg
#   inflating: wsj/22/wsj_2240.mrg
#   inflating: wsj/22/wsj_2201.mrg
#   inflating: wsj/22/wsj_2280.mrg
#   inflating: wsj/22/wsj_2274.mrg
#   inflating: wsj/22/wsj_2221.mrg
#   inflating: wsj/22/wsj_2260.mrg
#   inflating: wsj/22/wsj_2246.mrg
#   inflating: wsj/22/wsj_2205.mrg
#   inflating: wsj/22/wsj_2278.mrg
#   inflating: wsj/22/wsj_2212.mrg
#   inflating: wsj/22/wsj_2216.mrg
#   inflating: wsj/22/wsj_2249.mrg
#   inflating: wsj/22/wsj_2202.mrg
#   inflating: wsj/22/wsj_2228.mrg
#   inflating: wsj/22/wsj_2241.mrg
#   inflating: wsj/22/wsj_2257.mrg
#   inflating: wsj/22/wsj_2264.mrg
#   inflating: wsj/22/wsj_2262.mrg
#   inflating: wsj/22/wsj_2200.mrg
#   inflating: wsj/22/wsj_2230.mrg
#   inflating: wsj/22/wsj_2233.mrg
#   inflating: wsj/22/wsj_2265.mrg
#   inflating: wsj/22/wsj_2247.mrg
#   inflating: wsj/22/wsj_2210.mrg
#   inflating: wsj/22/wsj_2206.mrg
#   inflating: wsj/22/wsj_2236.mrg
#   inflating: wsj/22/wsj_2231.mrg
#   inflating: wsj/22/wsj_2248.mrg
#   inflating: wsj/22/wsj_2281.mrg
#   inflating: wsj/22/wsj_2237.mrg
#   inflating: wsj/22/wsj_2239.mrg
#   inflating: wsj/22/wsj_2208.mrg
#   inflating: wsj/22/wsj_2219.mrg
#   inflating: wsj/22/wsj_2227.mrg
#   inflating: wsj/22/wsj_2273.mrg
#   inflating: wsj/22/wsj_2251.mrg
#   inflating: wsj/22/wsj_2253.mrg
#   inflating: wsj/22/wsj_2209.mrg
#   inflating: wsj/22/wsj_2243.mrg
#   inflating: wsj/22/wsj_2215.mrg
#   inflating: wsj/22/wsj_2282.mrg
#   inflating: wsj/22/wsj_2238.mrg
#   inflating: wsj/22/wsj_2220.mrg
#   inflating: wsj/22/wsj_2242.mrg
#   inflating: wsj/22/wsj_2276.mrg
#   inflating: wsj/22/wsj_2263.mrg
#   inflating: wsj/22/wsj_2275.mrg
#   inflating: wsj/22/wsj_2256.mrg
#   inflating: wsj/22/wsj_2213.mrg
#   inflating: wsj/22/wsj_2272.mrg
#   inflating: wsj/22/wsj_2252.mrg
#   inflating: wsj/22/wsj_2217.mrg
#   inflating: wsj/22/wsj_2232.mrg
#   inflating: wsj/22/wsj_2244.mrg
#   inflating: wsj/22/wsj_2225.mrg
#   inflating: wsj/22/wsj_2259.mrg
#   inflating: wsj/22/wsj_2235.mrg
#   inflating: wsj/22/wsj_2268.mrg
#   inflating: wsj/22/wsj_2258.mrg
#   inflating: wsj/22/wsj_2222.mrg
#   inflating: wsj/22/wsj_2245.mrg
#   inflating: wsj/22/wsj_2214.mrg
#   inflating: wsj/22/wsj_2269.mrg
#   inflating: wsj/22/wsj_2223.mrg
#   inflating: wsj/22/wsj_2267.mrg
#    creating: wsj/12/
#   inflating: wsj/12/wsj_1216.mrg
#   inflating: wsj/12/wsj_1260.mrg
#   inflating: wsj/12/wsj_1246.mrg
#   inflating: wsj/12/wsj_1224.mrg
#   inflating: wsj/12/wsj_1287.mrg
#   inflating: wsj/12/wsj_1277.mrg
#   inflating: wsj/12/wsj_1253.mrg
#   inflating: wsj/12/wsj_1234.mrg
#   inflating: wsj/12/wsj_1239.mrg
#   inflating: wsj/12/wsj_1268.mrg
#   inflating: wsj/12/wsj_1217.mrg
#   inflating: wsj/12/wsj_1265.mrg
#   inflating: wsj/12/wsj_1288.mrg
#   inflating: wsj/12/wsj_1257.mrg
#   inflating: wsj/12/wsj_1214.mrg
#   inflating: wsj/12/wsj_1249.mrg
#   inflating: wsj/12/wsj_1294.mrg
#   inflating: wsj/12/wsj_1280.mrg
#   inflating: wsj/12/wsj_1218.mrg
#   inflating: wsj/12/wsj_1286.mrg
#   inflating: wsj/12/wsj_1255.mrg
#   inflating: wsj/12/wsj_1227.mrg
#   inflating: wsj/12/wsj_1205.mrg
#   inflating: wsj/12/wsj_1207.mrg
#   inflating: wsj/12/wsj_1229.mrg
#   inflating: wsj/12/wsj_1271.mrg
#   inflating: wsj/12/wsj_1251.mrg
#   inflating: wsj/12/wsj_1203.mrg
#   inflating: wsj/12/wsj_1201.mrg
#   inflating: wsj/12/wsj_1261.mrg
#   inflating: wsj/12/wsj_1278.mrg
#   inflating: wsj/12/wsj_1275.mrg
#   inflating: wsj/12/wsj_1292.mrg
#   inflating: wsj/12/wsj_1223.mrg
#   inflating: wsj/12/wsj_1210.mrg
#   inflating: wsj/12/wsj_1211.mrg
#   inflating: wsj/12/wsj_1267.mrg
#   inflating: wsj/12/wsj_1226.mrg
#   inflating: wsj/12/wsj_1237.mrg
#   inflating: wsj/12/wsj_1273.mrg
#   inflating: wsj/12/wsj_1230.mrg
#   inflating: wsj/12/wsj_1245.mrg
#   inflating: wsj/12/wsj_1281.mrg
#   inflating: wsj/12/wsj_1250.mrg
#   inflating: wsj/12/wsj_1262.mrg
#   inflating: wsj/12/wsj_1213.mrg
#   inflating: wsj/12/wsj_1284.mrg
#   inflating: wsj/12/wsj_1235.mrg
#   inflating: wsj/12/wsj_1293.mrg
#   inflating: wsj/12/wsj_1298.mrg
#   inflating: wsj/12/wsj_1225.mrg
#   inflating: wsj/12/wsj_1279.mrg
#   inflating: wsj/12/wsj_1238.mrg
#   inflating: wsj/12/wsj_1242.mrg
#   inflating: wsj/12/wsj_1200.mrg
#   inflating: wsj/12/wsj_1222.mrg
#   inflating: wsj/12/wsj_1233.mrg
#   inflating: wsj/12/wsj_1204.mrg
#   inflating: wsj/12/wsj_1252.mrg
#   inflating: wsj/12/wsj_1231.mrg
#   inflating: wsj/12/wsj_1248.mrg
#   inflating: wsj/12/wsj_1219.mrg
#   inflating: wsj/12/wsj_1272.mrg
#   inflating: wsj/12/wsj_1291.mrg
#   inflating: wsj/12/wsj_1228.mrg
#   inflating: wsj/12/wsj_1247.mrg
#   inflating: wsj/12/wsj_1206.mrg
#   inflating: wsj/12/wsj_1240.mrg
#   inflating: wsj/12/wsj_1232.mrg
#   inflating: wsj/12/wsj_1296.mrg
#   inflating: wsj/12/wsj_1258.mrg
#   inflating: wsj/12/wsj_1221.mrg
#   inflating: wsj/12/wsj_1269.mrg
#   inflating: wsj/12/wsj_1259.mrg
#   inflating: wsj/12/wsj_1270.mrg
#   inflating: wsj/12/wsj_1243.mrg
#   inflating: wsj/12/wsj_1236.mrg
#   inflating: wsj/12/wsj_1215.mrg
#   inflating: wsj/12/wsj_1283.mrg
#   inflating: wsj/12/wsj_1220.mrg
#   inflating: wsj/12/wsj_1290.mrg
#   inflating: wsj/12/wsj_1274.mrg
#   inflating: wsj/12/wsj_1266.mrg
#   inflating: wsj/12/wsj_1282.mrg
#   inflating: wsj/12/wsj_1264.mrg
#   inflating: wsj/12/wsj_1263.mrg
#   inflating: wsj/12/wsj_1254.mrg
#   inflating: wsj/12/wsj_1212.mrg
#   inflating: wsj/12/wsj_1285.mrg
#   inflating: wsj/12/wsj_1276.mrg
#   inflating: wsj/12/wsj_1241.mrg
#   inflating: wsj/12/wsj_1209.mrg
#   inflating: wsj/12/wsj_1208.mrg
#   inflating: wsj/12/wsj_1289.mrg
#   inflating: wsj/12/wsj_1295.mrg
#   inflating: wsj/12/wsj_1256.mrg
#   inflating: wsj/12/wsj_1299.mrg
#   inflating: wsj/12/wsj_1297.mrg
#   inflating: wsj/12/wsj_1202.mrg
#   inflating: wsj/12/wsj_1244.mrg
#    creating: wsj/13/
#   inflating: wsj/13/wsj_1324.mrg
#   inflating: wsj/13/wsj_1384.mrg
#   inflating: wsj/13/wsj_1319.mrg
#   inflating: wsj/13/wsj_1343.mrg
#   inflating: wsj/13/wsj_1372.mrg
#   inflating: wsj/13/wsj_1330.mrg
#   inflating: wsj/13/wsj_1373.mrg
#   inflating: wsj/13/wsj_1371.mrg
#   inflating: wsj/13/wsj_1342.mrg
#   inflating: wsj/13/wsj_1390.mrg
#   inflating: wsj/13/wsj_1300.mrg
#   inflating: wsj/13/wsj_1387.mrg
#   inflating: wsj/13/wsj_1345.mrg
#   inflating: wsj/13/wsj_1398.mrg
#   inflating: wsj/13/wsj_1363.mrg
#   inflating: wsj/13/wsj_1304.mrg
#   inflating: wsj/13/wsj_1325.mrg
#   inflating: wsj/13/wsj_1348.mrg
#   inflating: wsj/13/wsj_1377.mrg
#   inflating: wsj/13/wsj_1307.mrg
#   inflating: wsj/13/wsj_1362.mrg
#   inflating: wsj/13/wsj_1320.mrg
#   inflating: wsj/13/wsj_1310.mrg
#   inflating: wsj/13/wsj_1379.mrg
#   inflating: wsj/13/wsj_1313.mrg
#   inflating: wsj/13/wsj_1326.mrg
#   inflating: wsj/13/wsj_1312.mrg
#   inflating: wsj/13/wsj_1347.mrg
#   inflating: wsj/13/wsj_1334.mrg
#   inflating: wsj/13/wsj_1393.mrg
#   inflating: wsj/13/wsj_1335.mrg
#   inflating: wsj/13/wsj_1315.mrg
#   inflating: wsj/13/wsj_1383.mrg
#   inflating: wsj/13/wsj_1355.mrg
#   inflating: wsj/13/wsj_1331.mrg
#   inflating: wsj/13/wsj_1341.mrg
#   inflating: wsj/13/wsj_1309.mrg
#   inflating: wsj/13/wsj_1392.mrg
#   inflating: wsj/13/wsj_1395.mrg
#   inflating: wsj/13/wsj_1394.mrg
#   inflating: wsj/13/wsj_1346.mrg
#   inflating: wsj/13/wsj_1305.mrg
#   inflating: wsj/13/wsj_1351.mrg
#   inflating: wsj/13/wsj_1336.mrg
#   inflating: wsj/13/wsj_1301.mrg
#   inflating: wsj/13/wsj_1366.mrg
#   inflating: wsj/13/wsj_1396.mrg
#   inflating: wsj/13/wsj_1376.mrg
#   inflating: wsj/13/wsj_1388.mrg
#   inflating: wsj/13/wsj_1327.mrg
#   inflating: wsj/13/wsj_1317.mrg
#   inflating: wsj/13/wsj_1386.mrg
#   inflating: wsj/13/wsj_1337.mrg
#   inflating: wsj/13/wsj_1389.mrg
#   inflating: wsj/13/wsj_1323.mrg
#   inflating: wsj/13/wsj_1365.mrg
#   inflating: wsj/13/wsj_1374.mrg
#   inflating: wsj/13/wsj_1338.mrg
#   inflating: wsj/13/wsj_1328.mrg
#   inflating: wsj/13/wsj_1353.mrg
#   inflating: wsj/13/wsj_1370.mrg
#   inflating: wsj/13/wsj_1329.mrg
#   inflating: wsj/13/wsj_1321.mrg
#   inflating: wsj/13/wsj_1340.mrg
#   inflating: wsj/13/wsj_1369.mrg
#   inflating: wsj/13/wsj_1318.mrg
#   inflating: wsj/13/wsj_1361.mrg
#   inflating: wsj/13/wsj_1360.mrg
#   inflating: wsj/13/wsj_1381.mrg
#   inflating: wsj/13/wsj_1367.mrg
#   inflating: wsj/13/wsj_1378.mrg
#   inflating: wsj/13/wsj_1352.mrg
#   inflating: wsj/13/wsj_1311.mrg
#   inflating: wsj/13/wsj_1375.mrg
#   inflating: wsj/13/wsj_1339.mrg
#   inflating: wsj/13/wsj_1391.mrg
#   inflating: wsj/13/wsj_1316.mrg
#   inflating: wsj/13/wsj_1350.mrg
#   inflating: wsj/13/wsj_1397.mrg
#   inflating: wsj/13/wsj_1385.mrg
#   inflating: wsj/13/wsj_1382.mrg
#   inflating: wsj/13/wsj_1344.mrg
#   inflating: wsj/13/wsj_1358.mrg
#   inflating: wsj/13/wsj_1308.mrg
#   inflating: wsj/13/wsj_1364.mrg
#   inflating: wsj/13/wsj_1349.mrg
#   inflating: wsj/13/wsj_1359.mrg
#   inflating: wsj/13/wsj_1368.mrg
#   inflating: wsj/13/wsj_1333.mrg
#   inflating: wsj/13/wsj_1354.mrg
#   inflating: wsj/13/wsj_1399.mrg
#   inflating: wsj/13/wsj_1380.mrg
#   inflating: wsj/13/wsj_1303.mrg
#   inflating: wsj/13/wsj_1314.mrg
#   inflating: wsj/13/wsj_1356.mrg
#   inflating: wsj/13/wsj_1322.mrg
# ...
#   inflating: wsj/23/wsj_2313.mrg
#   inflating: wsj/23/wsj_2330.mrg
#   inflating: wsj/23/wsj_2349.mrg
#   inflating: wsj/23/wsj_2388.mrg
#   inflating: wsj/23/wsj_2342.mrg
#   inflating: wsj/23/wsj_2383.mrg
#   inflating: wsj/23/wsj_2345.mrg
#   inflating: wsj/23/wsj_2320.mrg
#   inflating: wsj/23/wsj_2326.mrg
#   inflating: wsj/23/wsj_2365.mrg
#   inflating: wsj/23/wsj_2377.mrg
#   inflating: wsj/23/wsj_2307.mrg
#   inflating: wsj/23/wsj_2354.mrg
#   inflating: wsj/23/wsj_2332.mrg
#   inflating: wsj/23/wsj_2316.mrg
#   inflating: wsj/23/wsj_2384.mrg
#   inflating: wsj/23/wsj_2314.mrg
#   inflating: wsj/23/wsj_2376.mrg
#   inflating: wsj/23/wsj_2364.mrg
#   inflating: wsj/23/wsj_2327.mrg
#   inflating: wsj/23/wsj_2353.mrg
#   inflating: wsj/23/wsj_2348.mrg
#   inflating: wsj/23/wsj_2304.mrg
#   inflating: wsj/23/wsj_2339.mrg
#   inflating: wsj/23/wsj_2368.mrg
#   inflating: wsj/23/wsj_2382.mrg
#   inflating: wsj/23/wsj_2317.mrg
#   inflating: wsj/23/wsj_2340.mrg
#   inflating: wsj/23/wsj_2370.mrg
#   inflating: wsj/23/wsj_2318.mrg
#   inflating: wsj/23/wsj_2355.mrg
#   inflating: wsj/23/wsj_2385.mrg
#   inflating: wsj/23/wsj_2328.mrg
#   inflating: wsj/23/wsj_2391.mrg
#   inflating: wsj/23/wsj_2362.mrg
#   inflating: wsj/23/wsj_2367.mrg
#   inflating: wsj/23/wsj_2399.mrg
#   inflating: wsj/23/wsj_2381.mrg
#   inflating: wsj/23/wsj_2395.mrg
#   inflating: wsj/23/wsj_2335.mrg
#   inflating: wsj/23/wsj_2351.mrg
#   inflating: wsj/23/wsj_2378.mrg
#   inflating: wsj/23/wsj_2358.mrg
#   inflating: wsj/23/wsj_2363.mrg
#   inflating: wsj/23/wsj_2323.mrg
#   inflating: wsj/23/wsj_2347.mrg
#   inflating: wsj/23/wsj_2369.mrg
#   inflating: wsj/23/wsj_2322.mrg
#   inflating: wsj/23/wsj_2315.mrg
#   inflating: wsj/23/wsj_2386.mrg
#   inflating: wsj/23/wsj_2329.mrg
#   inflating: wsj/23/wsj_2311.mrg
#   inflating: wsj/23/wsj_2344.mrg
#   inflating: wsj/23/wsj_2325.mrg
#   inflating: wsj/23/wsj_2380.mrg
#   inflating: wsj/23/wsj_2302.mrg
#   inflating: wsj/23/wsj_2387.mrg
#   inflating: wsj/23/wsj_2331.mrg
#   inflating: wsj/23/wsj_2336.mrg
#   inflating: wsj/23/wsj_2397.mrg
#   inflating: wsj/23/wsj_2366.mrg
#   inflating: wsj/23/wsj_2392.mrg
#   inflating: wsj/23/wsj_2372.mrg
#    creating: wsj/21/
#   inflating: wsj/21/wsj_2138.mrg
#   inflating: wsj/21/wsj_2102.mrg
#   inflating: wsj/21/wsj_2172.mrg
#   inflating: wsj/21/wsj_2164.mrg
#   inflating: wsj/21/wsj_2109.mrg
#   inflating: wsj/21/wsj_2154.mrg
#   inflating: wsj/21/wsj_2161.mrg
#   inflating: wsj/21/wsj_2150.mrg
#   inflating: wsj/21/wsj_2169.mrg
#   inflating: wsj/21/wsj_2158.mrg
#   inflating: wsj/21/wsj_2136.mrg
#   inflating: wsj/21/wsj_2116.mrg
#   inflating: wsj/21/wsj_2100.mrg
#   inflating: wsj/21/wsj_2145.mrg
#   inflating: wsj/21/wsj_2165.mrg
#   inflating: wsj/21/wsj_2149.mrg
#   inflating: wsj/21/wsj_2167.mrg
#   inflating: wsj/21/wsj_2144.mrg
#   inflating: wsj/21/wsj_2153.mrg
#   inflating: wsj/21/wsj_2139.mrg
#   inflating: wsj/21/wsj_2127.mrg
#   inflating: wsj/21/wsj_2168.mrg
#   inflating: wsj/21/wsj_2160.mrg
#   inflating: wsj/21/wsj_2114.mrg
#   inflating: wsj/21/wsj_2119.mrg
#   inflating: wsj/21/wsj_2133.mrg
#   inflating: wsj/21/wsj_2135.mrg
#   inflating: wsj/21/wsj_2152.mrg
#   inflating: wsj/21/wsj_2130.mrg
#   inflating: wsj/21/wsj_2129.mrg
#   inflating: wsj/21/wsj_2115.mrg
#   inflating: wsj/21/wsj_2101.mrg
#   inflating: wsj/21/wsj_2126.mrg
#   inflating: wsj/21/wsj_2123.mrg
#   inflating: wsj/21/wsj_2134.mrg
#   inflating: wsj/21/wsj_2159.mrg
#   inflating: wsj/21/wsj_2110.mrg
#   inflating: wsj/21/wsj_2111.mrg
#   inflating: wsj/21/wsj_2156.mrg
#   inflating: wsj/21/wsj_2151.mrg
#   inflating: wsj/21/wsj_2146.mrg
#   inflating: wsj/21/wsj_2105.mrg
#   inflating: wsj/21/wsj_2125.mrg
#   inflating: wsj/21/wsj_2107.mrg
#   inflating: wsj/21/wsj_2166.mrg
#   inflating: wsj/21/wsj_2131.mrg
#   inflating: wsj/21/wsj_2120.mrg
#   inflating: wsj/21/wsj_2112.mrg
#   inflating: wsj/21/wsj_2132.mrg
#   inflating: wsj/21/wsj_2148.mrg
#   inflating: wsj/21/wsj_2117.mrg
#   inflating: wsj/21/wsj_2103.mrg
#   inflating: wsj/21/wsj_2106.mrg
#   inflating: wsj/21/wsj_2157.mrg
#   inflating: wsj/21/wsj_2141.mrg
#   inflating: wsj/21/wsj_2163.mrg
#   inflating: wsj/21/wsj_2104.mrg
#   inflating: wsj/21/wsj_2162.mrg
#   inflating: wsj/21/wsj_2142.mrg
#   inflating: wsj/21/wsj_2122.mrg
#   inflating: wsj/21/wsj_2155.mrg
#   inflating: wsj/21/wsj_2170.mrg
#   inflating: wsj/21/wsj_2118.mrg
#   inflating: wsj/21/wsj_2143.mrg
#   inflating: wsj/21/wsj_2128.mrg
#   inflating: wsj/21/wsj_2137.mrg
#   inflating: wsj/21/wsj_2121.mrg
#   inflating: wsj/21/wsj_2171.mrg
#   inflating: wsj/21/wsj_2124.mrg
#   inflating: wsj/21/wsj_2147.mrg
#   inflating: wsj/21/wsj_2108.mrg
#   inflating: wsj/21/wsj_2113.mrg
#   inflating: wsj/21/wsj_2140.mrg
#   inflating: wsj/MERGE.LOG
#    creating: wsj/06/
#   inflating: wsj/06/wsj_0695.mrg
#   inflating: wsj/06/wsj_0652.mrg
#   inflating: wsj/06/wsj_0654.mrg
#   inflating: wsj/06/wsj_0688.mrg
#   inflating: wsj/06/wsj_0610.mrg
#   inflating: wsj/06/wsj_0673.mrg
#   inflating: wsj/06/wsj_0651.mrg
#   inflating: wsj/06/wsj_0648.mrg
#   inflating: wsj/06/wsj_0644.mrg
#   inflating: wsj/06/wsj_0699.mrg
#   inflating: wsj/06/wsj_0693.mrg
#   inflating: wsj/06/wsj_0626.mrg
#   inflating: wsj/06/wsj_0679.mrg
#   inflating: wsj/06/wsj_0641.mrg
#   inflating: wsj/06/wsj_0647.mrg
#   inflating: wsj/06/wsj_0620.mrg
#   inflating: wsj/06/wsj_0631.mrg
#   inflating: wsj/06/wsj_0687.mrg
#   inflating: wsj/06/wsj_0692.mrg
#   inflating: wsj/06/wsj_0624.mrg
#   inflating: wsj/06/wsj_0683.mrg
#   inflating: wsj/06/wsj_0630.mrg
#   inflating: wsj/06/wsj_0614.mrg
#   inflating: wsj/06/wsj_0675.mrg
#   inflating: wsj/06/wsj_0659.mrg
#   inflating: wsj/06/wsj_0618.mrg
#   inflating: wsj/06/wsj_0686.mrg
#   inflating: wsj/06/wsj_0637.mrg
#   inflating: wsj/06/wsj_0621.mrg
#   inflating: wsj/06/wsj_0691.mrg
#   inflating: wsj/06/wsj_0605.mrg
#   inflating: wsj/06/wsj_0634.mrg
#   inflating: wsj/06/wsj_0612.mrg
#   inflating: wsj/06/wsj_0632.mrg
#   inflating: wsj/06/wsj_0680.mrg
#   inflating: wsj/06/wsj_0696.mrg
#   inflating: wsj/06/wsj_0698.mrg
#   inflating: wsj/06/wsj_0611.mrg
#   inflating: wsj/06/wsj_0672.mrg
#   inflating: wsj/06/wsj_0640.mrg
#   inflating: wsj/06/wsj_0667.mrg
#   inflating: wsj/06/wsj_0617.mrg
#   inflating: wsj/06/wsj_0629.mrg
#   inflating: wsj/06/wsj_0653.mrg
#   inflating: wsj/06/wsj_0681.mrg
#   inflating: wsj/06/wsj_0669.mrg
#   inflating: wsj/06/wsj_0628.mrg
#   inflating: wsj/06/wsj_0602.mrg
#   inflating: wsj/06/wsj_0694.mrg
#   inflating: wsj/06/wsj_0677.mrg
#   inflating: wsj/06/wsj_0684.mrg
#   inflating: wsj/06/wsj_0689.mrg
#   inflating: wsj/06/wsj_0690.mrg
#   inflating: wsj/06/wsj_0639.mrg
#   inflating: wsj/06/wsj_0649.mrg
#   inflating: wsj/06/wsj_0645.mrg
#   inflating: wsj/06/wsj_0604.mrg
#   inflating: wsj/06/wsj_0666.mrg
#   inflating: wsj/06/wsj_0638.mrg
#   inflating: wsj/06/wsj_0657.mrg
#   inflating: wsj/06/wsj_0665.mrg
#   inflating: wsj/06/wsj_0650.mrg
#   inflating: wsj/06/wsj_0660.mrg
#   inflating: wsj/06/wsj_0670.mrg
#   inflating: wsj/06/wsj_0627.mrg
#   inflating: wsj/06/wsj_0682.mrg
#   inflating: wsj/06/wsj_0671.mrg
#   inflating: wsj/06/wsj_0635.mrg
#   inflating: wsj/06/wsj_0646.mrg
#   inflating: wsj/06/wsj_0600.mrg
#   inflating: wsj/06/wsj_0674.mrg
#   inflating: wsj/06/wsj_0607.mrg
#   inflating: wsj/06/wsj_0619.mrg
#   inflating: wsj/06/wsj_0608.mrg
#   inflating: wsj/06/wsj_0655.mrg
#   inflating: wsj/06/wsj_0606.mrg
#   inflating: wsj/06/wsj_0643.mrg
#   inflating: wsj/06/wsj_0603.mrg
#   inflating: wsj/06/wsj_0697.mrg
#   inflating: wsj/06/wsj_0601.mrg
#   inflating: wsj/06/wsj_0662.mrg
#   inflating: wsj/06/wsj_0636.mrg
#   inflating: wsj/06/wsj_0663.mrg
#   inflating: wsj/06/wsj_0664.mrg
#   inflating: wsj/06/wsj_0678.mrg
#   inflating: wsj/06/wsj_0625.mrg
#   inflating: wsj/06/wsj_0616.mrg
#   inflating: wsj/06/wsj_0668.mrg
#   inflating: wsj/06/wsj_0613.mrg
#   inflating: wsj/06/wsj_0656.mrg
#   inflating: wsj/06/wsj_0633.mrg
#   inflating: wsj/06/wsj_0676.mrg
#   inflating: wsj/06/wsj_0642.mrg
#   inflating: wsj/06/wsj_0658.mrg
#   inflating: wsj/06/wsj_0623.mrg
#   inflating: wsj/06/wsj_0609.mrg
#   inflating: wsj/06/wsj_0615.mrg
#   inflating: wsj/06/wsj_0685.mrg
#   inflating: wsj/06/wsj_0661.mrg
#   inflating: wsj/06/wsj_0622.mrg
#    creating: wsj/03/
#   inflating: wsj/03/wsj_0365.mrg
#   inflating: wsj/03/wsj_0315.mrg
#   inflating: wsj/03/wsj_0326.mrg
#   inflating: wsj/03/wsj_0327.mrg
#   inflating: wsj/03/wsj_0346.mrg
#   inflating: wsj/03/wsj_0357.mrg
#   inflating: wsj/03/wsj_0304.mrg
#   inflating: wsj/03/wsj_0368.mrg
#   inflating: wsj/03/wsj_0370.mrg
#   inflating: wsj/03/wsj_0375.mrg
#   inflating: wsj/03/wsj_0301.mrg
#   inflating: wsj/03/wsj_0310.mrg
#   inflating: wsj/03/wsj_0339.mrg
#   inflating: wsj/03/wsj_0363.mrg
#   inflating: wsj/03/wsj_0318.mrg
#   inflating: wsj/03/wsj_0364.mrg
#   inflating: wsj/03/wsj_0359.mrg
#   inflating: wsj/03/wsj_0348.mrg
#   inflating: wsj/03/wsj_0334.mrg
#   inflating: wsj/03/wsj_0367.mrg
#   inflating: wsj/03/wsj_0372.mrg
#   inflating: wsj/03/wsj_0321.mrg
#   inflating: wsj/03/wsj_0313.mrg
#   inflating: wsj/03/wsj_0341.mrg
#   inflating: wsj/03/wsj_0347.mrg
#   inflating: wsj/03/wsj_0335.mrg
#   inflating: wsj/03/wsj_0354.mrg
#   inflating: wsj/03/wsj_0379.mrg
#   inflating: wsj/03/wsj_0376.mrg
#   inflating: wsj/03/wsj_0302.mrg
#   inflating: wsj/03/wsj_0345.mrg
#   inflating: wsj/03/wsj_0373.mrg
#   inflating: wsj/03/wsj_0317.mrg
#   inflating: wsj/03/wsj_0349.mrg
#   inflating: wsj/03/wsj_0330.mrg
#   inflating: wsj/03/wsj_0356.mrg
#   inflating: wsj/03/wsj_0305.mrg
#   inflating: wsj/03/wsj_0319.mrg
#   inflating: wsj/03/wsj_0362.mrg
#   inflating: wsj/03/wsj_0329.mrg
#   inflating: wsj/03/wsj_0366.mrg
#   inflating: wsj/03/wsj_0311.mrg
#   inflating: wsj/03/wsj_0374.mrg
#   inflating: wsj/03/wsj_0360.mrg
#   inflating: wsj/03/wsj_0308.mrg
#   inflating: wsj/03/wsj_0351.mrg
#   inflating: wsj/03/wsj_0380.mrg
#   inflating: wsj/03/wsj_0353.mrg
#   inflating: wsj/03/wsj_0377.mrg
#   inflating: wsj/03/wsj_0371.mrg
#   inflating: wsj/03/wsj_0307.mrg
#   inflating: wsj/03/wsj_0342.mrg
#   inflating: wsj/03/wsj_0358.mrg
#   inflating: wsj/03/wsj_0314.mrg
#   inflating: wsj/03/wsj_0369.mrg
#   inflating: wsj/03/wsj_0336.mrg
#   inflating: wsj/03/wsj_0378.mrg
#   inflating: wsj/03/wsj_0337.mrg
#   inflating: wsj/03/wsj_0323.mrg
#   inflating: wsj/03/wsj_0320.mrg
#   inflating: wsj/03/wsj_0300.mrg
#   inflating: wsj/03/wsj_0328.mrg
#   inflating: wsj/03/wsj_0309.mrg
#   inflating: wsj/03/wsj_0352.mrg
#   inflating: wsj/03/wsj_0324.mrg
#   inflating: wsj/03/wsj_0325.mrg
#   inflating: wsj/03/wsj_0331.mrg
#   inflating: wsj/03/wsj_0316.mrg
#   inflating: wsj/03/wsj_0306.mrg
#   inflating: wsj/03/wsj_0322.mrg
#   inflating: wsj/03/wsj_0340.mrg
#   inflating: wsj/03/wsj_0343.mrg
#   inflating: wsj/03/wsj_0350.mrg
#   inflating: wsj/03/wsj_0332.mrg
#   inflating: wsj/03/wsj_0333.mrg
#   inflating: wsj/03/wsj_0303.mrg
#   inflating: wsj/03/wsj_0338.mrg
#   inflating: wsj/03/wsj_0355.mrg
#   inflating: wsj/03/wsj_0344.mrg
#   inflating: wsj/03/wsj_0312.mrg
#   inflating: wsj/03/wsj_0361.mrg
#    creating: wsj/09/
#   inflating: wsj/09/wsj_0977.mrg
#   inflating: wsj/09/wsj_0914.mrg
#   inflating: wsj/09/wsj_0931.mrg
#   inflating: wsj/09/wsj_0900.mrg
#   inflating: wsj/09/wsj_0906.mrg
#   inflating: wsj/09/wsj_0945.mrg
#   inflating: wsj/09/wsj_0908.mrg
#   inflating: wsj/09/wsj_0990.mrg
#   inflating: wsj/09/wsj_0992.mrg
#   inflating: wsj/09/wsj_0975.mrg
#   inflating: wsj/09/wsj_0933.mrg
#   inflating: wsj/09/wsj_0962.mrg
#   inflating: wsj/09/wsj_0954.mrg
#   inflating: wsj/09/wsj_0922.mrg
#   inflating: wsj/09/wsj_0956.mrg
#   inflating: wsj/09/wsj_0915.mrg
#   inflating: wsj/09/wsj_0959.mrg
#   inflating: wsj/09/wsj_0904.mrg
#   inflating: wsj/09/wsj_0974.mrg
#   inflating: wsj/09/wsj_0982.mrg
#   inflating: wsj/09/wsj_0911.mrg
#   inflating: wsj/09/wsj_0939.mrg
#   inflating: wsj/09/wsj_0998.mrg
#   inflating: wsj/09/wsj_0936.mrg
#   inflating: wsj/09/wsj_0995.mrg
#   inflating: wsj/09/wsj_0985.mrg
#   inflating: wsj/09/wsj_0968.mrg
#   inflating: wsj/09/wsj_0932.mrg
#   inflating: wsj/09/wsj_0909.mrg
#   inflating: wsj/09/wsj_0960.mrg
#   inflating: wsj/09/wsj_0907.mrg
#   inflating: wsj/09/wsj_0905.mrg
#   inflating: wsj/09/wsj_0972.mrg
#   inflating: wsj/09/wsj_0951.mrg
#   inflating: wsj/09/wsj_0981.mrg
#   inflating: wsj/09/wsj_0996.mrg
#   inflating: wsj/09/wsj_0970.mrg
#   inflating: wsj/09/wsj_0913.mrg
#   inflating: wsj/09/wsj_0965.mrg
#   inflating: wsj/09/wsj_0980.mrg
#   inflating: wsj/09/wsj_0976.mrg
#   inflating: wsj/09/wsj_0920.mrg
#   inflating: wsj/09/wsj_0918.mrg
#   inflating: wsj/09/wsj_0989.mrg
#   inflating: wsj/09/wsj_0961.mrg
#   inflating: wsj/09/wsj_0942.mrg
#   inflating: wsj/09/wsj_0943.mrg
#   inflating: wsj/09/wsj_0948.mrg
#   inflating: wsj/09/wsj_0916.mrg
#   inflating: wsj/09/wsj_0941.mrg
#   inflating: wsj/09/wsj_0966.mrg
#   inflating: wsj/09/wsj_0997.mrg
#   inflating: wsj/09/wsj_0994.mrg
#   inflating: wsj/09/wsj_0930.mrg
#   inflating: wsj/09/wsj_0903.mrg
#   inflating: wsj/09/wsj_0946.mrg
#   inflating: wsj/09/wsj_0964.mrg
#   inflating: wsj/09/wsj_0901.mrg
#   inflating: wsj/09/wsj_0999.mrg
#   inflating: wsj/09/wsj_0950.mrg
#   inflating: wsj/09/wsj_0952.mrg
#   inflating: wsj/09/wsj_0971.mrg
#   inflating: wsj/09/wsj_0958.mrg
#   inflating: wsj/09/wsj_0973.mrg
#   inflating: wsj/09/wsj_0978.mrg
#   inflating: wsj/09/wsj_0926.mrg
#   inflating: wsj/09/wsj_0938.mrg
#   inflating: wsj/09/wsj_0967.mrg
#   inflating: wsj/09/wsj_0979.mrg
#   inflating: wsj/09/wsj_0934.mrg
#   inflating: wsj/09/wsj_0921.mrg
#   inflating: wsj/09/wsj_0912.mrg
#   inflating: wsj/09/wsj_0987.mrg
#   inflating: wsj/09/wsj_0986.mrg
#   inflating: wsj/09/wsj_0991.mrg
#   inflating: wsj/09/wsj_0935.mrg
#   inflating: wsj/09/wsj_0993.mrg
#   inflating: wsj/09/wsj_0949.mrg
#   inflating: wsj/09/wsj_0902.mrg
#   inflating: wsj/09/wsj_0988.mrg
#   inflating: wsj/09/wsj_0919.mrg
#   inflating: wsj/09/wsj_0957.mrg
#   inflating: wsj/09/wsj_0984.mrg
#   inflating: wsj/09/wsj_0955.mrg
#   inflating: wsj/09/wsj_0924.mrg
#   inflating: wsj/09/wsj_0937.mrg
#   inflating: wsj/09/wsj_0983.mrg
#   inflating: wsj/09/wsj_0953.mrg
#   inflating: wsj/09/wsj_0963.mrg
#   inflating: wsj/09/wsj_0947.mrg
#   inflating: wsj/09/wsj_0944.mrg
#   inflating: wsj/09/wsj_0917.mrg
#   inflating: wsj/09/wsj_0925.mrg
#   inflating: wsj/09/wsj_0929.mrg
#   inflating: wsj/09/wsj_0969.mrg
#   inflating: wsj/09/wsj_0910.mrg
#   inflating: wsj/09/wsj_0927.mrg
#   inflating: wsj/09/wsj_0928.mrg
#   inflating: wsj/09/wsj_0940.mrg
#   inflating: wsj/09/wsj_0923.mrg

# %%
def parse_trees(file_path):
    with open(file_path, "r") as file:
        data = file.read()

    trees = []
    current_tree = []
    open_parens = 0

    for line in data.splitlines():
        line = line.strip()
        if not line:
            continue

        current_tree.append(line)
        open_parens += line.count("(") - line.count(")")

        # If open_parens reaches zero, we've completed a tree
        if open_parens == 0:
            tree_string = " ".join(current_tree)
            trees.append(tree_string)
            current_tree = []

    return trees

# %%
# wsj/00-18 is the train set
# wsj/19-21 is the dev set
# wsj/22-24 is the test set

# separate the trees into train, dev, and test sets

def collect_trees(range_limits, target_list):
    for i in range(*range_limits):
        directory = f"wsj/{i:02}"
        files = os.listdir(directory)
        for file in files:
            target_list.extend(parse_trees(f"{directory}/{file}"))

# Initialize tree lists
train_trees, validation_trees, test_trees = [], [], []

# Collect trees for train, validation, and test sets
collect_trees((0, 19), train_trees)
collect_trees((19, 22), validation_trees)
collect_trees((22, 25), test_trees)

# Print the number of trees in each set
print(f"Number of training trees: {len(train_trees)}")
print(f"Number of validation trees: {len(validation_trees)}")
print(f"Number of test trees: {len(test_trees)}")
# Out:
# Number of training trees: 38219
# Number of validation trees: 5527
# Number of test trees: 5462

# %%
print(Tree.fromstring(train_trees[0]))
# Out:
# (
#   (S
#     (NP-SBJ
#       (NP (JJ Japanese))
#       (NN investment)
#       (PP-LOC (IN in) (NP (NNP Southeast) (NNP Asia))))
#     (VP
#       (VBZ is)
#       (VP
#         (VBG propelling)
#         (NP (DT the) (NN region))
#         (PP-DIR-CLR (IN toward) (NP (JJ economic) (NN integration)))))
#     (. .)))

# %%
train = [Tree.fromstring(tree).pos() for tree in train_trees]
val = [Tree.fromstring(tree).pos() for tree in validation_trees]
test = [Tree.fromstring(tree).pos() for tree in test_trees]

# %%
# Example for the first tree in the training set
print(train[0])
# Out:
# [('Japanese', 'JJ'), ('investment', 'NN'), ('in', 'IN'), ('Southeast', 'NNP'), ('Asia', 'NNP'), ('is', 'VBZ'), ('propelling', 'VBG'), ('the', 'DT'), ('region', 'NN'), ('toward', 'IN'), ('economic', 'JJ'), ('integration', 'NN'), ('.', '.')]

# %%
# Processing Tags
tags = set()
for tree in train:
    for _, tag in tree:
        tags.add(tag)
tags = ",".join(sorted(tags))
tags = tags.split(",")
tags = ["<pad>"] + tags
# tag2idx = {tag: idx for idx, tag in enumerate(tags)}
# idx2tag = {idx: tag for idx, tag in enumerate(tags)}
# Update tag2idx and idx2tag
tag2idx = {tag: idx for idx, tag in enumerate(tags)}
tag2idx['<pad>'] = tag2idx.pop('<pad>')
tag2idx['X'] = len(tag2idx)

idx2tag = {idx: tag for idx, tag in enumerate(tags)}
print(tags)
# Out:
# ['<pad>', '#', '$', "''", '', '', '-LRB-', '-NONE-', '-RRB-', '.', ':', 'CC', 'CD', 'DT', 'EX', 'FW', 'IN', 'JJ', 'JJR', 'JJS', 'LS', 'MD', 'NN', 'NNP', 'NNPS', 'NNS', 'PDT', 'POS', 'PRP', 'PRP$', 'RB', 'RBR', 'RBS', 'RP', 'SYM', 'TO', 'UH', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'WDT', 'WP', 'WP$', 'WRB', '``']

# %%
MAX_LEN = 128

# %%
def trees_to_tokens_labels(trees):
    tokens_list = []
    labels_list = []

    for tree in trees:
        tokens = []
        labels = []
        for token, label in tree:
            tokens.append(token)
            labels.append(label)
        tokens_list.append(tokens)
        labels_list.append(labels)

    return tokens_list, labels_list

train_tokens, train_labels = trees_to_tokens_labels(train)
val_tokens, val_labels = trees_to_tokens_labels(val)
test_tokens, test_labels = trees_to_tokens_labels(test)

print(f"Number of training sentences: {len(train_tokens)}")
print(f"Number of validation sentences: {len(val_tokens)}")
print(f"Number of test sentences: {len(test_tokens)}")
# Out:
# Number of training sentences: 38219
# Number of validation sentences: 5527
# Number of test sentences: 5462

# %%
def tokenize_and_align_labels(tokens_list, labels_list, tokenizer, max_len):
    input_ids = []
    attention_masks = []
    label_ids = []

    for tokens, labels in zip(tokens_list, labels_list):
        tokens_enc = []
        label_enc = []

        tokens_enc.append("[CLS]")
        label_enc.append(tag2idx['<pad>'])

        for token, label in zip(tokens, labels):
            sub_tokens = tokenizer.tokenize(token)
            if not sub_tokens:
                sub_tokens = ['[UNK]']
            tokens_enc.extend(sub_tokens)
            label_enc.append(tag2idx.get(label, tag2idx['<pad>']))
            for _ in sub_tokens[1:]:
                label_enc.append(tag2idx['X'])

        tokens_enc.append("[SEP]")
        label_enc.append(tag2idx['<pad>'])

        input_id = tokenizer.convert_tokens_to_ids(tokens_enc)
        attention_mask = [1] * len(input_id)

        # Trunc
        if len(input_id) > max_len:
            input_id = input_id[:max_len-1] + [tokenizer.convert_tokens_to_ids("[SEP]")]
            attention_mask = attention_mask[:max_len-1] + [1]
            label_enc = label_enc[:max_len-1] + [tag2idx['<pad>']]
        # ideally, we can pad the input
        else:
            padding_length = max_len - len(input_id)
            input_id += [tokenizer.pad_token_id] * padding_length
            attention_mask += [0] * padding_length
            label_enc += [tag2idx['<pad>']] * padding_length

        input_ids.append(input_id)
        attention_masks.append(attention_mask)
        label_ids.append(label_enc)

    return torch.tensor(input_ids), torch.tensor(attention_masks), torch.tensor(label_ids)

# %%
from transformers import BertTokenizer

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-cased', do_lower_case=False)

train_input_ids, train_attention_masks, train_label_ids = tokenize_and_align_labels(
    train_tokens, train_labels, tokenizer, MAX_LEN
)

val_input_ids, val_attention_masks, val_label_ids = tokenize_and_align_labels(
    val_tokens, val_labels, tokenizer, MAX_LEN
)

test_input_ids, test_attention_masks, test_label_ids = tokenize_and_align_labels(
    test_tokens, test_labels, tokenizer, MAX_LEN
)

print(f"Training input IDs shape: {train_input_ids.shape}")
print(f"Validation input IDs shape: {val_input_ids.shape}")
print(f"Test input IDs shape: {test_input_ids.shape}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Training input IDs shape: torch.Size([38219, 128])
# Validation input IDs shape: torch.Size([5527, 128])
# Test input IDs shape: torch.Size([5462, 128])

# %%
class POSDataset(Dataset):
    def __init__(self, input_ids, attention_masks, labels):
        self.input_ids = input_ids
        self.attention_masks = attention_masks
        self.labels = labels

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx]
        }

# Dataset
train_dataset = POSDataset(train_input_ids, train_attention_masks, train_label_ids)
val_dataset = POSDataset(val_input_ids, val_attention_masks, val_label_ids)
test_dataset = POSDataset(test_input_ids, test_attention_masks, test_label_ids)

# DataLoaders
BATCH_SIZE = 16

train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
num_labels = len(tag2idx)

# prtrained BERT model
model = BertForTokenClassification.from_pretrained(
    "bert-base-cased",
    num_labels=num_labels,
    output_attentions=False,
    output_hidden_states=False
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

print(f"Using device: {device}")
# Out:
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using device: cuda

# %%
from transformers import get_linear_schedule_with_warmup

optimizer = optim.AdamW(model.parameters(), lr=3e-5)

epochs = 3
total_steps = len(train_dataloader) * epochs

scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps
)

loss_fn = nn.CrossEntropyLoss(ignore_index=tag2idx['<pad>'])

def train_epoch(model, dataloader, optimizer, scheduler, device, loss_fn):
    model.train()
    total_loss = 0

    for batch in tqdm(dataloader, desc="Training"):
        optimizer.zero_grad()

        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=labels
        )

        loss = outputs.loss
        total_loss += loss.item()

        loss.backward()
        optimizer.step()
        scheduler.step()

    avg_loss = total_loss / len(dataloader)
    return avg_loss

def eval_model(model, dataloader, device, loss_fn):
    model.eval()
    total_loss = 0
    predictions = []
    true_labels = []

    with torch.no_grad():
        for batch in tqdm(dataloader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                labels=labels
            )

            loss = outputs.loss
            total_loss += loss.item()

            logits = outputs.logits
            preds = torch.argmax(logits, dim=2)

            # Move tensors to CPU
            preds = preds.detach().cpu().numpy()
            labels = labels.detach().cpu().numpy()

            predictions.extend(preds)
            true_labels.extend(labels)

    avg_loss = total_loss / len(dataloader)

    return avg_loss, predictions, true_labels

# %%
# !pip install seqeval
# Out:
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.5.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.5.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=0ebb92a3613a8cb20439e347cdb490669ed04ee0cd3618bd2e49580b7df2bc4e
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
from seqeval.metrics import classification_report, f1_score

# %%
for epoch in range(epochs):
    print(f"\n======== Epoch {epoch + 1} / {epochs} ========")
    print("Training...")

    train_loss = train_epoch(model, train_dataloader, optimizer, scheduler, device, loss_fn)
    print(f"Training loss: {train_loss}")

    print("Evaluating...")
    val_loss, val_preds, val_true = eval_model(model, val_dataloader, device, loss_fn)
    print(f"Validation loss: {val_loss}")

    val_preds_labels = []
    val_true_labels = []

    for pred_seq, true_seq in zip(val_preds, val_true):
        pred_labels = []
        true_label = []
        for p, t in zip(pred_seq, true_seq):
            if t != tag2idx['<pad>']:
                pred_labels.append(idx2tag.get(p, "X"))
                true_label.append(idx2tag.get(t, "X"))
        val_preds_labels.append(pred_labels)
        val_true_labels.append(true_label)

    f1 = f1_score(val_true_labels, val_preds_labels)
    print(f"Validation F1 Score: {f1:.4f}")

    print("Classification Report:")
    print(classification_report(val_true_labels, val_preds_labels))
# Out:
# ======== Epoch 1 / 3 ========
# Training...
# Training: 100%|██████████| 2389/2389 [03:14<00:00, 12.27it/s]
# Training loss: 0.048294703268932156
# Evaluating...
# Evaluating: 100%|██████████| 346/346 [00:09<00:00, 37.30it/s]
# Validation loss: 0.01387806895062478
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: JJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: `` seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: IN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NNP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBD seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CD seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NNS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RBR seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBG seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: TO seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: POS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: . seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -NONE- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CC seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRP$ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NNPS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WDT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBZ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PDT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: MD seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: JJS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WRB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: JJR seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: $ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: EX seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RBS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: '' seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: : seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -LRB- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -RRB- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: # seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: FW seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WP$ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: UH seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: LS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# Validation F1 Score: 0.9728
# Classification Report:
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            '       1.00      1.00      1.00       980
#            B       0.94      0.94      0.94      7019
#           BD       0.98      0.98      0.98      4618
#           BG       0.95      0.94      0.94      1951
#           BN       0.91      0.93      0.92      2746
#           BP       0.96      0.97      0.97      1485
#           BR       0.69      0.80      0.74       229
#           BS       0.89      0.80      0.85        51
#           BZ       0.99      0.99      0.99      2814
#            C       1.00      0.99      1.00      3380
#            D       0.99      0.99      0.99      5889
#           DT       0.95      0.97      0.96       609
#            H       1.00      0.08      0.14        13
#            J       0.91      0.93      0.92      7575
#           JR       0.89      0.89      0.89       444
#           JS       0.94      0.97      0.95       262
#            N       0.96      0.95      0.96     24004
#           NP       0.96      0.95      0.96      9947
#          NPS       0.67      0.81      0.74       408
#           NS       0.98      0.99      0.98      7943
#            O       1.00      1.00      1.00      3074
#           OS       0.99      0.99      0.99      1240
#            P       0.85      0.94      0.89       678
#           P$       1.00      1.00      1.00        16
#           RB       1.00      1.00      1.00       270
#           RP       1.00      0.99      0.99      2383
#          RP$       1.00      1.00      1.00      1184
#            S       0.00      0.00      0.00         2
#            T       0.99      0.99      0.99     11219
#            W       0.33      0.18      0.24        11
#            X       0.97      1.00      0.98       118
#           YM       0.00      0.00      0.00         4
#            _       1.00      1.00      1.00     10433
#            `       1.00      1.00      1.00     23495
#
#    micro avg       0.97      0.97      0.97    136494
#    macro avg       0.87      0.85      0.85    136494
# weighted avg       0.97      0.97      0.97    136494
#
#
# ======== Epoch 2 / 3 ========
# Training...
# Training: 100%|██████████| 2389/2389 [03:13<00:00, 12.35it/s]
# Training loss: 0.011554799458501621
# Evaluating...
# Evaluating: 100%|██████████| 346/346 [00:09<00:00, 37.42it/s]
# Validation loss: 0.013202031628858578
# Validation F1 Score: 0.9733
# Classification Report:
#               precision    recall  f1-score   support
#
#            '       1.00      1.00      1.00       980
#            B       0.93      0.94      0.94      7019
#           BD       0.98      0.98      0.98      4618
#           BG       0.94      0.95      0.94      1951
#           BN       0.92      0.92      0.92      2746
#           BP       0.97      0.98      0.97      1485
#           BR       0.70      0.81      0.75       229
#           BS       0.93      0.80      0.86        51
#           BZ       0.99      0.99      0.99      2814
#            C       1.00      0.99      1.00      3380
#            D       0.99      1.00      1.00      5889
#           DT       0.95      0.96      0.96       609
#            H       0.86      0.46      0.60        13
#            J       0.90      0.94      0.92      7575
#           JR       0.90      0.91      0.90       444
#           JS       0.96      0.98      0.97       262
#            N       0.96      0.95      0.96     24004
#           NP       0.96      0.96      0.96      9947
#          NPS       0.65      0.89      0.75       408
#           NS       0.99      0.99      0.99      7943
#            O       1.00      1.00      1.00      3074
#           OS       0.99      0.99      0.99      1240
#            P       0.87      0.93      0.90       678
#           P$       1.00      1.00      1.00        16
#           RB       1.00      1.00      1.00       270
#           RP       1.00      0.99      1.00      2383
#          RP$       1.00      1.00      1.00      1184
#            S       0.00      0.00      0.00         2
#            T       1.00      0.99      0.99     11219
#            W       0.42      0.45      0.43        11
#            X       0.97      0.99      0.98       118
#           YM       0.80      1.00      0.89         4
#            _       1.00      1.00      1.00     10433
#            `       1.00      1.00      1.00     23495
#
#    micro avg       0.97      0.97      0.97    136494
#    macro avg       0.90      0.90      0.90    136494
# weighted avg       0.97      0.97      0.97    136494
#
#
# ======== Epoch 3 / 3 ========
# Training...
# Training: 100%|██████████| 2389/2389 [03:13<00:00, 12.36it/s]
# Training loss: 0.008789662173547649
# Evaluating...
# Evaluating: 100%|██████████| 346/346 [00:09<00:00, 37.54it/s]
# Validation loss: 0.012999179710451019
# Validation F1 Score: 0.9745
# Classification Report:
#               precision    recall  f1-score   support
#
#            '       1.00      1.00      1.00       980
#            B       0.94      0.94      0.94      7019
#           BD       0.98      0.98      0.98      4618
#           BG       0.94      0.95      0.94      1951
#           BN       0.91      0.93      0.92      2746
#           BP       0.97      0.98      0.97      1485
#           BR       0.74      0.79      0.76       229
#           BS       0.93      0.80      0.86        51
#           BZ       0.99      0.99      0.99      2814
#            C       1.00      1.00      1.00      3380
#            D       0.99      1.00      1.00      5889
#           DT       0.95      0.97      0.96       609
#            H       0.88      0.54      0.67        13
#            J       0.91      0.93      0.92      7575
#           JR       0.89      0.93      0.91       444
#           JS       0.96      0.98      0.97       262
#            N       0.96      0.95      0.96     24004
#           NP       0.96      0.96      0.96      9947
#          NPS       0.69      0.83      0.75       408
#           NS       0.99      0.99      0.99      7943
#            O       1.00      1.00      1.00      3074
#           OS       0.99      0.99      0.99      1240
#            P       0.87      0.93      0.90       678
#           P$       1.00      1.00      1.00        16
#           RB       1.00      1.00      1.00       270
#           RP       1.00      1.00      1.00      2383
#          RP$       1.00      1.00      1.00      1184
#            S       0.00      0.00      0.00         2
#            T       1.00      0.99      0.99     11219
#            W       0.38      0.55      0.44        11
#            X       0.97      1.00      0.98       118
#           YM       0.80      1.00      0.89         4
#            _       1.00      1.00      1.00     10433
#            `       1.00      1.00      1.00     23495
#
#    micro avg       0.97      0.98      0.97    136494
#    macro avg       0.90      0.91      0.90    136494
# weighted avg       0.97      0.98      0.97    136494

# %%
# FINAL EVAL ONLY, TEST SET
from itertools import chain
print("\nEvaluating on Test Set...")
test_loss, test_preds, test_true = eval_model(model, test_dataloader, device, loss_fn)
print(f"Test loss: {test_loss}")

test_preds_labels = []
test_true_labels = []

for pred_seq, true_seq in zip(test_preds, test_true):
    pred_labels = []
    true_label = []
    for p, t in zip(pred_seq, true_seq):
        if t != tag2idx['<pad>']:
            pred_labels.append(idx2tag.get(p, "X"))
            true_label.append(idx2tag.get(t, "X"))
    test_preds_labels.append(pred_labels)
    test_true_labels.append(true_label)

test_f1 = f1_score(test_true_labels, test_preds_labels)
print(f"Test F1 Score: {test_f1:.4f}")

# Print test accuracy

# Flatten the predicted and true label lists
flat_test_preds_labels = list(chain.from_iterable(test_preds_labels))
flat_test_true_labels = list(chain.from_iterable(test_true_labels))

# Compute accuracy
test_acc = (np.array(flat_test_preds_labels) == np.array(flat_test_true_labels)).mean()
print(f"Test Accuracy: {test_acc :.4f}")

print("Test Classification Report:")
print(classification_report(test_true_labels, test_preds_labels))
# Out:
# Evaluating on Test Set...
# Evaluating: 100%|██████████| 342/342 [00:09<00:00, 37.27it/s]
# Test loss: 0.012540405189648423
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: `` seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBD seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: IN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NNP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NNS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: JJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -NONE- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CC seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: . seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CD seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBG seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: POS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RBR seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRP$ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: $ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: '' seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: TO seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: JJR seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: MD seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBZ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WDT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WRB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: : seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: JJS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NNPS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: EX seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: LS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RBS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WP$ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: UH seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -LRB- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -RRB- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PDT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: # seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: FW seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# Test F1 Score: 0.9738
# Test Accuracy: 0.9831
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            '       1.00      1.00      1.00      1041
#            B       0.94      0.94      0.94      7330
#           BD       0.98      0.97      0.98      4554
#           BG       0.95      0.94      0.94      1930
#           BN       0.90      0.93      0.92      2608
#           BP       0.97      0.99      0.98      1564
#           BR       0.88      0.81      0.84       271
#           BS       0.93      0.91      0.92        69
#           BZ       0.99      0.99      0.99      2639
#            C       1.00      1.00      1.00      3243
#            D       0.99      0.99      0.99      5566
#           DT       0.94      0.97      0.95       628
#            H       0.69      0.73      0.71        15
#            J       0.92      0.93      0.93      7721
#           JR       0.90      0.96      0.93       422
#           JS       0.97      0.97      0.97       267
#            N       0.96      0.96      0.96     23470
#           NP       0.95      0.94      0.95      9571
#          NPS       0.27      0.72      0.40       170
#           NS       0.99      0.99      0.99      7984
#            O       1.00      1.00      1.00      2912
#           OS       0.99      0.99      0.99      1276
#            P       0.89      0.93      0.91       680
#           P$       1.00      1.00      1.00        37
#           RB       1.00      1.00      1.00       304
#           RP       1.00      1.00      1.00      2201
#          RP$       1.00      1.00      1.00      1068
#            S       1.00      0.80      0.89        15
#            T       0.99      0.99      0.99     11147
#            W       0.18      0.12      0.15        24
#            X       0.96      1.00      0.98       126
#           YM       0.91      0.91      0.91        11
#            _       1.00      1.00      1.00     10100
#            `       1.00      1.00      1.00     23050
#
#    micro avg       0.97      0.97      0.97    134014
#    macro avg       0.91      0.92      0.91    134014
# weighted avg       0.97      0.97      0.97    134014
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))

# %%
# Save the model
output_dir = './bert-pos-model/'


# Create the directory if it does not exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Save model weights
torch.save(model.state_dict(), os.path.join(output_dir, "model_weights.pth"))

# Save model config
with open(os.path.join(output_dir, "config.json"), 'w') as f:
    f.write(model.config.to_json_string())

# Save tokenizer
tokenizer.save_pretrained(output_dir)
# Out:
# ('./bert-pos-model/tokenizer_config.json',
#  './bert-pos-model/special_tokens_map.json',
#  './bert-pos-model/vocab.txt',
#  './bert-pos-model/added_tokens.json')

# %%
# TO LOAD THE MODEL LATER!

from transformers import BertForTokenClassification, BertTokenizer, BertConfig
import torch

# Load tokenizer and config
tokenizer = BertTokenizer.from_pretrained('./bert-pos-model/')
config = BertConfig.from_pretrained('./bert-pos-model/config.json')

# Initialize the model
model = BertForTokenClassification(config)

# Load weights
model.load_state_dict(torch.load('./bert-pos-model/model_weights.pth'))
model.eval()  # Set to evaluation mode

print("Model loaded successfully!")

# %% [markdown]
# #### BERT with CRF

# %%
! pip install pytorch-crf
# Out:
# Requirement already satisfied: pytorch-crf in /usr/local/lib/python3.10/dist-packages (0.7.2)

# %%
# INITIAL REFERENCE CODE!
# from torchcrf import CRF


# class BertCRFTagger(nn.Module):

#   def __init__(self, bert, hidden_size, num_tags, dropout):
#     super().__init__()
#     self.bert = bert
#     self.crf = CRF(num_tags, batch_first=True)
#     self.fc = nn.Linear(hidden_size, num_tags)
#     self.dropout = nn.Dropout(dropout)

#   def generate_mask(self, input_temaplte):
#     bs = input_temaplte.size(0)
#     seq_len = torch.max(input_temaplte)
#     mask = torch.ByteTensor(bs, seq_len).fill_(0)
#     for i in range(bs):
#       mask[i, :input_temaplte[i]] = 1
#     return mask

#   def forward(self, input_ids, text_lens, tags=None):
#     bert_output = self.bert(input_ids)
#     last_hidden_state = bert_output['hidden_states'][-1]

#     emission = self.fc(last_hidden_state)
#     mask = self.generate_mask(text_lens).to(device)

#     if tags is not None:
#       loss = -self.crf(torch.log_softmax(emission, dim=2), tags, mask=mask, reduction='mean')
#       return loss
#     else:
#       prediction = self.crf.decode(emission, mask=mask)
#       return prediction

# %%
from torchcrf import CRF


class BertCRFTagger(nn.Module):

  def __init__(self, bert_model_name, hidden_size, num_tags, dropout_rate = 0.1):
    super(BertCRFTagger, self).__init__()
    self.bert = BertModel.from_pretrained(bert_model_name)
    self.dropout = nn.Dropout(dropout_rate)
    self.fc = nn.Linear(hidden_size, num_tags)
    self.crf = CRF(num_tags, batch_first=True)

  def forward(self, input_ids, attention_mask, labels = None):
    # Get BERT embeddings
    outputs = self.bert(input_ids, attention_mask=attention_mask)
    sequence_output = self.dropout(outputs.last_hidden_state)

    # Linear layer for emissions
    emissions = self.fc(sequence_output)

    # If labels are provided, calculate the loss
    if labels is not None:
      mask = attention_mask.bool() # CRF requires a mask
      loss = -self.crf(emissions, labels, mask=mask, reduction='mean')
      return loss

    # If labels are not provided, decode the tags
    else:
      mask = attention_mask.bool()
      predictions = self.crf.decode(emissions, mask=mask)
      return predictions

# %%
# Update model initializations

hidden_size = 768 # Hidden size for BERT-base
num_labels = len(tag2idx)
dropout_rate = 0.1
bert_model_name = 'bert-base-cased'

model = BertCRFTagger(bert_model_name, hidden_size, num_labels, dropout_rate).to(device)

print(f"Using device:{device}")

# Optimizer and scheduler
optimizer = optim.AdamW(model.parameters(), lr=3e-5)
total_steps = len(train_dataloader) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-407536424f11> in <cell line: 4>()
#       2
#       3 hidden_size = 768 # Hidden size for BERT-base
# ----> 4 num_labels = len(tag2idx)
#       5 dropout_rate = 0.1
#       6 bert_model_name = 'bert-base-cased'
#
# NameError: name 'tag2idx' is not defined

# %%
# Update training function - the training function needs to compute loss using the CRF layer now

def train_epoch(model, dataloader, optimizer, scheduler, device):
  model.train()
  total_loss = 0

  for batch in tqdm(dataloader, desc = "Training"):
    optimizer.zero_grad()

    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)
    labels = batch['labels'].to(device)

    # Forward pass
    loss = model(input_ids = input_ids, attention_mask = attention_mask, labels = labels)
    total_loss += loss.item()

    # Backward pass and optimization
    loss.backward()
    optimizer.step()
    scheduler.step()

  avg_loss = total_loss / len(dataloader)
  return avg_loss

# %%
# Update the evaluation function
def eval_model(model, dataloader, device):
  model.eval()
  total_loss = 0
  predictions = []
  true_labels = []

  with torch.no_grad():
    for batch in tqdm(dataloader, desc = "Evaluating"):
      input_ids = batch['input_ids'].to(device)
      attention_mask = batch['attention_mask'].to(device)
      labels = batch['labels'].to(device)

      # Forward pass
      loss = model(input_ids = input_ids, attention_mask = attention_mask, labels = labels)
      total_loss += loss.item()

      # Get predictions
      preds = model(input_ids = input_ids, attention_mask = attention_mask)
      predictions.extend(preds)
      true_labels.extend(labels.detach().cpu().tolist())

  avg_loss = total_loss / len(dataloader)
  return avg_loss, predictions, true_labels

# %%
# train the model
for epoch in range(epochs):
    print(f"\n======== Epoch {epoch + 1} / {epochs} ========")
    print("Training...")

    train_loss = train_epoch(model, train_dataloader, optimizer, scheduler, device)
    print(f"Training loss: {train_loss}")

    print("Evaluating...")
    val_loss, val_preds, val_true = eval_model(model, val_dataloader, device)
    print(f"Validation loss: {val_loss}")

    # # Convert true labels and predictions to tag names
    # val_preds_labels = [[idx2tag[p] for p in seq] for seq in val_preds]
    # val_true_labels = [[idx2tag[t] for t in seq if t != tag2idx['<pad>']] for seq in val_true]

    # f1 = f1_score(val_true_labels, val_preds_labels, average='weighted')
    # print(f"Validation F1 Score: {f1:.4f}")

    # print("Classification Report:")
    # print(classification_report(val_true_labels, val_preds_labels))

    val_preds_labels = []
    val_true_labels = []

    for pred_seq, true_seq in zip(val_preds, val_true):
        filtered_preds = [idx2tag[p] for p, t in zip(pred_seq, true_seq) if t != tag2idx['<pad>']]
        filtered_labels = [idx2tag[t] for t in true_seq if t != tag2idx['<pad>']]

        if len(filtered_preds) == len(filtered_labels):  # Ensure alignment
            val_preds_labels.append(filtered_preds)
            val_true_labels.append(filtered_labels)

    # Compute F1 score
    f1 = f1_score(val_true_labels, val_preds_labels, average='weighted')
    print(f"Validation F1 Score: {f1:.4f}")

    # Classification report
    print("Classification Report:")
    print(classification_report(val_true_labels, val_preds_labels))
# Out:
# ======== Epoch 1 / 3 ========
# Training...
# Training: 100%|██████████| 2389/2389 [08:19<00:00,  4.78it/s]
# Training loss: 3.754462001662017
# Evaluating...
# Evaluating: 100%|██████████| 346/346 [00:38<00:00,  8.88it/s]
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: JJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: `` seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: IN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NNP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBD seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CD seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NNS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RBR seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBG seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: TO seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: POS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: . seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -NONE- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: CC seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PRP$ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: NNPS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WDT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBZ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PDT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: MD seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: VBP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: JJS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WP seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WRB seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: JJR seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: $ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: EX seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: RBS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: '' seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: : seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -LRB- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: -RRB- seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: # seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: FW seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: WP$ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# Validation loss: 1.7037329026040313
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: UH seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: SYM seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: LS seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# Validation F1 Score: 0.9731
# Classification Report:
# /usr/local/lib/python3.10/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            '       1.00      1.00      1.00       980
#            B       0.94      0.94      0.94      7019
#           BD       0.97      0.99      0.98      4618
#           BG       0.94      0.95      0.94      1951
#           BN       0.91      0.92      0.92      2746
#           BP       0.97      0.98      0.97      1485
#           BR       0.72      0.76      0.74       229
#           BS       0.89      0.80      0.85        51
#           BZ       0.99      0.99      0.99      2814
#            C       0.99      1.00      1.00      3380
#            D       0.99      1.00      1.00      5889
#           DT       0.96      0.92      0.94       609
#            H       0.50      0.08      0.13        13
#            J       0.92      0.92      0.92      7575
#           JR       0.88      0.94      0.91       444
#           JS       0.96      0.97      0.96       262
#            N       0.96      0.95      0.96     24004
#           NP       0.96      0.96      0.96      9947
#          NPS       0.69      0.67      0.68       408
#           NS       0.98      0.99      0.99      7943
#            O       1.00      1.00      1.00      3074
#           OS       0.99      1.00      0.99      1240
#            P       0.87      0.93      0.90       678
#           P$       1.00      1.00      1.00        16
#           RB       1.00      1.00      1.00       270
#           RP       1.00      0.99      1.00      2383
#          RP$       1.00      1.00      1.00      1184
#            S       0.00      0.00      0.00         2
#            T       0.99      0.99      0.99     11219
#            W       0.62      0.45      0.53        11
#            X       0.98      1.00      0.99       118
#           YM       0.00      0.00      0.00         4
#            _       1.00      1.00      1.00     10433
#            `       1.00      1.00      1.00     23495
#
#    micro avg       0.97      0.97      0.97    136494
#    macro avg       0.87      0.86      0.86    136494
# weighted avg       0.97      0.97      0.97    136494
#
#
# ======== Epoch 2 / 3 ========
# Training...
# Training: 100%|██████████| 2389/2389 [08:23<00:00,  4.75it/s]
# Training loss: 1.4000765681017289
# Evaluating...
# Evaluating: 100%|██████████| 346/346 [00:38<00:00,  8.88it/s]
# Validation loss: 1.6344475208679377
# Validation F1 Score: 0.9744
# Classification Report:
#               precision    recall  f1-score   support
#
#            '       1.00      1.00      1.00       980
#            B       0.93      0.94      0.94      7019
#           BD       0.97      0.98      0.98      4618
#           BG       0.94      0.94      0.94      1951
#           BN       0.90      0.95      0.92      2746
#           BP       0.97      0.98      0.97      1485
#           BR       0.79      0.72      0.76       229
#           BS       0.91      0.80      0.85        51
#           BZ       0.99      0.99      0.99      2814
#            C       1.00      1.00      1.00      3380
#            D       0.99      1.00      1.00      5889
#           DT       0.95      0.96      0.95       609
#            H       0.78      0.54      0.64        13
#            J       0.93      0.92      0.92      7575
#           JR       0.87      0.95      0.91       444
#           JS       0.96      0.97      0.97       262
#            N       0.96      0.95      0.96     24004
#           NP       0.96      0.96      0.96      9947
#          NPS       0.64      0.88      0.74       408
#           NS       0.98      0.99      0.99      7943
#            O       1.00      1.00      1.00      3074
#           OS       0.99      0.99      0.99      1240
#            P       0.89      0.92      0.90       678
#           P$       1.00      1.00      1.00        16
#           RB       1.00      1.00      1.00       270
#           RP       1.00      0.99      1.00      2383
#          RP$       1.00      1.00      1.00      1184
#            S       0.00      0.00      0.00         2
#            T       1.00      0.99      0.99     11219
#            W       0.50      0.64      0.56        11
#            X       0.97      1.00      0.98       118
#           YM       0.80      1.00      0.89         4
#            _       1.00      1.00      1.00     10433
#            `       1.00      1.00      1.00     23495
#
#    micro avg       0.97      0.97      0.97    136494
#    macro avg       0.90      0.91      0.90    136494
# weighted avg       0.97      0.97      0.97    136494
#
#
# ======== Epoch 3 / 3 ========
# Training...
# Training: 100%|██████████| 2389/2389 [08:21<00:00,  4.77it/s]
# Training loss: 1.0683629369201797
# Evaluating...
# Evaluating: 100%|██████████| 346/346 [00:38<00:00,  8.89it/s]
# Validation loss: 1.6206061357707646
# Validation F1 Score: 0.9749
# Classification Report:
#               precision    recall  f1-score   support
#
#            '       1.00      1.00      1.00       980
#            B       0.94      0.94      0.94      7019
#           BD       0.98      0.98      0.98      4618
#           BG       0.94      0.95      0.94      1951
#           BN       0.92      0.93      0.92      2746
#           BP       0.97      0.98      0.97      1485
#           BR       0.73      0.77      0.75       229
#           BS       0.91      0.80      0.85        51
#           BZ       0.99      0.99      0.99      2814
#            C       1.00      1.00      1.00      3380
#            D       0.99      1.00      1.00      5889
#           DT       0.96      0.97      0.96       609
#            H       0.88      0.54      0.67        13
#            J       0.92      0.93      0.92      7575
#           JR       0.88      0.93      0.90       444
#           JS       0.96      0.97      0.97       262
#            N       0.96      0.95      0.96     24004
#           NP       0.96      0.96      0.96      9947
#          NPS       0.66      0.81      0.73       408
#           NS       0.99      0.99      0.99      7943
#            O       1.00      1.00      1.00      3074
#           OS       0.99      0.99      0.99      1240
#            P       0.87      0.94      0.90       678
#           P$       1.00      1.00      1.00        16
#           RB       1.00      1.00      1.00       270
#           RP       1.00      0.99      1.00      2383
#          RP$       1.00      1.00      1.00      1184
#            S       0.00      0.00      0.00         2
#            T       1.00      0.99      1.00     11219
#            W       0.62      0.73      0.67        11
#            X       0.97      0.99      0.98       118
#           YM       0.80      1.00      0.89         4
#            _       1.00      1.00      1.00     10433
#            `       1.00      1.00      1.00     23495
#
#    micro avg       0.97      0.98      0.97    136494
#    macro avg       0.91      0.91      0.91    136494
# weighted avg       0.97      0.98      0.97    136494

# %%
def evaluate_test_set_with_accuracy(model, dataloader, device, idx2tag, tag2idx):
    model.eval()
    test_preds = []
    test_labels = []

    with torch.no_grad():
        for batch in dataloader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            # CRF Decode
            preds = model(input_ids=input_ids, attention_mask=attention_mask)
            test_preds.extend(preds)  # CRF decode returns a list of lists
            test_labels.extend(labels.cpu().numpy().tolist())  # Convert to list

    # Align predictions and labels
    aligned_preds = []
    aligned_labels = []
    for pred_seq, true_seq in zip(test_preds, test_labels):
        filtered_preds = [idx2tag[p] for p, t in zip(pred_seq, true_seq) if t != tag2idx['<pad>']]
        filtered_labels = [idx2tag[t] for t in true_seq if t != tag2idx['<pad>']]

        if len(filtered_preds) == len(filtered_labels):  # Ensure length match
            aligned_preds.append(filtered_preds)
            aligned_labels.append(filtered_labels)

    # Calculate F1 score
    f1 = f1_score(aligned_labels, aligned_preds, average='weighted')
    print(f"Test F1 Score: {f1:.4f}")

    # Calculate Accuracy
    correct = sum(p == l for preds, labels in zip(aligned_preds, aligned_labels) for p, l in zip(preds, labels))
    total = sum(len(labels) for labels in aligned_labels)
    accuracy = correct / total
    print(f"Test Accuracy: {accuracy:.4f}")

    print("Test Classification Report:")
    print(classification_report(aligned_labels, aligned_preds))

    return aligned_preds, aligned_labels, accuracy

test_preds_labels, test_true_labels, test_accuracy = evaluate_test_set_with_accuracy(
    model=model,
    dataloader=test_dataloader,
    device=device,
    idx2tag=idx2tag,
    tag2idx=tag2idx
)

# %%
# Saving the model

# Directory to save the model
output_dir = './bert-crf-pos-model/'

# Create the directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Save model weights
torch.save(model.state_dict(), os.path.join(output_dir, "model_weights.pth"))

# Save model configuration
with open(os.path.join(output_dir, "config.json"), 'w') as f:
    f.write(model.bert.config.to_json_string())  # Save BERT config

# Save tokenizer
tokenizer.save_pretrained(output_dir)

print(f"Model and related files saved to {output_dir}")
# Out:
# Model and related files saved to ./bert-crf-pos-model/

# %%
# Code to load in the model again

from transformers import BertModel, BertTokenizer
import torch

# Load tokenizer and BERT configuration
tokenizer = BertTokenizer.from_pretrained('./bert-crf-pos-model/')
bert_config = BertModel.from_pretrained('./bert-crf-pos-model/config.json').config

# Reinitialize the model
loaded_model = BertCRFTagger(
    bert_model_name="bert-base-cased",  # Ensure it matches your pretrained BERT
    hidden_size=768,
    num_labels=len(tag2idx),
    dropout_rate=0.1
)

# Load weights
loaded_model.load_state_dict(torch.load('./bert-crf-pos-model/model_weights.pth'))
loaded_model.to(device)

print("Model reloaded successfully!")

# %%
# Example input
input_ids = torch.tensor([[101, 2023, 2003, 1037, 2742, 102]]).to(device)  # Replace with your actual test input
attention_mask = torch.tensor([[1, 1, 1, 1, 1, 1]]).to(device)

# Decode predictions
loaded_model.eval()
with torch.no_grad():
    preds = loaded_model(input_ids=input_ids, attention_mask=attention_mask)

print("Predicted labels:", preds)

# %% [markdown]
# #### BERT + CRF on augmented data

# %%
data_augmentation = False

# %%
# !unzip wsj.zip
# Out:
# Archive:  wsj.zip
#    creating: wsj/
#    creating: wsj/11/
#   inflating: wsj/11/wsj_1138.mrg
#   inflating: wsj/11/wsj_1130.mrg
#   inflating: wsj/11/wsj_1197.mrg
#   inflating: wsj/11/wsj_1178.mrg
#   inflating: wsj/11/wsj_1161.mrg
#   inflating: wsj/11/wsj_1167.mrg
#   inflating: wsj/11/wsj_1175.mrg
#   inflating: wsj/11/wsj_1101.mrg
#   inflating: wsj/11/wsj_1110.mrg
#   inflating: wsj/11/wsj_1119.mrg
#   inflating: wsj/11/wsj_1176.mrg
#   inflating: wsj/11/wsj_1168.mrg
#   inflating: wsj/11/wsj_1174.mrg
#   inflating: wsj/11/wsj_1142.mrg
#   inflating: wsj/11/wsj_1190.mrg
#   inflating: wsj/11/wsj_1170.mrg
#   inflating: wsj/11/wsj_1124.mrg
#   inflating: wsj/11/wsj_1129.mrg
#   inflating: wsj/11/wsj_1154.mrg
#   inflating: wsj/11/wsj_1173.mrg
#   inflating: wsj/11/wsj_1148.mrg
#   inflating: wsj/11/wsj_1135.mrg
#   inflating: wsj/11/wsj_1162.mrg
#   inflating: wsj/11/wsj_1132.mrg
#   inflating: wsj/11/wsj_1181.mrg
#   inflating: wsj/11/wsj_1152.mrg
#   inflating: wsj/11/wsj_1106.mrg
#   inflating: wsj/11/wsj_1194.mrg
#   inflating: wsj/11/wsj_1192.mrg
#   inflating: wsj/11/wsj_1198.mrg
#   inflating: wsj/11/wsj_1107.mrg
#   inflating: wsj/11/wsj_1186.mrg
#   inflating: wsj/11/wsj_1182.mrg
#   inflating: wsj/11/wsj_1105.mrg
#   inflating: wsj/11/wsj_1180.mrg
#   inflating: wsj/11/wsj_1159.mrg
#   inflating: wsj/11/wsj_1191.mrg
#   inflating: wsj/11/wsj_1100.mrg
#   inflating: wsj/11/wsj_1177.mrg
#   inflating: wsj/11/wsj_1183.mrg
#   inflating: wsj/11/wsj_1131.mrg
#   inflating: wsj/11/wsj_1126.mrg
#   inflating: wsj/11/wsj_1185.mrg
#   inflating: wsj/11/wsj_1137.mrg
#   inflating: wsj/11/wsj_1133.mrg
#   inflating: wsj/11/wsj_1165.mrg
#   inflating: wsj/11/wsj_1151.mrg
#   inflating: wsj/11/wsj_1171.mrg
#   inflating: wsj/11/wsj_1116.mrg
#   inflating: wsj/11/wsj_1141.mrg
#   inflating: wsj/11/wsj_1184.mrg
#   inflating: wsj/11/wsj_1112.mrg
#   inflating: wsj/11/wsj_1146.mrg
#   inflating: wsj/11/wsj_1125.mrg
#   inflating: wsj/11/wsj_1172.mrg
#   inflating: wsj/11/wsj_1145.mrg
#   inflating: wsj/11/wsj_1102.mrg
#   inflating: wsj/11/wsj_1179.mrg
#   inflating: wsj/11/wsj_1120.mrg
#   inflating: wsj/11/wsj_1156.mrg
#   inflating: wsj/11/wsj_1128.mrg
#   inflating: wsj/11/wsj_1157.mrg
#   inflating: wsj/11/wsj_1150.mrg
#   inflating: wsj/11/wsj_1158.mrg
#   inflating: wsj/11/wsj_1114.mrg
#   inflating: wsj/11/wsj_1169.mrg
#   inflating: wsj/11/wsj_1164.mrg
#   inflating: wsj/11/wsj_1140.mrg
#   inflating: wsj/11/wsj_1193.mrg
#   inflating: wsj/11/wsj_1189.mrg
#   inflating: wsj/11/wsj_1122.mrg
#   inflating: wsj/11/wsj_1113.mrg
#   inflating: wsj/11/wsj_1139.mrg
#   inflating: wsj/11/wsj_1104.mrg
#   inflating: wsj/11/wsj_1118.mrg
#   inflating: wsj/11/wsj_1160.mrg
#   inflating: wsj/11/wsj_1115.mrg
#   inflating: wsj/11/wsj_1199.mrg
#   inflating: wsj/11/wsj_1123.mrg
#   inflating: wsj/11/wsj_1166.mrg
#   inflating: wsj/11/wsj_1127.mrg
#   inflating: wsj/11/wsj_1103.mrg
#   inflating: wsj/11/wsj_1155.mrg
#   inflating: wsj/11/wsj_1117.mrg
#   inflating: wsj/11/wsj_1109.mrg
#   inflating: wsj/11/wsj_1136.mrg
#   inflating: wsj/11/wsj_1144.mrg
#   inflating: wsj/11/wsj_1153.mrg
#   inflating: wsj/11/wsj_1143.mrg
#   inflating: wsj/11/wsj_1149.mrg
#   inflating: wsj/11/wsj_1195.mrg
#   inflating: wsj/11/wsj_1196.mrg
#   inflating: wsj/11/wsj_1163.mrg
#   inflating: wsj/11/wsj_1108.mrg
#   inflating: wsj/11/wsj_1121.mrg
#   inflating: wsj/11/wsj_1111.mrg
#   inflating: wsj/11/wsj_1147.mrg
#   inflating: wsj/11/wsj_1188.mrg
#   inflating: wsj/11/wsj_1187.mrg
#   inflating: wsj/11/wsj_1134.mrg
#    creating: wsj/07/
#   inflating: wsj/07/wsj_0729.mrg
#   inflating: wsj/07/wsj_0751.mrg
#   inflating: wsj/07/wsj_0749.mrg
#   inflating: wsj/07/wsj_0788.mrg
#   inflating: wsj/07/wsj_0766.mrg
#   inflating: wsj/07/wsj_0746.mrg
#   inflating: wsj/07/wsj_0736.mrg
#   inflating: wsj/07/wsj_0790.mrg
#   inflating: wsj/07/wsj_0739.mrg
#   inflating: wsj/07/wsj_0713.mrg
#   inflating: wsj/07/wsj_0714.mrg
#   inflating: wsj/07/wsj_0789.mrg
#   inflating: wsj/07/wsj_0762.mrg
#   inflating: wsj/07/wsj_0786.mrg
#   inflating: wsj/07/wsj_0708.mrg
#   inflating: wsj/07/wsj_0785.mrg
#   inflating: wsj/07/wsj_0741.mrg
#   inflating: wsj/07/wsj_0765.mrg
#   inflating: wsj/07/wsj_0725.mrg
#   inflating: wsj/07/wsj_0778.mrg
#   inflating: wsj/07/wsj_0721.mrg
#   inflating: wsj/07/wsj_0724.mrg
#   inflating: wsj/07/wsj_0720.mrg
#   inflating: wsj/07/wsj_0792.mrg
#   inflating: wsj/07/wsj_0744.mrg
#   inflating: wsj/07/wsj_0728.mrg
#   inflating: wsj/07/wsj_0753.mrg
#   inflating: wsj/07/wsj_0798.mrg
#   inflating: wsj/07/wsj_0712.mrg
#   inflating: wsj/07/wsj_0759.mrg
#   inflating: wsj/07/wsj_0710.mrg
#   inflating: wsj/07/wsj_0795.mrg
#   inflating: wsj/07/wsj_0752.mrg
#   inflating: wsj/07/wsj_0775.mrg
#   inflating: wsj/07/wsj_0770.mrg
#   inflating: wsj/07/wsj_0771.mrg
#   inflating: wsj/07/wsj_0704.mrg
#   inflating: wsj/07/wsj_0756.mrg
#   inflating: wsj/07/wsj_0715.mrg
#   inflating: wsj/07/wsj_0760.mrg
#   inflating: wsj/07/wsj_0763.mrg
#   inflating: wsj/07/wsj_0707.mrg
#   inflating: wsj/07/wsj_0755.mrg
#   inflating: wsj/07/wsj_0716.mrg
#   inflating: wsj/07/wsj_0754.mrg
#   inflating: wsj/07/wsj_0796.mrg
#   inflating: wsj/07/wsj_0738.mrg
#   inflating: wsj/07/wsj_0747.mrg
#   inflating: wsj/07/wsj_0777.mrg
#   inflating: wsj/07/wsj_0745.mrg
#   inflating: wsj/07/wsj_0705.mrg
#   inflating: wsj/07/wsj_0780.mrg
#   inflating: wsj/07/wsj_0774.mrg
#   inflating: wsj/07/wsj_0711.mrg
#   inflating: wsj/07/wsj_0737.mrg
#   inflating: wsj/07/wsj_0750.mrg
#   inflating: wsj/07/wsj_0700.mrg
#   inflating: wsj/07/wsj_0734.mrg
#   inflating: wsj/07/wsj_0773.mrg
#   inflating: wsj/07/wsj_0703.mrg
#   inflating: wsj/07/wsj_0772.mrg
#   inflating: wsj/07/wsj_0794.mrg
#   inflating: wsj/07/wsj_0791.mrg
#   inflating: wsj/07/wsj_0702.mrg
#   inflating: wsj/07/wsj_0768.mrg
#   inflating: wsj/07/wsj_0781.mrg
#   inflating: wsj/07/wsj_0779.mrg
#   inflating: wsj/07/wsj_0761.mrg
#   inflating: wsj/07/wsj_0730.mrg
#   inflating: wsj/07/wsj_0748.mrg
#   inflating: wsj/07/wsj_0733.mrg
#   inflating: wsj/07/wsj_0727.mrg
#   inflating: wsj/07/wsj_0767.mrg
#   inflating: wsj/07/wsj_0731.mrg
#   inflating: wsj/07/wsj_0719.mrg
#   inflating: wsj/07/wsj_0769.mrg
#   inflating: wsj/07/wsj_0740.mrg
#   inflating: wsj/07/wsj_0722.mrg
#   inflating: wsj/07/wsj_0797.mrg
#   inflating: wsj/07/wsj_0726.mrg
#   inflating: wsj/07/wsj_0764.mrg
#   inflating: wsj/07/wsj_0735.mrg
#   inflating: wsj/07/wsj_0776.mrg
#   inflating: wsj/07/wsj_0758.mrg
#   inflating: wsj/07/wsj_0784.mrg
#   inflating: wsj/07/wsj_0742.mrg
#   inflating: wsj/07/wsj_0757.mrg
#   inflating: wsj/07/wsj_0709.mrg
#   inflating: wsj/07/wsj_0799.mrg
#   inflating: wsj/07/wsj_0718.mrg
#   inflating: wsj/07/wsj_0782.mrg
#   inflating: wsj/07/wsj_0701.mrg
#   inflating: wsj/07/wsj_0723.mrg
#   inflating: wsj/07/wsj_0787.mrg
#   inflating: wsj/07/wsj_0706.mrg
#   inflating: wsj/07/wsj_0793.mrg
#   inflating: wsj/07/wsj_0743.mrg
#   inflating: wsj/07/wsj_0783.mrg
#   inflating: wsj/07/wsj_0717.mrg
#   inflating: wsj/07/wsj_0732.mrg
#    creating: wsj/00/
#   inflating: wsj/00/wsj_0088.mrg
#   inflating: wsj/00/wsj_0047.mrg
#   inflating: wsj/00/wsj_0031.mrg
#   inflating: wsj/00/wsj_0084.mrg
#   inflating: wsj/00/wsj_0028.mrg
#   inflating: wsj/00/wsj_0081.mrg
#   inflating: wsj/00/wsj_0029.mrg
#   inflating: wsj/00/wsj_0069.mrg
#   inflating: wsj/00/wsj_0002.mrg
#   inflating: wsj/00/wsj_0085.mrg
#   inflating: wsj/00/wsj_0006.mrg
#   inflating: wsj/00/wsj_0003.mrg
#   inflating: wsj/00/wsj_0008.mrg
#   inflating: wsj/00/wsj_0059.mrg
#   inflating: wsj/00/wsj_0045.mrg
#   inflating: wsj/00/wsj_0039.mrg
#   inflating: wsj/00/wsj_0078.mrg
#   inflating: wsj/00/wsj_0061.mrg
#   inflating: wsj/00/wsj_0099.mrg
#   inflating: wsj/00/wsj_0080.mrg
#   inflating: wsj/00/wsj_0022.mrg
#   inflating: wsj/00/wsj_0057.mrg
#   inflating: wsj/00/wsj_0071.mrg
#   inflating: wsj/00/wsj_0033.mrg
#   inflating: wsj/00/wsj_0024.mrg
#   inflating: wsj/00/wsj_0014.mrg
#   inflating: wsj/00/wsj_0036.mrg
#   inflating: wsj/00/wsj_0020.mrg
#   inflating: wsj/00/wsj_0089.mrg
#   inflating: wsj/00/wsj_0038.mrg
#   inflating: wsj/00/wsj_0063.mrg
#   inflating: wsj/00/wsj_0013.mrg
#   inflating: wsj/00/wsj_0064.mrg
#   inflating: wsj/00/wsj_0004.mrg
#   inflating: wsj/00/wsj_0035.mrg
#   inflating: wsj/00/wsj_0023.mrg
#   inflating: wsj/00/wsj_0054.mrg
#   inflating: wsj/00/wsj_0067.mrg
#   inflating: wsj/00/wsj_0050.mrg
#   inflating: wsj/00/wsj_0021.mrg
#   inflating: wsj/00/wsj_0026.mrg
#   inflating: wsj/00/wsj_0079.mrg
#   inflating: wsj/00/wsj_0074.mrg
#   inflating: wsj/00/wsj_0072.mrg
#   inflating: wsj/00/wsj_0068.mrg
#   inflating: wsj/00/wsj_0032.mrg
#   inflating: wsj/00/wsj_0046.mrg
#   inflating: wsj/00/wsj_0087.mrg
#   inflating: wsj/00/wsj_0066.mrg
#   inflating: wsj/00/wsj_0017.mrg
#   inflating: wsj/00/wsj_0062.mrg
#   inflating: wsj/00/wsj_0048.mrg
#   inflating: wsj/00/wsj_0043.mrg
#   inflating: wsj/00/wsj_0055.mrg
#   inflating: wsj/00/wsj_0007.mrg
#   inflating: wsj/00/wsj_0096.mrg
#   inflating: wsj/00/wsj_0044.mrg
#   inflating: wsj/00/wsj_0091.mrg
#   inflating: wsj/00/wsj_0009.mrg
#   inflating: wsj/00/wsj_0094.mrg
#   inflating: wsj/00/wsj_0019.mrg
#   inflating: wsj/00/wsj_0041.mrg
#   inflating: wsj/00/wsj_0037.mrg
#   inflating: wsj/00/wsj_0093.mrg
#   inflating: wsj/00/wsj_0095.mrg
#   inflating: wsj/00/wsj_0073.mrg
#   inflating: wsj/00/wsj_0051.mrg
#   inflating: wsj/00/wsj_0065.mrg
#   inflating: wsj/00/wsj_0005.mrg
#   inflating: wsj/00/wsj_0018.mrg
#   inflating: wsj/00/wsj_0075.mrg
#   inflating: wsj/00/wsj_0056.mrg
#   inflating: wsj/00/wsj_0049.mrg
#   inflating: wsj/00/wsj_0097.mrg
#   inflating: wsj/00/wsj_0092.mrg
#   inflating: wsj/00/wsj_0098.mrg
#   inflating: wsj/00/wsj_0052.mrg
#   inflating: wsj/00/wsj_0001.mrg
#   inflating: wsj/00/wsj_0070.mrg
#   inflating: wsj/00/wsj_0082.mrg
#   inflating: wsj/00/wsj_0053.mrg
#   inflating: wsj/00/wsj_0011.mrg
#   inflating: wsj/00/wsj_0010.mrg
#   inflating: wsj/00/wsj_0060.mrg
#   inflating: wsj/00/wsj_0042.mrg
#   inflating: wsj/00/wsj_0027.mrg
#   inflating: wsj/00/wsj_0086.mrg
#   inflating: wsj/00/wsj_0025.mrg
#   inflating: wsj/00/wsj_0030.mrg
#   inflating: wsj/00/wsj_0012.mrg
#   inflating: wsj/00/wsj_0016.mrg
#   inflating: wsj/00/wsj_0083.mrg
#   inflating: wsj/00/wsj_0015.mrg
#   inflating: wsj/00/wsj_0076.mrg
#   inflating: wsj/00/wsj_0058.mrg
#   inflating: wsj/00/wsj_0090.mrg
#   inflating: wsj/00/wsj_0034.mrg
#   inflating: wsj/00/wsj_0040.mrg
#   inflating: wsj/00/wsj_0077.mrg
#    creating: wsj/10/
#   inflating: wsj/10/wsj_1089.mrg
#   inflating: wsj/10/wsj_1046.mrg
#   inflating: wsj/10/wsj_1060.mrg
#   inflating: wsj/10/wsj_1056.mrg
#   inflating: wsj/10/wsj_1004.mrg
#   inflating: wsj/10/wsj_1058.mrg
#   inflating: wsj/10/wsj_1048.mrg
#   inflating: wsj/10/wsj_1095.mrg
#   inflating: wsj/10/wsj_1097.mrg
#   inflating: wsj/10/wsj_1059.mrg
#   inflating: wsj/10/wsj_1065.mrg
#   inflating: wsj/10/wsj_1023.mrg
#   inflating: wsj/10/wsj_1055.mrg
#   inflating: wsj/10/wsj_1042.mrg
#   inflating: wsj/10/wsj_1038.mrg
#   inflating: wsj/10/wsj_1003.mrg
#   inflating: wsj/10/wsj_1002.mrg
#   inflating: wsj/10/wsj_1014.mrg
#   inflating: wsj/10/wsj_1018.mrg
#   inflating: wsj/10/wsj_1036.mrg
#   inflating: wsj/10/wsj_1041.mrg
#   inflating: wsj/10/wsj_1085.mrg
#   inflating: wsj/10/wsj_1032.mrg
#   inflating: wsj/10/wsj_1070.mrg
#   inflating: wsj/10/wsj_1062.mrg
#   inflating: wsj/10/wsj_1076.mrg
#   inflating: wsj/10/wsj_1064.mrg
#   inflating: wsj/10/wsj_1051.mrg
#   inflating: wsj/10/wsj_1017.mrg
#   inflating: wsj/10/wsj_1037.mrg
#   inflating: wsj/10/wsj_1019.mrg
#   inflating: wsj/10/wsj_1044.mrg
#   inflating: wsj/10/wsj_1057.mrg
#   inflating: wsj/10/wsj_1043.mrg
#   inflating: wsj/10/wsj_1096.mrg
#   inflating: wsj/10/wsj_1035.mrg
#   inflating: wsj/10/wsj_1080.mrg
#   inflating: wsj/10/wsj_1092.mrg
#   inflating: wsj/10/wsj_1049.mrg
#   inflating: wsj/10/wsj_1000.mrg
#   inflating: wsj/10/wsj_1013.mrg
#   inflating: wsj/10/wsj_1026.mrg
#   inflating: wsj/10/wsj_1079.mrg
#   inflating: wsj/10/wsj_1083.mrg
#   inflating: wsj/10/wsj_1061.mrg
#   inflating: wsj/10/wsj_1015.mrg
#   inflating: wsj/10/wsj_1021.mrg
#   inflating: wsj/10/wsj_1011.mrg
#   inflating: wsj/10/wsj_1020.mrg
#   inflating: wsj/10/wsj_1053.mrg
#   inflating: wsj/10/wsj_1067.mrg
#   inflating: wsj/10/wsj_1066.mrg
#   inflating: wsj/10/wsj_1030.mrg
#   inflating: wsj/10/wsj_1009.mrg
#   inflating: wsj/10/wsj_1078.mrg
#   inflating: wsj/10/wsj_1077.mrg
#   inflating: wsj/10/wsj_1071.mrg
#   inflating: wsj/10/wsj_1006.mrg
#   inflating: wsj/10/wsj_1045.mrg
#   inflating: wsj/10/wsj_1031.mrg
#   inflating: wsj/10/wsj_1007.mrg
#   inflating: wsj/10/wsj_1090.mrg
#   inflating: wsj/10/wsj_1098.mrg
#   inflating: wsj/10/wsj_1005.mrg
#   inflating: wsj/10/wsj_1075.mrg
#   inflating: wsj/10/wsj_1050.mrg
#   inflating: wsj/10/wsj_1072.mrg
#   inflating: wsj/10/wsj_1029.mrg
#   inflating: wsj/10/wsj_1091.mrg
#   inflating: wsj/10/wsj_1010.mrg
#   inflating: wsj/10/wsj_1001.mrg
#   inflating: wsj/10/wsj_1054.mrg
#   inflating: wsj/10/wsj_1088.mrg
#   inflating: wsj/10/wsj_1069.mrg
#   inflating: wsj/10/wsj_1068.mrg
#   inflating: wsj/10/wsj_1034.mrg
#   inflating: wsj/10/wsj_1081.mrg
#   inflating: wsj/10/wsj_1039.mrg
#   inflating: wsj/10/wsj_1063.mrg
#   inflating: wsj/10/wsj_1084.mrg
#   inflating: wsj/10/wsj_1052.mrg
#   inflating: wsj/10/wsj_1040.mrg
#   inflating: wsj/10/wsj_1016.mrg
#   inflating: wsj/10/wsj_1082.mrg
#   inflating: wsj/10/wsj_1028.mrg
#   inflating: wsj/10/wsj_1094.mrg
#   inflating: wsj/10/wsj_1033.mrg
#   inflating: wsj/10/wsj_1012.mrg
#   inflating: wsj/10/wsj_1024.mrg
#   inflating: wsj/10/wsj_1087.mrg
#   inflating: wsj/10/wsj_1047.mrg
#   inflating: wsj/10/wsj_1022.mrg
#   inflating: wsj/10/wsj_1008.mrg
#   inflating: wsj/10/wsj_1025.mrg
#   inflating: wsj/10/wsj_1027.mrg
#   inflating: wsj/10/wsj_1086.mrg
#   inflating: wsj/10/wsj_1093.mrg
#   inflating: wsj/10/wsj_1073.mrg
#   inflating: wsj/10/wsj_1099.mrg
#   inflating: wsj/10/wsj_1074.mrg
#    creating: wsj/24/
#   inflating: wsj/24/wsj_2417.mrg
#   inflating: wsj/24/wsj_2434.mrg
#   inflating: wsj/24/wsj_2444.mrg
#   inflating: wsj/24/wsj_2402.mrg
#   inflating: wsj/24/wsj_2419.mrg
#   inflating: wsj/24/wsj_2416.mrg
#   inflating: wsj/24/wsj_2400.mrg
#   inflating: wsj/24/wsj_2408.mrg
#   inflating: wsj/24/wsj_2445.mrg
#   inflating: wsj/24/wsj_2414.mrg
#   inflating: wsj/24/wsj_2406.mrg
#   inflating: wsj/24/wsj_2441.mrg
#   inflating: wsj/24/wsj_2418.mrg
#   inflating: wsj/24/wsj_2446.mrg
#   inflating: wsj/24/wsj_2410.mrg
#   inflating: wsj/24/wsj_2404.mrg
#   inflating: wsj/24/wsj_2401.mrg
#   inflating: wsj/24/wsj_2430.mrg
#   inflating: wsj/24/wsj_2453.mrg
#   inflating: wsj/24/wsj_2437.mrg
#   inflating: wsj/24/wsj_2439.mrg
#   inflating: wsj/24/wsj_2423.mrg
#   inflating: wsj/24/wsj_2428.mrg
#   inflating: wsj/24/wsj_2424.mrg
#   inflating: wsj/24/wsj_2440.mrg
#   inflating: wsj/24/wsj_2431.mrg
#   inflating: wsj/24/wsj_2422.mrg
#   inflating: wsj/24/wsj_2429.mrg
#   inflating: wsj/24/wsj_2447.mrg
#   inflating: wsj/24/wsj_2448.mrg
#   inflating: wsj/24/wsj_2421.mrg
#   inflating: wsj/24/wsj_2409.mrg
#   inflating: wsj/24/wsj_2415.mrg
#   inflating: wsj/24/wsj_2452.mrg
#   inflating: wsj/24/wsj_2426.mrg
#   inflating: wsj/24/wsj_2436.mrg
#   inflating: wsj/24/wsj_2433.mrg
#   inflating: wsj/24/wsj_2438.mrg
#   inflating: wsj/24/wsj_2451.mrg
#   inflating: wsj/24/wsj_2407.mrg
#   inflating: wsj/24/wsj_2454.mrg
#   inflating: wsj/24/wsj_2427.mrg
#   inflating: wsj/24/wsj_2450.mrg
#   inflating: wsj/24/wsj_2425.mrg
#   inflating: wsj/24/wsj_2432.mrg
#   inflating: wsj/24/wsj_2412.mrg
#   inflating: wsj/24/wsj_2435.mrg
#   inflating: wsj/24/wsj_2442.mrg
#   inflating: wsj/24/wsj_2403.mrg
#   inflating: wsj/24/wsj_2413.mrg
#   inflating: wsj/24/wsj_2443.mrg
#   inflating: wsj/24/wsj_2420.mrg
#   inflating: wsj/24/wsj_2411.mrg
#   inflating: wsj/24/wsj_2405.mrg
#   inflating: wsj/24/wsj_2449.mrg
#    creating: wsj/01/
#   inflating: wsj/01/wsj_0185.mrg
#   inflating: wsj/01/wsj_0186.mrg
#   inflating: wsj/01/wsj_0193.mrg
#   inflating: wsj/01/wsj_0107.mrg
#   inflating: wsj/01/wsj_0123.mrg
#   inflating: wsj/01/wsj_0121.mrg
#   inflating: wsj/01/wsj_0148.mrg
#   inflating: wsj/01/wsj_0151.mrg
#   inflating: wsj/01/wsj_0173.mrg
#   inflating: wsj/01/wsj_0137.mrg
#   inflating: wsj/01/wsj_0176.mrg
#   inflating: wsj/01/wsj_0110.mrg
#   inflating: wsj/01/wsj_0133.mrg
#   inflating: wsj/01/wsj_0194.mrg
#   inflating: wsj/01/wsj_0120.mrg
#   inflating: wsj/01/wsj_0147.mrg
#   inflating: wsj/01/wsj_0125.mrg
#   inflating: wsj/01/wsj_0153.mrg
#   inflating: wsj/01/wsj_0124.mrg
#   inflating: wsj/01/wsj_0184.mrg
#   inflating: wsj/01/wsj_0179.mrg
#   inflating: wsj/01/wsj_0104.mrg
#   inflating: wsj/01/wsj_0105.mrg
#   inflating: wsj/01/wsj_0113.mrg
#   inflating: wsj/01/wsj_0175.mrg
#   inflating: wsj/01/wsj_0149.mrg
#   inflating: wsj/01/wsj_0119.mrg
#   inflating: wsj/01/wsj_0146.mrg
#   inflating: wsj/01/wsj_0117.mrg
#   inflating: wsj/01/wsj_0163.mrg
#   inflating: wsj/01/wsj_0167.mrg
#   inflating: wsj/01/wsj_0135.mrg
#   inflating: wsj/01/wsj_0191.mrg
#   inflating: wsj/01/wsj_0131.mrg
#   inflating: wsj/01/wsj_0144.mrg
#   inflating: wsj/01/wsj_0156.mrg
#   inflating: wsj/01/wsj_0111.mrg
#   inflating: wsj/01/wsj_0118.mrg
#   inflating: wsj/01/wsj_0140.mrg
#   inflating: wsj/01/wsj_0196.mrg
#   inflating: wsj/01/wsj_0178.mrg
#   inflating: wsj/01/wsj_0152.mrg
#   inflating: wsj/01/wsj_0160.mrg
#   inflating: wsj/01/wsj_0141.mrg
#   inflating: wsj/01/wsj_0136.mrg
#   inflating: wsj/01/wsj_0169.mrg
#   inflating: wsj/01/wsj_0127.mrg
#   inflating: wsj/01/wsj_0155.mrg
#   inflating: wsj/01/wsj_0159.mrg
#   inflating: wsj/01/wsj_0126.mrg
#   inflating: wsj/01/wsj_0101.mrg
#   inflating: wsj/01/wsj_0106.mrg
#   inflating: wsj/01/wsj_0168.mrg
#   inflating: wsj/01/wsj_0112.mrg
#   inflating: wsj/01/wsj_0115.mrg
#   inflating: wsj/01/wsj_0197.mrg
#   inflating: wsj/01/wsj_0192.mrg
#   inflating: wsj/01/wsj_0195.mrg
#   inflating: wsj/01/wsj_0166.mrg
#   inflating: wsj/01/wsj_0143.mrg
#   inflating: wsj/01/wsj_0189.mrg
#   inflating: wsj/01/wsj_0142.mrg
#   inflating: wsj/01/wsj_0116.mrg
#   inflating: wsj/01/wsj_0161.mrg
#   inflating: wsj/01/wsj_0130.mrg
#   inflating: wsj/01/wsj_0122.mrg
#   inflating: wsj/01/wsj_0139.mrg
#   inflating: wsj/01/wsj_0183.mrg
#   inflating: wsj/01/wsj_0103.mrg
#   inflating: wsj/01/wsj_0190.mrg
#   inflating: wsj/01/wsj_0108.mrg
#   inflating: wsj/01/wsj_0100.mrg
#   inflating: wsj/01/wsj_0187.mrg
#   inflating: wsj/01/wsj_0171.mrg
#   inflating: wsj/01/wsj_0132.mrg
#   inflating: wsj/01/wsj_0162.mrg
#   inflating: wsj/01/wsj_0181.mrg
#   inflating: wsj/01/wsj_0129.mrg
#   inflating: wsj/01/wsj_0165.mrg
#   inflating: wsj/01/wsj_0198.mrg
#   inflating: wsj/01/wsj_0150.mrg
#   inflating: wsj/01/wsj_0114.mrg
#   inflating: wsj/01/wsj_0182.mrg
#   inflating: wsj/01/wsj_0164.mrg
#   inflating: wsj/01/wsj_0158.mrg
#   inflating: wsj/01/wsj_0138.mrg
#   inflating: wsj/01/wsj_0172.mrg
#   inflating: wsj/01/wsj_0109.mrg
#   inflating: wsj/01/wsj_0170.mrg
#   inflating: wsj/01/wsj_0177.mrg
#   inflating: wsj/01/wsj_0180.mrg
#   inflating: wsj/01/wsj_0145.mrg
#   inflating: wsj/01/wsj_0157.mrg
#   inflating: wsj/01/wsj_0199.mrg
#   inflating: wsj/01/wsj_0154.mrg
#   inflating: wsj/01/wsj_0102.mrg
#   inflating: wsj/01/wsj_0134.mrg
#   inflating: wsj/01/wsj_0128.mrg
#   inflating: wsj/01/wsj_0174.mrg
#   inflating: wsj/01/wsj_0188.mrg
#    creating: wsj/19/
#   inflating: wsj/19/wsj_1943.mrg
#   inflating: wsj/19/wsj_1948.mrg
#   inflating: wsj/19/wsj_1919.mrg
#   inflating: wsj/19/wsj_1944.mrg
#   inflating: wsj/19/wsj_1909.mrg
#   inflating: wsj/19/wsj_1934.mrg
#   inflating: wsj/19/wsj_1965.mrg
#   inflating: wsj/19/wsj_1959.mrg
#   inflating: wsj/19/wsj_1914.mrg
#   inflating: wsj/19/wsj_1942.mrg
#   inflating: wsj/19/wsj_1952.mrg
#   inflating: wsj/19/wsj_1982.mrg
#   inflating: wsj/19/wsj_1970.mrg
#   inflating: wsj/19/wsj_1902.mrg
#   inflating: wsj/19/wsj_1928.mrg
#   inflating: wsj/19/wsj_1994.mrg
#   inflating: wsj/19/wsj_1999.mrg
#   inflating: wsj/19/wsj_1956.mrg
#   inflating: wsj/19/wsj_1964.mrg
#   inflating: wsj/19/wsj_1967.mrg
#   inflating: wsj/19/wsj_1933.mrg
#   inflating: wsj/19/wsj_1915.mrg
#   inflating: wsj/19/wsj_1979.mrg
#   inflating: wsj/19/wsj_1972.mrg
#   inflating: wsj/19/wsj_1978.mrg
#   inflating: wsj/19/wsj_1945.mrg
#   inflating: wsj/19/wsj_1912.mrg
#   inflating: wsj/19/wsj_1950.mrg
#   inflating: wsj/19/wsj_1963.mrg
#   inflating: wsj/19/wsj_1971.mrg
#   inflating: wsj/19/wsj_1997.mrg
#   inflating: wsj/19/wsj_1946.mrg
#   inflating: wsj/19/wsj_1962.mrg
#   inflating: wsj/19/wsj_1941.mrg
#   inflating: wsj/19/wsj_1929.mrg
#   inflating: wsj/19/wsj_1987.mrg
#   inflating: wsj/19/wsj_1977.mrg
#   inflating: wsj/19/wsj_1936.mrg
#   inflating: wsj/19/wsj_1988.mrg
#   inflating: wsj/19/wsj_1931.mrg
#   inflating: wsj/19/wsj_1930.mrg
#   inflating: wsj/19/wsj_1980.mrg
#   inflating: wsj/19/wsj_1918.mrg
#   inflating: wsj/19/wsj_1938.mrg
#   inflating: wsj/19/wsj_1910.mrg
#   inflating: wsj/19/wsj_1974.mrg
#   inflating: wsj/19/wsj_1975.mrg
#   inflating: wsj/19/wsj_1995.mrg
#   inflating: wsj/19/wsj_1991.mrg
#   inflating: wsj/19/wsj_1901.mrg
#   inflating: wsj/19/wsj_1932.mrg
#   inflating: wsj/19/wsj_1908.mrg
#   inflating: wsj/19/wsj_1990.mrg
#   inflating: wsj/19/wsj_1916.mrg
#   inflating: wsj/19/wsj_1961.mrg
#   inflating: wsj/19/wsj_1985.mrg
#   inflating: wsj/19/wsj_1907.mrg
#   inflating: wsj/19/wsj_1953.mrg
#   inflating: wsj/19/wsj_1922.mrg
#   inflating: wsj/19/wsj_1986.mrg
#   inflating: wsj/19/wsj_1949.mrg
#   inflating: wsj/19/wsj_1958.mrg
#   inflating: wsj/19/wsj_1947.mrg
#   inflating: wsj/19/wsj_1904.mrg
#   inflating: wsj/19/wsj_1993.mrg
#   inflating: wsj/19/wsj_1935.mrg
#   inflating: wsj/19/wsj_1903.mrg
#   inflating: wsj/19/wsj_1925.mrg
#   inflating: wsj/19/wsj_1973.mrg
#   inflating: wsj/19/wsj_1998.mrg
#   inflating: wsj/19/wsj_1981.mrg
#   inflating: wsj/19/wsj_1976.mrg
#   inflating: wsj/19/wsj_1969.mrg
#   inflating: wsj/19/wsj_1960.mrg
#   inflating: wsj/19/wsj_1921.mrg
#   inflating: wsj/19/wsj_1951.mrg
#   inflating: wsj/19/wsj_1926.mrg
#   inflating: wsj/19/wsj_1989.mrg
#   inflating: wsj/19/wsj_1983.mrg
#   inflating: wsj/19/wsj_1905.mrg
#   inflating: wsj/19/wsj_1966.mrg
#   inflating: wsj/19/wsj_1923.mrg
#   inflating: wsj/19/wsj_1913.mrg
#   inflating: wsj/19/wsj_1920.mrg
#   inflating: wsj/19/wsj_1955.mrg
#   inflating: wsj/19/wsj_1927.mrg
#   inflating: wsj/19/wsj_1917.mrg
#   inflating: wsj/19/wsj_1992.mrg
#   inflating: wsj/19/wsj_1940.mrg
#   inflating: wsj/19/wsj_1954.mrg
#   inflating: wsj/19/wsj_1924.mrg
#   inflating: wsj/19/wsj_1968.mrg
#   inflating: wsj/19/wsj_1957.mrg
#   inflating: wsj/19/wsj_1900.mrg
#   inflating: wsj/19/wsj_1939.mrg
#   inflating: wsj/19/wsj_1984.mrg
#   inflating: wsj/19/wsj_1911.mrg
#   inflating: wsj/19/wsj_1937.mrg
#   inflating: wsj/19/wsj_1996.mrg
#   inflating: wsj/19/wsj_1906.mrg
#    creating: wsj/08/
#   inflating: wsj/08/wsj_0816.mrg
#   inflating: wsj/08/wsj_0803.mrg
#   inflating: wsj/08/wsj_0820.mrg
#   inflating: wsj/08/wsj_0806.mrg
#   inflating: wsj/08/wsj_0800.mrg
#   inflating: wsj/08/wsj_0804.mrg
#   inflating: wsj/08/wsj_0805.mrg
#   inflating: wsj/08/wsj_0813.mrg
#   inflating: wsj/08/wsj_0801.mrg
#   inflating: wsj/08/wsj_0812.mrg
#   inflating: wsj/08/wsj_0807.mrg
#   inflating: wsj/08/wsj_0819.mrg
#   inflating: wsj/08/wsj_0809.mrg
#   inflating: wsj/08/wsj_0802.mrg
#   inflating: wsj/08/wsj_0808.mrg
#   inflating: wsj/08/wsj_0811.mrg
#   inflating: wsj/08/wsj_0815.mrg
#   inflating: wsj/08/wsj_0814.mrg
#   inflating: wsj/08/wsj_0818.mrg
#   inflating: wsj/08/wsj_0817.mrg
#   inflating: wsj/08/wsj_0810.mrg
#    creating: wsj/20/
#   inflating: wsj/20/wsj_2083.mrg
#   inflating: wsj/20/wsj_2086.mrg
#   inflating: wsj/20/wsj_2017.mrg
#   inflating: wsj/20/wsj_2096.mrg
#   inflating: wsj/20/wsj_2033.mrg
#   inflating: wsj/20/wsj_2069.mrg
#   inflating: wsj/20/wsj_2014.mrg
#   inflating: wsj/20/wsj_2018.mrg
#   inflating: wsj/20/wsj_2044.mrg
#   inflating: wsj/20/wsj_2011.mrg
#   inflating: wsj/20/wsj_2024.mrg
#   inflating: wsj/20/wsj_2051.mrg
#   inflating: wsj/20/wsj_2040.mrg
#   inflating: wsj/20/wsj_2073.mrg
#   inflating: wsj/20/wsj_2061.mrg
#   inflating: wsj/20/wsj_2034.mrg
#   inflating: wsj/20/wsj_2008.mrg
#   inflating: wsj/20/wsj_2046.mrg
#   inflating: wsj/20/wsj_2006.mrg
#   inflating: wsj/20/wsj_2019.mrg
#   inflating: wsj/20/wsj_2099.mrg
#   inflating: wsj/20/wsj_2060.mrg
#   inflating: wsj/20/wsj_2068.mrg
#   inflating: wsj/20/wsj_2066.mrg
#   inflating: wsj/20/wsj_2041.mrg
#   inflating: wsj/20/wsj_2000.mrg
#   inflating: wsj/20/wsj_2082.mrg
#   inflating: wsj/20/wsj_2092.mrg
#   inflating: wsj/20/wsj_2079.mrg
#   inflating: wsj/20/wsj_2012.mrg
#   inflating: wsj/20/wsj_2088.mrg
#   inflating: wsj/20/wsj_2021.mrg
#   inflating: wsj/20/wsj_2062.mrg
#   inflating: wsj/20/wsj_2020.mrg
#   inflating: wsj/20/wsj_2043.mrg
#   inflating: wsj/20/wsj_2098.mrg
#   inflating: wsj/20/wsj_2029.mrg
#   inflating: wsj/20/wsj_2036.mrg
#   inflating: wsj/20/wsj_2091.mrg
#   inflating: wsj/20/wsj_2015.mrg
#   inflating: wsj/20/wsj_2063.mrg
#   inflating: wsj/20/wsj_2054.mrg
#   inflating: wsj/20/wsj_2047.mrg
#   inflating: wsj/20/wsj_2050.mrg
#   inflating: wsj/20/wsj_2031.mrg
#   inflating: wsj/20/wsj_2097.mrg
#   inflating: wsj/20/wsj_2045.mrg
#   inflating: wsj/20/wsj_2032.mrg
#   inflating: wsj/20/wsj_2087.mrg
#   inflating: wsj/20/wsj_2093.mrg
#   inflating: wsj/20/wsj_2004.mrg
#   inflating: wsj/20/wsj_2003.mrg
#   inflating: wsj/20/wsj_2042.mrg
#   inflating: wsj/20/wsj_2090.mrg
#   inflating: wsj/20/wsj_2081.mrg
#   inflating: wsj/20/wsj_2078.mrg
#   inflating: wsj/20/wsj_2064.mrg
#   inflating: wsj/20/wsj_2065.mrg
#   inflating: wsj/20/wsj_2038.mrg
#   inflating: wsj/20/wsj_2075.mrg
#   inflating: wsj/20/wsj_2057.mrg
#   inflating: wsj/20/wsj_2002.mrg
#   inflating: wsj/20/wsj_2022.mrg
#   inflating: wsj/20/wsj_2023.mrg
#   inflating: wsj/20/wsj_2053.mrg
#   inflating: wsj/20/wsj_2001.mrg
#   inflating: wsj/20/wsj_2058.mrg
#   inflating: wsj/20/wsj_2080.mrg
#   inflating: wsj/20/wsj_2089.mrg
#   inflating: wsj/20/wsj_2005.mrg
#   inflating: wsj/20/wsj_2055.mrg
#   inflating: wsj/20/wsj_2076.mrg
#   inflating: wsj/20/wsj_2013.mrg
#   inflating: wsj/20/wsj_2026.mrg
#   inflating: wsj/20/wsj_2084.mrg
#   inflating: wsj/20/wsj_2094.mrg
#   inflating: wsj/20/wsj_2072.mrg
#   inflating: wsj/20/wsj_2070.mrg
#   inflating: wsj/20/wsj_2039.mrg
#   inflating: wsj/20/wsj_2071.mrg
#   inflating: wsj/20/wsj_2056.mrg
#   inflating: wsj/20/wsj_2048.mrg
#   inflating: wsj/20/wsj_2030.mrg
#   inflating: wsj/20/wsj_2052.mrg
#   inflating: wsj/20/wsj_2009.mrg
#   inflating: wsj/20/wsj_2067.mrg
#   inflating: wsj/20/wsj_2059.mrg
#   inflating: wsj/20/wsj_2095.mrg
#   inflating: wsj/20/wsj_2077.mrg
#   inflating: wsj/20/wsj_2049.mrg
#   inflating: wsj/20/wsj_2035.mrg
#   inflating: wsj/20/wsj_2025.mrg
#   inflating: wsj/20/wsj_2007.mrg
#   inflating: wsj/20/wsj_2016.mrg
#   inflating: wsj/20/wsj_2085.mrg
#   inflating: wsj/20/wsj_2074.mrg
#   inflating: wsj/20/wsj_2028.mrg
#   inflating: wsj/20/wsj_2027.mrg
#   inflating: wsj/20/wsj_2010.mrg
#   inflating: wsj/20/wsj_2037.mrg
#    creating: wsj/14/
#   inflating: wsj/14/wsj_1462.mrg
#   inflating: wsj/14/wsj_1425.mrg
#   inflating: wsj/14/wsj_1479.mrg
#   inflating: wsj/14/wsj_1495.mrg
#   inflating: wsj/14/wsj_1456.mrg
#   inflating: wsj/14/wsj_1430.mrg
#   inflating: wsj/14/wsj_1428.mrg
#   inflating: wsj/14/wsj_1496.mrg
#   inflating: wsj/14/wsj_1445.mrg
#   inflating: wsj/14/wsj_1471.mrg
#   inflating: wsj/14/wsj_1460.mrg
#   inflating: wsj/14/wsj_1491.mrg
#   inflating: wsj/14/wsj_1494.mrg
#   inflating: wsj/14/wsj_1468.mrg
#   inflating: wsj/14/wsj_1448.mrg
#   inflating: wsj/14/wsj_1470.mrg
#   inflating: wsj/14/wsj_1443.mrg
#   inflating: wsj/14/wsj_1444.mrg
#   inflating: wsj/14/wsj_1483.mrg
#   inflating: wsj/14/wsj_1440.mrg
#   inflating: wsj/14/wsj_1410.mrg
#   inflating: wsj/14/wsj_1408.mrg
#   inflating: wsj/14/wsj_1453.mrg
#   inflating: wsj/14/wsj_1414.mrg
#   inflating: wsj/14/wsj_1486.mrg
#   inflating: wsj/14/wsj_1467.mrg
#   inflating: wsj/14/wsj_1427.mrg
#   inflating: wsj/14/wsj_1465.mrg
#   inflating: wsj/14/wsj_1412.mrg
#   inflating: wsj/14/wsj_1454.mrg
#   inflating: wsj/14/wsj_1480.mrg
#   inflating: wsj/14/wsj_1473.mrg
#   inflating: wsj/14/wsj_1458.mrg
#   inflating: wsj/14/wsj_1490.mrg
#   inflating: wsj/14/wsj_1422.mrg
#   inflating: wsj/14/wsj_1402.mrg
#   inflating: wsj/14/wsj_1419.mrg
#   inflating: wsj/14/wsj_1416.mrg
#   inflating: wsj/14/wsj_1476.mrg
#   inflating: wsj/14/wsj_1492.mrg
#   inflating: wsj/14/wsj_1400.mrg
#   inflating: wsj/14/wsj_1447.mrg
#   inflating: wsj/14/wsj_1472.mrg
#   inflating: wsj/14/wsj_1482.mrg
#   inflating: wsj/14/wsj_1474.mrg
#   inflating: wsj/14/wsj_1452.mrg
#   inflating: wsj/14/wsj_1469.mrg
#   inflating: wsj/14/wsj_1404.mrg
#   inflating: wsj/14/wsj_1484.mrg
#   inflating: wsj/14/wsj_1488.mrg
#   inflating: wsj/14/wsj_1464.mrg
#   inflating: wsj/14/wsj_1423.mrg
#   inflating: wsj/14/wsj_1446.mrg
#   inflating: wsj/14/wsj_1459.mrg
#   inflating: wsj/14/wsj_1441.mrg
#   inflating: wsj/14/wsj_1466.mrg
#   inflating: wsj/14/wsj_1405.mrg
#   inflating: wsj/14/wsj_1442.mrg
#   inflating: wsj/14/wsj_1413.mrg
#   inflating: wsj/14/wsj_1411.mrg
#   inflating: wsj/14/wsj_1481.mrg
#   inflating: wsj/14/wsj_1455.mrg
#   inflating: wsj/14/wsj_1432.mrg
#   inflating: wsj/14/wsj_1409.mrg
#   inflating: wsj/14/wsj_1439.mrg
#   inflating: wsj/14/wsj_1493.mrg
#   inflating: wsj/14/wsj_1407.mrg
#   inflating: wsj/14/wsj_1434.mrg
#   inflating: wsj/14/wsj_1435.mrg
#   inflating: wsj/14/wsj_1426.mrg
#   inflating: wsj/14/wsj_1438.mrg
#   inflating: wsj/14/wsj_1477.mrg
#   inflating: wsj/14/wsj_1463.mrg
#   inflating: wsj/14/wsj_1403.mrg
#   inflating: wsj/14/wsj_1499.mrg
#   inflating: wsj/14/wsj_1401.mrg
#   inflating: wsj/14/wsj_1497.mrg
#   inflating: wsj/14/wsj_1461.mrg
#   inflating: wsj/14/wsj_1489.mrg
#   inflating: wsj/14/wsj_1475.mrg
#   inflating: wsj/14/wsj_1485.mrg
#   inflating: wsj/14/wsj_1457.mrg
#   inflating: wsj/14/wsj_1431.mrg
#   inflating: wsj/14/wsj_1420.mrg
#   inflating: wsj/14/wsj_1449.mrg
#   inflating: wsj/14/wsj_1437.mrg
#   inflating: wsj/14/wsj_1429.mrg
#   inflating: wsj/14/wsj_1418.mrg
#   inflating: wsj/14/wsj_1415.mrg
#   inflating: wsj/14/wsj_1487.mrg
#   inflating: wsj/14/wsj_1433.mrg
#   inflating: wsj/14/wsj_1424.mrg
#   inflating: wsj/14/wsj_1450.mrg
#   inflating: wsj/14/wsj_1417.mrg
#   inflating: wsj/14/wsj_1478.mrg
#   inflating: wsj/14/wsj_1406.mrg
#   inflating: wsj/14/wsj_1436.mrg
#   inflating: wsj/14/wsj_1498.mrg
#   inflating: wsj/14/wsj_1421.mrg
#   inflating: wsj/14/wsj_1451.mrg
#    creating: wsj/17/
#   inflating: wsj/17/wsj_1792.mrg
#   inflating: wsj/17/wsj_1752.mrg
#   inflating: wsj/17/wsj_1754.mrg
#   inflating: wsj/17/wsj_1769.mrg
#   inflating: wsj/17/wsj_1721.mrg
#   inflating: wsj/17/wsj_1734.mrg
#   inflating: wsj/17/wsj_1794.mrg
#   inflating: wsj/17/wsj_1797.mrg
#   inflating: wsj/17/wsj_1773.mrg
#   inflating: wsj/17/wsj_1742.mrg
#   inflating: wsj/17/wsj_1760.mrg
#   inflating: wsj/17/wsj_1791.mrg
#   inflating: wsj/17/wsj_1737.mrg
#   inflating: wsj/17/wsj_1743.mrg
#   inflating: wsj/17/wsj_1738.mrg
#   inflating: wsj/17/wsj_1756.mrg
#   inflating: wsj/17/wsj_1779.mrg
#   inflating: wsj/17/wsj_1704.mrg
#   inflating: wsj/17/wsj_1727.mrg
#   inflating: wsj/17/wsj_1703.mrg
#   inflating: wsj/17/wsj_1768.mrg
#   inflating: wsj/17/wsj_1739.mrg
#   inflating: wsj/17/wsj_1735.mrg
#   inflating: wsj/17/wsj_1746.mrg
#   inflating: wsj/17/wsj_1741.mrg
#   inflating: wsj/17/wsj_1789.mrg
#   inflating: wsj/17/wsj_1772.mrg
#   inflating: wsj/17/wsj_1713.mrg
#   inflating: wsj/17/wsj_1788.mrg
#   inflating: wsj/17/wsj_1733.mrg
#   inflating: wsj/17/wsj_1770.mrg
#   inflating: wsj/17/wsj_1716.mrg
#   inflating: wsj/17/wsj_1710.mrg
#   inflating: wsj/17/wsj_1793.mrg
#   inflating: wsj/17/wsj_1747.mrg
#   inflating: wsj/17/wsj_1736.mrg
#   inflating: wsj/17/wsj_1787.mrg
#   inflating: wsj/17/wsj_1723.mrg
#   inflating: wsj/17/wsj_1707.mrg
#   inflating: wsj/17/wsj_1766.mrg
#   inflating: wsj/17/wsj_1750.mrg
#   inflating: wsj/17/wsj_1726.mrg
#   inflating: wsj/17/wsj_1759.mrg
#   inflating: wsj/17/wsj_1755.mrg
#   inflating: wsj/17/wsj_1731.mrg
#   inflating: wsj/17/wsj_1799.mrg
#   inflating: wsj/17/wsj_1725.mrg
#   inflating: wsj/17/wsj_1740.mrg
#   inflating: wsj/17/wsj_1753.mrg
#   inflating: wsj/17/wsj_1758.mrg
#   inflating: wsj/17/wsj_1778.mrg
#   inflating: wsj/17/wsj_1782.mrg
#   inflating: wsj/17/wsj_1709.mrg
#   inflating: wsj/17/wsj_1795.mrg
#   inflating: wsj/17/wsj_1761.mrg
#   inflating: wsj/17/wsj_1730.mrg
#   inflating: wsj/17/wsj_1781.mrg
#   inflating: wsj/17/wsj_1780.mrg
#   inflating: wsj/17/wsj_1714.mrg
#   inflating: wsj/17/wsj_1702.mrg
#   inflating: wsj/17/wsj_1751.mrg
#   inflating: wsj/17/wsj_1771.mrg
#   inflating: wsj/17/wsj_1706.mrg
#   inflating: wsj/17/wsj_1749.mrg
#   inflating: wsj/17/wsj_1763.mrg
#   inflating: wsj/17/wsj_1745.mrg
#   inflating: wsj/17/wsj_1775.mrg
#   inflating: wsj/17/wsj_1784.mrg
#   inflating: wsj/17/wsj_1729.mrg
#   inflating: wsj/17/wsj_1700.mrg
#   inflating: wsj/17/wsj_1748.mrg
#   inflating: wsj/17/wsj_1712.mrg
#   inflating: wsj/17/wsj_1705.mrg
#   inflating: wsj/17/wsj_1744.mrg
#   inflating: wsj/17/wsj_1776.mrg
#   inflating: wsj/17/wsj_1786.mrg
#   inflating: wsj/17/wsj_1762.mrg
#   inflating: wsj/17/wsj_1765.mrg
#   inflating: wsj/17/wsj_1711.mrg
#   inflating: wsj/17/wsj_1757.mrg
#   inflating: wsj/17/wsj_1708.mrg
#   inflating: wsj/17/wsj_1718.mrg
#   inflating: wsj/17/wsj_1701.mrg
#   inflating: wsj/17/wsj_1720.mrg
#   inflating: wsj/17/wsj_1798.mrg
#   inflating: wsj/17/wsj_1783.mrg
#   inflating: wsj/17/wsj_1724.mrg
#   inflating: wsj/17/wsj_1785.mrg
#   inflating: wsj/17/wsj_1767.mrg
#   inflating: wsj/17/wsj_1790.mrg
#   inflating: wsj/17/wsj_1715.mrg
#   inflating: wsj/17/wsj_1719.mrg
#   inflating: wsj/17/wsj_1777.mrg
#   inflating: wsj/17/wsj_1796.mrg
#   inflating: wsj/17/wsj_1728.mrg
#   inflating: wsj/17/wsj_1722.mrg
#   inflating: wsj/17/wsj_1774.mrg
#   inflating: wsj/17/wsj_1717.mrg
#   inflating: wsj/17/wsj_1732.mrg
#   inflating: wsj/17/wsj_1764.mrg
#    creating: wsj/22/
#   inflating: wsj/22/wsj_2218.mrg
#   inflating: wsj/22/wsj_2254.mrg
#   inflating: wsj/22/wsj_2207.mrg
#   inflating: wsj/22/wsj_2204.mrg
#   inflating: wsj/22/wsj_2271.mrg
#   inflating: wsj/22/wsj_2266.mrg
#   inflating: wsj/22/wsj_2261.mrg
#   inflating: wsj/22/wsj_2234.mrg
#   inflating: wsj/22/wsj_2224.mrg
#   inflating: wsj/22/wsj_2255.mrg
#   inflating: wsj/22/wsj_2203.mrg
#   inflating: wsj/22/wsj_2250.mrg
#   inflating: wsj/22/wsj_2229.mrg
#   inflating: wsj/22/wsj_2226.mrg
#   inflating: wsj/22/wsj_2270.mrg
#   inflating: wsj/22/wsj_2279.mrg
#   inflating: wsj/22/wsj_2277.mrg
#   inflating: wsj/22/wsj_2211.mrg
#   inflating: wsj/22/wsj_2240.mrg
#   inflating: wsj/22/wsj_2201.mrg
#   inflating: wsj/22/wsj_2280.mrg
#   inflating: wsj/22/wsj_2274.mrg
#   inflating: wsj/22/wsj_2221.mrg
#   inflating: wsj/22/wsj_2260.mrg
#   inflating: wsj/22/wsj_2246.mrg
#   inflating: wsj/22/wsj_2205.mrg
#   inflating: wsj/22/wsj_2278.mrg
#   inflating: wsj/22/wsj_2212.mrg
#   inflating: wsj/22/wsj_2216.mrg
#   inflating: wsj/22/wsj_2249.mrg
#   inflating: wsj/22/wsj_2202.mrg
#   inflating: wsj/22/wsj_2228.mrg
#   inflating: wsj/22/wsj_2241.mrg
#   inflating: wsj/22/wsj_2257.mrg
#   inflating: wsj/22/wsj_2264.mrg
#   inflating: wsj/22/wsj_2262.mrg
#   inflating: wsj/22/wsj_2200.mrg
#   inflating: wsj/22/wsj_2230.mrg
#   inflating: wsj/22/wsj_2233.mrg
#   inflating: wsj/22/wsj_2265.mrg
#   inflating: wsj/22/wsj_2247.mrg
#   inflating: wsj/22/wsj_2210.mrg
#   inflating: wsj/22/wsj_2206.mrg
#   inflating: wsj/22/wsj_2236.mrg
#   inflating: wsj/22/wsj_2231.mrg
#   inflating: wsj/22/wsj_2248.mrg
#   inflating: wsj/22/wsj_2281.mrg
#   inflating: wsj/22/wsj_2237.mrg
#   inflating: wsj/22/wsj_2239.mrg
#   inflating: wsj/22/wsj_2208.mrg
#   inflating: wsj/22/wsj_2219.mrg
#   inflating: wsj/22/wsj_2227.mrg
#   inflating: wsj/22/wsj_2273.mrg
#   inflating: wsj/22/wsj_2251.mrg
#   inflating: wsj/22/wsj_2253.mrg
#   inflating: wsj/22/wsj_2209.mrg
#   inflating: wsj/22/wsj_2243.mrg
#   inflating: wsj/22/wsj_2215.mrg
#   inflating: wsj/22/wsj_2282.mrg
#   inflating: wsj/22/wsj_2238.mrg
#   inflating: wsj/22/wsj_2220.mrg
#   inflating: wsj/22/wsj_2242.mrg
#   inflating: wsj/22/wsj_2276.mrg
#   inflating: wsj/22/wsj_2263.mrg
#   inflating: wsj/22/wsj_2275.mrg
#   inflating: wsj/22/wsj_2256.mrg
#   inflating: wsj/22/wsj_2213.mrg
#   inflating: wsj/22/wsj_2272.mrg
#   inflating: wsj/22/wsj_2252.mrg
#   inflating: wsj/22/wsj_2217.mrg
#   inflating: wsj/22/wsj_2232.mrg
#   inflating: wsj/22/wsj_2244.mrg
#   inflating: wsj/22/wsj_2225.mrg
#   inflating: wsj/22/wsj_2259.mrg
#   inflating: wsj/22/wsj_2235.mrg
#   inflating: wsj/22/wsj_2268.mrg
#   inflating: wsj/22/wsj_2258.mrg
#   inflating: wsj/22/wsj_2222.mrg
#   inflating: wsj/22/wsj_2245.mrg
#   inflating: wsj/22/wsj_2214.mrg
#   inflating: wsj/22/wsj_2269.mrg
#   inflating: wsj/22/wsj_2223.mrg
#   inflating: wsj/22/wsj_2267.mrg
#    creating: wsj/12/
#   inflating: wsj/12/wsj_1216.mrg
#   inflating: wsj/12/wsj_1260.mrg
#   inflating: wsj/12/wsj_1246.mrg
#   inflating: wsj/12/wsj_1224.mrg
#   inflating: wsj/12/wsj_1287.mrg
#   inflating: wsj/12/wsj_1277.mrg
#   inflating: wsj/12/wsj_1253.mrg
#   inflating: wsj/12/wsj_1234.mrg
#   inflating: wsj/12/wsj_1239.mrg
#   inflating: wsj/12/wsj_1268.mrg
#   inflating: wsj/12/wsj_1217.mrg
#   inflating: wsj/12/wsj_1265.mrg
#   inflating: wsj/12/wsj_1288.mrg
#   inflating: wsj/12/wsj_1257.mrg
#   inflating: wsj/12/wsj_1214.mrg
#   inflating: wsj/12/wsj_1249.mrg
#   inflating: wsj/12/wsj_1294.mrg
#   inflating: wsj/12/wsj_1280.mrg
#   inflating: wsj/12/wsj_1218.mrg
#   inflating: wsj/12/wsj_1286.mrg
#   inflating: wsj/12/wsj_1255.mrg
#   inflating: wsj/12/wsj_1227.mrg
#   inflating: wsj/12/wsj_1205.mrg
#   inflating: wsj/12/wsj_1207.mrg
#   inflating: wsj/12/wsj_1229.mrg
#   inflating: wsj/12/wsj_1271.mrg
#   inflating: wsj/12/wsj_1251.mrg
#   inflating: wsj/12/wsj_1203.mrg
#   inflating: wsj/12/wsj_1201.mrg
#   inflating: wsj/12/wsj_1261.mrg
#   inflating: wsj/12/wsj_1278.mrg
#   inflating: wsj/12/wsj_1275.mrg
#   inflating: wsj/12/wsj_1292.mrg
#   inflating: wsj/12/wsj_1223.mrg
#   inflating: wsj/12/wsj_1210.mrg
#   inflating: wsj/12/wsj_1211.mrg
#   inflating: wsj/12/wsj_1267.mrg
#   inflating: wsj/12/wsj_1226.mrg
#   inflating: wsj/12/wsj_1237.mrg
#   inflating: wsj/12/wsj_1273.mrg
#   inflating: wsj/12/wsj_1230.mrg
#   inflating: wsj/12/wsj_1245.mrg
#   inflating: wsj/12/wsj_1281.mrg
#   inflating: wsj/12/wsj_1250.mrg
#   inflating: wsj/12/wsj_1262.mrg
#   inflating: wsj/12/wsj_1213.mrg
#   inflating: wsj/12/wsj_1284.mrg
#   inflating: wsj/12/wsj_1235.mrg
#   inflating: wsj/12/wsj_1293.mrg
#   inflating: wsj/12/wsj_1298.mrg
#   inflating: wsj/12/wsj_1225.mrg
#   inflating: wsj/12/wsj_1279.mrg
#   inflating: wsj/12/wsj_1238.mrg
#   inflating: wsj/12/wsj_1242.mrg
#   inflating: wsj/12/wsj_1200.mrg
#   inflating: wsj/12/wsj_1222.mrg
#   inflating: wsj/12/wsj_1233.mrg
#   inflating: wsj/12/wsj_1204.mrg
#   inflating: wsj/12/wsj_1252.mrg
#   inflating: wsj/12/wsj_1231.mrg
#   inflating: wsj/12/wsj_1248.mrg
#   inflating: wsj/12/wsj_1219.mrg
#   inflating: wsj/12/wsj_1272.mrg
#   inflating: wsj/12/wsj_1291.mrg
#   inflating: wsj/12/wsj_1228.mrg
#   inflating: wsj/12/wsj_1247.mrg
#   inflating: wsj/12/wsj_1206.mrg
#   inflating: wsj/12/wsj_1240.mrg
#   inflating: wsj/12/wsj_1232.mrg
#   inflating: wsj/12/wsj_1296.mrg
#   inflating: wsj/12/wsj_1258.mrg
#   inflating: wsj/12/wsj_1221.mrg
#   inflating: wsj/12/wsj_1269.mrg
#   inflating: wsj/12/wsj_1259.mrg
#   inflating: wsj/12/wsj_1270.mrg
#   inflating: wsj/12/wsj_1243.mrg
#   inflating: wsj/12/wsj_1236.mrg
#   inflating: wsj/12/wsj_1215.mrg
#   inflating: wsj/12/wsj_1283.mrg
#   inflating: wsj/12/wsj_1220.mrg
#   inflating: wsj/12/wsj_1290.mrg
#   inflating: wsj/12/wsj_1274.mrg
#   inflating: wsj/12/wsj_1266.mrg
#   inflating: wsj/12/wsj_1282.mrg
#   inflating: wsj/12/wsj_1264.mrg
#   inflating: wsj/12/wsj_1263.mrg
#   inflating: wsj/12/wsj_1254.mrg
#   inflating: wsj/12/wsj_1212.mrg
#   inflating: wsj/12/wsj_1285.mrg
#   inflating: wsj/12/wsj_1276.mrg
#   inflating: wsj/12/wsj_1241.mrg
#   inflating: wsj/12/wsj_1209.mrg
#   inflating: wsj/12/wsj_1208.mrg
#   inflating: wsj/12/wsj_1289.mrg
#   inflating: wsj/12/wsj_1295.mrg
#   inflating: wsj/12/wsj_1256.mrg
#   inflating: wsj/12/wsj_1299.mrg
#   inflating: wsj/12/wsj_1297.mrg
#   inflating: wsj/12/wsj_1202.mrg
#   inflating: wsj/12/wsj_1244.mrg
#    creating: wsj/13/
#   inflating: wsj/13/wsj_1324.mrg
#   inflating: wsj/13/wsj_1384.mrg
#   inflating: wsj/13/wsj_1319.mrg
#   inflating: wsj/13/wsj_1343.mrg
#   inflating: wsj/13/wsj_1372.mrg
#   inflating: wsj/13/wsj_1330.mrg
#   inflating: wsj/13/wsj_1373.mrg
#   inflating: wsj/13/wsj_1371.mrg
#   inflating: wsj/13/wsj_1342.mrg
#   inflating: wsj/13/wsj_1390.mrg
#   inflating: wsj/13/wsj_1300.mrg
#   inflating: wsj/13/wsj_1387.mrg
#   inflating: wsj/13/wsj_1345.mrg
#   inflating: wsj/13/wsj_1398.mrg
#   inflating: wsj/13/wsj_1363.mrg
#   inflating: wsj/13/wsj_1304.mrg
#   inflating: wsj/13/wsj_1325.mrg
#   inflating: wsj/13/wsj_1348.mrg
#   inflating: wsj/13/wsj_1377.mrg
#   inflating: wsj/13/wsj_1307.mrg
#   inflating: wsj/13/wsj_1362.mrg
#   inflating: wsj/13/wsj_1320.mrg
#   inflating: wsj/13/wsj_1310.mrg
#   inflating: wsj/13/wsj_1379.mrg
#   inflating: wsj/13/wsj_1313.mrg
#   inflating: wsj/13/wsj_1326.mrg
#   inflating: wsj/13/wsj_1312.mrg
#   inflating: wsj/13/wsj_1347.mrg
#   inflating: wsj/13/wsj_1334.mrg
#   inflating: wsj/13/wsj_1393.mrg
#   inflating: wsj/13/wsj_1335.mrg
#   inflating: wsj/13/wsj_1315.mrg
#   inflating: wsj/13/wsj_1383.mrg
#   inflating: wsj/13/wsj_1355.mrg
#   inflating: wsj/13/wsj_1331.mrg
#   inflating: wsj/13/wsj_1341.mrg
#   inflating: wsj/13/wsj_1309.mrg
#   inflating: wsj/13/wsj_1392.mrg
#   inflating: wsj/13/wsj_1395.mrg
#   inflating: wsj/13/wsj_1394.mrg
#   inflating: wsj/13/wsj_1346.mrg
#   inflating: wsj/13/wsj_1305.mrg
#   inflating: wsj/13/wsj_1351.mrg
#   inflating: wsj/13/wsj_1336.mrg
#   inflating: wsj/13/wsj_1301.mrg
#   inflating: wsj/13/wsj_1366.mrg
#   inflating: wsj/13/wsj_1396.mrg
#   inflating: wsj/13/wsj_1376.mrg
#   inflating: wsj/13/wsj_1388.mrg
#   inflating: wsj/13/wsj_1327.mrg
#   inflating: wsj/13/wsj_1317.mrg
#   inflating: wsj/13/wsj_1386.mrg
#   inflating: wsj/13/wsj_1337.mrg
#   inflating: wsj/13/wsj_1389.mrg
#   inflating: wsj/13/wsj_1323.mrg
#   inflating: wsj/13/wsj_1365.mrg
#   inflating: wsj/13/wsj_1374.mrg
#   inflating: wsj/13/wsj_1338.mrg
#   inflating: wsj/13/wsj_1328.mrg
#   inflating: wsj/13/wsj_1353.mrg
#   inflating: wsj/13/wsj_1370.mrg
#   inflating: wsj/13/wsj_1329.mrg
#   inflating: wsj/13/wsj_1321.mrg
#   inflating: wsj/13/wsj_1340.mrg
#   inflating: wsj/13/wsj_1369.mrg
#   inflating: wsj/13/wsj_1318.mrg
#   inflating: wsj/13/wsj_1361.mrg
#   inflating: wsj/13/wsj_1360.mrg
#   inflating: wsj/13/wsj_1381.mrg
#   inflating: wsj/13/wsj_1367.mrg
#   inflating: wsj/13/wsj_1378.mrg
#   inflating: wsj/13/wsj_1352.mrg
#   inflating: wsj/13/wsj_1311.mrg
#   inflating: wsj/13/wsj_1375.mrg
#   inflating: wsj/13/wsj_1339.mrg
#   inflating: wsj/13/wsj_1391.mrg
#   inflating: wsj/13/wsj_1316.mrg
#   inflating: wsj/13/wsj_1350.mrg
#   inflating: wsj/13/wsj_1397.mrg
#   inflating: wsj/13/wsj_1385.mrg
#   inflating: wsj/13/wsj_1382.mrg
#   inflating: wsj/13/wsj_1344.mrg
#   inflating: wsj/13/wsj_1358.mrg
#   inflating: wsj/13/wsj_1308.mrg
#   inflating: wsj/13/wsj_1364.mrg
#   inflating: wsj/13/wsj_1349.mrg
#   inflating: wsj/13/wsj_1359.mrg
#   inflating: wsj/13/wsj_1368.mrg
#   inflating: wsj/13/wsj_1333.mrg
#   inflating: wsj/13/wsj_1354.mrg
#   inflating: wsj/13/wsj_1399.mrg
#   inflating: wsj/13/wsj_1380.mrg
#   inflating: wsj/13/wsj_1303.mrg
#   inflating: wsj/13/wsj_1314.mrg
#   inflating: wsj/13/wsj_1356.mrg
#   inflating: wsj/13/wsj_1322.mrg
# ...
#   inflating: wsj/23/wsj_2313.mrg
#   inflating: wsj/23/wsj_2330.mrg
#   inflating: wsj/23/wsj_2349.mrg
#   inflating: wsj/23/wsj_2388.mrg
#   inflating: wsj/23/wsj_2342.mrg
#   inflating: wsj/23/wsj_2383.mrg
#   inflating: wsj/23/wsj_2345.mrg
#   inflating: wsj/23/wsj_2320.mrg
#   inflating: wsj/23/wsj_2326.mrg
#   inflating: wsj/23/wsj_2365.mrg
#   inflating: wsj/23/wsj_2377.mrg
#   inflating: wsj/23/wsj_2307.mrg
#   inflating: wsj/23/wsj_2354.mrg
#   inflating: wsj/23/wsj_2332.mrg
#   inflating: wsj/23/wsj_2316.mrg
#   inflating: wsj/23/wsj_2384.mrg
#   inflating: wsj/23/wsj_2314.mrg
#   inflating: wsj/23/wsj_2376.mrg
#   inflating: wsj/23/wsj_2364.mrg
#   inflating: wsj/23/wsj_2327.mrg
#   inflating: wsj/23/wsj_2353.mrg
#   inflating: wsj/23/wsj_2348.mrg
#   inflating: wsj/23/wsj_2304.mrg
#   inflating: wsj/23/wsj_2339.mrg
#   inflating: wsj/23/wsj_2368.mrg
#   inflating: wsj/23/wsj_2382.mrg
#   inflating: wsj/23/wsj_2317.mrg
#   inflating: wsj/23/wsj_2340.mrg
#   inflating: wsj/23/wsj_2370.mrg
#   inflating: wsj/23/wsj_2318.mrg
#   inflating: wsj/23/wsj_2355.mrg
#   inflating: wsj/23/wsj_2385.mrg
#   inflating: wsj/23/wsj_2328.mrg
#   inflating: wsj/23/wsj_2391.mrg
#   inflating: wsj/23/wsj_2362.mrg
#   inflating: wsj/23/wsj_2367.mrg
#   inflating: wsj/23/wsj_2399.mrg
#   inflating: wsj/23/wsj_2381.mrg
#   inflating: wsj/23/wsj_2395.mrg
#   inflating: wsj/23/wsj_2335.mrg
#   inflating: wsj/23/wsj_2351.mrg
#   inflating: wsj/23/wsj_2378.mrg
#   inflating: wsj/23/wsj_2358.mrg
#   inflating: wsj/23/wsj_2363.mrg
#   inflating: wsj/23/wsj_2323.mrg
#   inflating: wsj/23/wsj_2347.mrg
#   inflating: wsj/23/wsj_2369.mrg
#   inflating: wsj/23/wsj_2322.mrg
#   inflating: wsj/23/wsj_2315.mrg
#   inflating: wsj/23/wsj_2386.mrg
#   inflating: wsj/23/wsj_2329.mrg
#   inflating: wsj/23/wsj_2311.mrg
#   inflating: wsj/23/wsj_2344.mrg
#   inflating: wsj/23/wsj_2325.mrg
#   inflating: wsj/23/wsj_2380.mrg
#   inflating: wsj/23/wsj_2302.mrg
#   inflating: wsj/23/wsj_2387.mrg
#   inflating: wsj/23/wsj_2331.mrg
#   inflating: wsj/23/wsj_2336.mrg
#   inflating: wsj/23/wsj_2397.mrg
#   inflating: wsj/23/wsj_2366.mrg
#   inflating: wsj/23/wsj_2392.mrg
#   inflating: wsj/23/wsj_2372.mrg
#    creating: wsj/21/
#   inflating: wsj/21/wsj_2138.mrg
#   inflating: wsj/21/wsj_2102.mrg
#   inflating: wsj/21/wsj_2172.mrg
#   inflating: wsj/21/wsj_2164.mrg
#   inflating: wsj/21/wsj_2109.mrg
#   inflating: wsj/21/wsj_2154.mrg
#   inflating: wsj/21/wsj_2161.mrg
#   inflating: wsj/21/wsj_2150.mrg
#   inflating: wsj/21/wsj_2169.mrg
#   inflating: wsj/21/wsj_2158.mrg
#   inflating: wsj/21/wsj_2136.mrg
#   inflating: wsj/21/wsj_2116.mrg
#   inflating: wsj/21/wsj_2100.mrg
#   inflating: wsj/21/wsj_2145.mrg
#   inflating: wsj/21/wsj_2165.mrg
#   inflating: wsj/21/wsj_2149.mrg
#   inflating: wsj/21/wsj_2167.mrg
#   inflating: wsj/21/wsj_2144.mrg
#   inflating: wsj/21/wsj_2153.mrg
#   inflating: wsj/21/wsj_2139.mrg
#   inflating: wsj/21/wsj_2127.mrg
#   inflating: wsj/21/wsj_2168.mrg
#   inflating: wsj/21/wsj_2160.mrg
#   inflating: wsj/21/wsj_2114.mrg
#   inflating: wsj/21/wsj_2119.mrg
#   inflating: wsj/21/wsj_2133.mrg
#   inflating: wsj/21/wsj_2135.mrg
#   inflating: wsj/21/wsj_2152.mrg
#   inflating: wsj/21/wsj_2130.mrg
#   inflating: wsj/21/wsj_2129.mrg
#   inflating: wsj/21/wsj_2115.mrg
#   inflating: wsj/21/wsj_2101.mrg
#   inflating: wsj/21/wsj_2126.mrg
#   inflating: wsj/21/wsj_2123.mrg
#   inflating: wsj/21/wsj_2134.mrg
#   inflating: wsj/21/wsj_2159.mrg
#   inflating: wsj/21/wsj_2110.mrg
#   inflating: wsj/21/wsj_2111.mrg
#   inflating: wsj/21/wsj_2156.mrg
#   inflating: wsj/21/wsj_2151.mrg
#   inflating: wsj/21/wsj_2146.mrg
#   inflating: wsj/21/wsj_2105.mrg
#   inflating: wsj/21/wsj_2125.mrg
#   inflating: wsj/21/wsj_2107.mrg
#   inflating: wsj/21/wsj_2166.mrg
#   inflating: wsj/21/wsj_2131.mrg
#   inflating: wsj/21/wsj_2120.mrg
#   inflating: wsj/21/wsj_2112.mrg
#   inflating: wsj/21/wsj_2132.mrg
#   inflating: wsj/21/wsj_2148.mrg
#   inflating: wsj/21/wsj_2117.mrg
#   inflating: wsj/21/wsj_2103.mrg
#   inflating: wsj/21/wsj_2106.mrg
#   inflating: wsj/21/wsj_2157.mrg
#   inflating: wsj/21/wsj_2141.mrg
#   inflating: wsj/21/wsj_2163.mrg
#   inflating: wsj/21/wsj_2104.mrg
#   inflating: wsj/21/wsj_2162.mrg
#   inflating: wsj/21/wsj_2142.mrg
#   inflating: wsj/21/wsj_2122.mrg
#   inflating: wsj/21/wsj_2155.mrg
#   inflating: wsj/21/wsj_2170.mrg
#   inflating: wsj/21/wsj_2118.mrg
#   inflating: wsj/21/wsj_2143.mrg
#   inflating: wsj/21/wsj_2128.mrg
#   inflating: wsj/21/wsj_2137.mrg
#   inflating: wsj/21/wsj_2121.mrg
#   inflating: wsj/21/wsj_2171.mrg
#   inflating: wsj/21/wsj_2124.mrg
#   inflating: wsj/21/wsj_2147.mrg
#   inflating: wsj/21/wsj_2108.mrg
#   inflating: wsj/21/wsj_2113.mrg
#   inflating: wsj/21/wsj_2140.mrg
#   inflating: wsj/MERGE.LOG
#    creating: wsj/06/
#   inflating: wsj/06/wsj_0695.mrg
#   inflating: wsj/06/wsj_0652.mrg
#   inflating: wsj/06/wsj_0654.mrg
#   inflating: wsj/06/wsj_0688.mrg
#   inflating: wsj/06/wsj_0610.mrg
#   inflating: wsj/06/wsj_0673.mrg
#   inflating: wsj/06/wsj_0651.mrg
#   inflating: wsj/06/wsj_0648.mrg
#   inflating: wsj/06/wsj_0644.mrg
#   inflating: wsj/06/wsj_0699.mrg
#   inflating: wsj/06/wsj_0693.mrg
#   inflating: wsj/06/wsj_0626.mrg
#   inflating: wsj/06/wsj_0679.mrg
#   inflating: wsj/06/wsj_0641.mrg
#   inflating: wsj/06/wsj_0647.mrg
#   inflating: wsj/06/wsj_0620.mrg
#   inflating: wsj/06/wsj_0631.mrg
#   inflating: wsj/06/wsj_0687.mrg
#   inflating: wsj/06/wsj_0692.mrg
#   inflating: wsj/06/wsj_0624.mrg
#   inflating: wsj/06/wsj_0683.mrg
#   inflating: wsj/06/wsj_0630.mrg
#   inflating: wsj/06/wsj_0614.mrg
#   inflating: wsj/06/wsj_0675.mrg
#   inflating: wsj/06/wsj_0659.mrg
#   inflating: wsj/06/wsj_0618.mrg
#   inflating: wsj/06/wsj_0686.mrg
#   inflating: wsj/06/wsj_0637.mrg
#   inflating: wsj/06/wsj_0621.mrg
#   inflating: wsj/06/wsj_0691.mrg
#   inflating: wsj/06/wsj_0605.mrg
#   inflating: wsj/06/wsj_0634.mrg
#   inflating: wsj/06/wsj_0612.mrg
#   inflating: wsj/06/wsj_0632.mrg
#   inflating: wsj/06/wsj_0680.mrg
#   inflating: wsj/06/wsj_0696.mrg
#   inflating: wsj/06/wsj_0698.mrg
#   inflating: wsj/06/wsj_0611.mrg
#   inflating: wsj/06/wsj_0672.mrg
#   inflating: wsj/06/wsj_0640.mrg
#   inflating: wsj/06/wsj_0667.mrg
#   inflating: wsj/06/wsj_0617.mrg
#   inflating: wsj/06/wsj_0629.mrg
#   inflating: wsj/06/wsj_0653.mrg
#   inflating: wsj/06/wsj_0681.mrg
#   inflating: wsj/06/wsj_0669.mrg
#   inflating: wsj/06/wsj_0628.mrg
#   inflating: wsj/06/wsj_0602.mrg
#   inflating: wsj/06/wsj_0694.mrg
#   inflating: wsj/06/wsj_0677.mrg
#   inflating: wsj/06/wsj_0684.mrg
#   inflating: wsj/06/wsj_0689.mrg
#   inflating: wsj/06/wsj_0690.mrg
#   inflating: wsj/06/wsj_0639.mrg
#   inflating: wsj/06/wsj_0649.mrg
#   inflating: wsj/06/wsj_0645.mrg
#   inflating: wsj/06/wsj_0604.mrg
#   inflating: wsj/06/wsj_0666.mrg
#   inflating: wsj/06/wsj_0638.mrg
#   inflating: wsj/06/wsj_0657.mrg
#   inflating: wsj/06/wsj_0665.mrg
#   inflating: wsj/06/wsj_0650.mrg
#   inflating: wsj/06/wsj_0660.mrg
#   inflating: wsj/06/wsj_0670.mrg
#   inflating: wsj/06/wsj_0627.mrg
#   inflating: wsj/06/wsj_0682.mrg
#   inflating: wsj/06/wsj_0671.mrg
#   inflating: wsj/06/wsj_0635.mrg
#   inflating: wsj/06/wsj_0646.mrg
#   inflating: wsj/06/wsj_0600.mrg
#   inflating: wsj/06/wsj_0674.mrg
#   inflating: wsj/06/wsj_0607.mrg
#   inflating: wsj/06/wsj_0619.mrg
#   inflating: wsj/06/wsj_0608.mrg
#   inflating: wsj/06/wsj_0655.mrg
#   inflating: wsj/06/wsj_0606.mrg
#   inflating: wsj/06/wsj_0643.mrg
#   inflating: wsj/06/wsj_0603.mrg
#   inflating: wsj/06/wsj_0697.mrg
#   inflating: wsj/06/wsj_0601.mrg
#   inflating: wsj/06/wsj_0662.mrg
#   inflating: wsj/06/wsj_0636.mrg
#   inflating: wsj/06/wsj_0663.mrg
#   inflating: wsj/06/wsj_0664.mrg
#   inflating: wsj/06/wsj_0678.mrg
#   inflating: wsj/06/wsj_0625.mrg
#   inflating: wsj/06/wsj_0616.mrg
#   inflating: wsj/06/wsj_0668.mrg
#   inflating: wsj/06/wsj_0613.mrg
#   inflating: wsj/06/wsj_0656.mrg
#   inflating: wsj/06/wsj_0633.mrg
#   inflating: wsj/06/wsj_0676.mrg
#   inflating: wsj/06/wsj_0642.mrg
#   inflating: wsj/06/wsj_0658.mrg
#   inflating: wsj/06/wsj_0623.mrg
#   inflating: wsj/06/wsj_0609.mrg
#   inflating: wsj/06/wsj_0615.mrg
#   inflating: wsj/06/wsj_0685.mrg
#   inflating: wsj/06/wsj_0661.mrg
#   inflating: wsj/06/wsj_0622.mrg
#    creating: wsj/03/
#   inflating: wsj/03/wsj_0365.mrg
#   inflating: wsj/03/wsj_0315.mrg
#   inflating: wsj/03/wsj_0326.mrg
#   inflating: wsj/03/wsj_0327.mrg
#   inflating: wsj/03/wsj_0346.mrg
#   inflating: wsj/03/wsj_0357.mrg
#   inflating: wsj/03/wsj_0304.mrg
#   inflating: wsj/03/wsj_0368.mrg
#   inflating: wsj/03/wsj_0370.mrg
#   inflating: wsj/03/wsj_0375.mrg
#   inflating: wsj/03/wsj_0301.mrg
#   inflating: wsj/03/wsj_0310.mrg
#   inflating: wsj/03/wsj_0339.mrg
#   inflating: wsj/03/wsj_0363.mrg
#   inflating: wsj/03/wsj_0318.mrg
#   inflating: wsj/03/wsj_0364.mrg
#   inflating: wsj/03/wsj_0359.mrg
#   inflating: wsj/03/wsj_0348.mrg
#   inflating: wsj/03/wsj_0334.mrg
#   inflating: wsj/03/wsj_0367.mrg
#   inflating: wsj/03/wsj_0372.mrg
#   inflating: wsj/03/wsj_0321.mrg
#   inflating: wsj/03/wsj_0313.mrg
#   inflating: wsj/03/wsj_0341.mrg
#   inflating: wsj/03/wsj_0347.mrg
#   inflating: wsj/03/wsj_0335.mrg
#   inflating: wsj/03/wsj_0354.mrg
#   inflating: wsj/03/wsj_0379.mrg
#   inflating: wsj/03/wsj_0376.mrg
#   inflating: wsj/03/wsj_0302.mrg
#   inflating: wsj/03/wsj_0345.mrg
#   inflating: wsj/03/wsj_0373.mrg
#   inflating: wsj/03/wsj_0317.mrg
#   inflating: wsj/03/wsj_0349.mrg
#   inflating: wsj/03/wsj_0330.mrg
#   inflating: wsj/03/wsj_0356.mrg
#   inflating: wsj/03/wsj_0305.mrg
#   inflating: wsj/03/wsj_0319.mrg
#   inflating: wsj/03/wsj_0362.mrg
#   inflating: wsj/03/wsj_0329.mrg
#   inflating: wsj/03/wsj_0366.mrg
#   inflating: wsj/03/wsj_0311.mrg
#   inflating: wsj/03/wsj_0374.mrg
#   inflating: wsj/03/wsj_0360.mrg
#   inflating: wsj/03/wsj_0308.mrg
#   inflating: wsj/03/wsj_0351.mrg
#   inflating: wsj/03/wsj_0380.mrg
#   inflating: wsj/03/wsj_0353.mrg
#   inflating: wsj/03/wsj_0377.mrg
#   inflating: wsj/03/wsj_0371.mrg
#   inflating: wsj/03/wsj_0307.mrg
#   inflating: wsj/03/wsj_0342.mrg
#   inflating: wsj/03/wsj_0358.mrg
#   inflating: wsj/03/wsj_0314.mrg
#   inflating: wsj/03/wsj_0369.mrg
#   inflating: wsj/03/wsj_0336.mrg
#   inflating: wsj/03/wsj_0378.mrg
#   inflating: wsj/03/wsj_0337.mrg
#   inflating: wsj/03/wsj_0323.mrg
#   inflating: wsj/03/wsj_0320.mrg
#   inflating: wsj/03/wsj_0300.mrg
#   inflating: wsj/03/wsj_0328.mrg
#   inflating: wsj/03/wsj_0309.mrg
#   inflating: wsj/03/wsj_0352.mrg
#   inflating: wsj/03/wsj_0324.mrg
#   inflating: wsj/03/wsj_0325.mrg
#   inflating: wsj/03/wsj_0331.mrg
#   inflating: wsj/03/wsj_0316.mrg
#   inflating: wsj/03/wsj_0306.mrg
#   inflating: wsj/03/wsj_0322.mrg
#   inflating: wsj/03/wsj_0340.mrg
#   inflating: wsj/03/wsj_0343.mrg
#   inflating: wsj/03/wsj_0350.mrg
#   inflating: wsj/03/wsj_0332.mrg
#   inflating: wsj/03/wsj_0333.mrg
#   inflating: wsj/03/wsj_0303.mrg
#   inflating: wsj/03/wsj_0338.mrg
#   inflating: wsj/03/wsj_0355.mrg
#   inflating: wsj/03/wsj_0344.mrg
#   inflating: wsj/03/wsj_0312.mrg
#   inflating: wsj/03/wsj_0361.mrg
#    creating: wsj/09/
#   inflating: wsj/09/wsj_0977.mrg
#   inflating: wsj/09/wsj_0914.mrg
#   inflating: wsj/09/wsj_0931.mrg
#   inflating: wsj/09/wsj_0900.mrg
#   inflating: wsj/09/wsj_0906.mrg
#   inflating: wsj/09/wsj_0945.mrg
#   inflating: wsj/09/wsj_0908.mrg
#   inflating: wsj/09/wsj_0990.mrg
#   inflating: wsj/09/wsj_0992.mrg
#   inflating: wsj/09/wsj_0975.mrg
#   inflating: wsj/09/wsj_0933.mrg
#   inflating: wsj/09/wsj_0962.mrg
#   inflating: wsj/09/wsj_0954.mrg
#   inflating: wsj/09/wsj_0922.mrg
#   inflating: wsj/09/wsj_0956.mrg
#   inflating: wsj/09/wsj_0915.mrg
#   inflating: wsj/09/wsj_0959.mrg
#   inflating: wsj/09/wsj_0904.mrg
#   inflating: wsj/09/wsj_0974.mrg
#   inflating: wsj/09/wsj_0982.mrg
#   inflating: wsj/09/wsj_0911.mrg
#   inflating: wsj/09/wsj_0939.mrg
#   inflating: wsj/09/wsj_0998.mrg
#   inflating: wsj/09/wsj_0936.mrg
#   inflating: wsj/09/wsj_0995.mrg
#   inflating: wsj/09/wsj_0985.mrg
#   inflating: wsj/09/wsj_0968.mrg
#   inflating: wsj/09/wsj_0932.mrg
#   inflating: wsj/09/wsj_0909.mrg
#   inflating: wsj/09/wsj_0960.mrg
#   inflating: wsj/09/wsj_0907.mrg
#   inflating: wsj/09/wsj_0905.mrg
#   inflating: wsj/09/wsj_0972.mrg
#   inflating: wsj/09/wsj_0951.mrg
#   inflating: wsj/09/wsj_0981.mrg
#   inflating: wsj/09/wsj_0996.mrg
#   inflating: wsj/09/wsj_0970.mrg
#   inflating: wsj/09/wsj_0913.mrg
#   inflating: wsj/09/wsj_0965.mrg
#   inflating: wsj/09/wsj_0980.mrg
#   inflating: wsj/09/wsj_0976.mrg
#   inflating: wsj/09/wsj_0920.mrg
#   inflating: wsj/09/wsj_0918.mrg
#   inflating: wsj/09/wsj_0989.mrg
#   inflating: wsj/09/wsj_0961.mrg
#   inflating: wsj/09/wsj_0942.mrg
#   inflating: wsj/09/wsj_0943.mrg
#   inflating: wsj/09/wsj_0948.mrg
#   inflating: wsj/09/wsj_0916.mrg
#   inflating: wsj/09/wsj_0941.mrg
#   inflating: wsj/09/wsj_0966.mrg
#   inflating: wsj/09/wsj_0997.mrg
#   inflating: wsj/09/wsj_0994.mrg
#   inflating: wsj/09/wsj_0930.mrg
#   inflating: wsj/09/wsj_0903.mrg
#   inflating: wsj/09/wsj_0946.mrg
#   inflating: wsj/09/wsj_0964.mrg
#   inflating: wsj/09/wsj_0901.mrg
#   inflating: wsj/09/wsj_0999.mrg
#   inflating: wsj/09/wsj_0950.mrg
#   inflating: wsj/09/wsj_0952.mrg
#   inflating: wsj/09/wsj_0971.mrg
#   inflating: wsj/09/wsj_0958.mrg
#   inflating: wsj/09/wsj_0973.mrg
#   inflating: wsj/09/wsj_0978.mrg
#   inflating: wsj/09/wsj_0926.mrg
#   inflating: wsj/09/wsj_0938.mrg
#   inflating: wsj/09/wsj_0967.mrg
#   inflating: wsj/09/wsj_0979.mrg
#   inflating: wsj/09/wsj_0934.mrg
#   inflating: wsj/09/wsj_0921.mrg
#   inflating: wsj/09/wsj_0912.mrg
#   inflating: wsj/09/wsj_0987.mrg
#   inflating: wsj/09/wsj_0986.mrg
#   inflating: wsj/09/wsj_0991.mrg
#   inflating: wsj/09/wsj_0935.mrg
#   inflating: wsj/09/wsj_0993.mrg
#   inflating: wsj/09/wsj_0949.mrg
#   inflating: wsj/09/wsj_0902.mrg
#   inflating: wsj/09/wsj_0988.mrg
#   inflating: wsj/09/wsj_0919.mrg
#   inflating: wsj/09/wsj_0957.mrg
#   inflating: wsj/09/wsj_0984.mrg
#   inflating: wsj/09/wsj_0955.mrg
#   inflating: wsj/09/wsj_0924.mrg
#   inflating: wsj/09/wsj_0937.mrg
#   inflating: wsj/09/wsj_0983.mrg
#   inflating: wsj/09/wsj_0953.mrg
#   inflating: wsj/09/wsj_0963.mrg
#   inflating: wsj/09/wsj_0947.mrg
#   inflating: wsj/09/wsj_0944.mrg
#   inflating: wsj/09/wsj_0917.mrg
#   inflating: wsj/09/wsj_0925.mrg
#   inflating: wsj/09/wsj_0929.mrg
#   inflating: wsj/09/wsj_0969.mrg
#   inflating: wsj/09/wsj_0910.mrg
#   inflating: wsj/09/wsj_0927.mrg
#   inflating: wsj/09/wsj_0928.mrg
#   inflating: wsj/09/wsj_0940.mrg
#   inflating: wsj/09/wsj_0923.mrg

# %%
def parse_trees(file_path):
    with open(file_path, "r") as file:
        data = file.read()

    trees = []
    current_tree = []
    open_parens = 0

    for line in data.splitlines():
        line = line.strip()
        if not line:
            continue

        current_tree.append(line)
        open_parens += line.count("(") - line.count(")")

        # If open_parens reaches zero, we've completed a tree
        if open_parens == 0:
            tree_string = " ".join(current_tree)
            trees.append(tree_string)
            current_tree = []

    return trees

# %%
# wsj/00-18 is the train set
# wsj/19-21 is the dev set
# wsj/22-24 is the test set

# separate the trees into train, dev, and test sets

def collect_trees(range_limits, target_list):
    for i in range(*range_limits):
        directory = f"wsj/{i:02}"
        files = os.listdir(directory)
        for file in files:
            target_list.extend(parse_trees(f"{directory}/{file}"))

# Initialize tree lists
train_trees, validation_trees, test_trees = [], [], []

# Collect trees for train, validation, and test sets
collect_trees((0, 19), train_trees)
collect_trees((19, 22), validation_trees)
collect_trees((22, 25), test_trees)

# Print the number of trees in each set
print(f"Number of training trees: {len(train_trees)}")
print(f"Number of validation trees: {len(validation_trees)}")
print(f"Number of test trees: {len(test_trees)}")
# Out:
# Number of training trees: 38219
# Number of validation trees: 5527
# Number of test trees: 5462

# %%
print(Tree.fromstring(train_trees[0]))
# Out:
# (
#   (S
#     (NP-SBJ
#       (NP (JJ Japanese))
#       (NN investment)
#       (PP-LOC (IN in) (NP (NNP Southeast) (NNP Asia))))
#     (VP
#       (VBZ is)
#       (VP
#         (VBG propelling)
#         (NP (DT the) (NN region))
#         (PP-DIR-CLR (IN toward) (NP (JJ economic) (NN integration)))))
#     (. .)))

# %%
train = [Tree.fromstring(tree).pos() for tree in train_trees]
val = [Tree.fromstring(tree).pos() for tree in validation_trees]
test = [Tree.fromstring(tree).pos() for tree in test_trees]

# %%
# Example for the first tree in the training set
print(train[0])
# Out:
# [('Japanese', 'JJ'), ('investment', 'NN'), ('in', 'IN'), ('Southeast', 'NNP'), ('Asia', 'NNP'), ('is', 'VBZ'), ('propelling', 'VBG'), ('the', 'DT'), ('region', 'NN'), ('toward', 'IN'), ('economic', 'JJ'), ('integration', 'NN'), ('.', '.')]

# %%
# Processing Tags
tags = set()
for tree in train:
    for _, tag in tree:
        tags.add(tag)
tags = ",".join(sorted(tags))
tags = tags.split(",")
tags = ["<pad>"] + tags
# tag2idx = {tag: idx for idx, tag in enumerate(tags)}
# idx2tag = {idx: tag for idx, tag in enumerate(tags)}
# Update tag2idx and idx2tag
tag2idx = {tag: idx for idx, tag in enumerate(tags)}
tag2idx['<pad>'] = tag2idx.pop('<pad>')
tag2idx['X'] = len(tag2idx)

idx2tag = {idx: tag for idx, tag in enumerate(tags)}
print(tags)
# Out:
# ['<pad>', '#', '$', "''", '', '', '-LRB-', '-NONE-', '-RRB-', '.', ':', 'CC', 'CD', 'DT', 'EX', 'FW', 'IN', 'JJ', 'JJR', 'JJS', 'LS', 'MD', 'NN', 'NNP', 'NNPS', 'NNS', 'PDT', 'POS', 'PRP', 'PRP$', 'RB', 'RBR', 'RBS', 'RP', 'SYM', 'TO', 'UH', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ', 'WDT', 'WP', 'WP$', 'WRB', '``']

# %%
MAX_LEN = 128

# %%
def trees_to_tokens_labels(trees):
    tokens_list = []
    labels_list = []

    for tree in trees:
        tokens = []
        labels = []
        for token, label in tree:
            tokens.append(token)
            labels.append(label)
        tokens_list.append(tokens)
        labels_list.append(labels)

    return tokens_list, labels_list

train_tokens, train_labels = trees_to_tokens_labels(train)
val_tokens, val_labels = trees_to_tokens_labels(val)
test_tokens, test_labels = trees_to_tokens_labels(test)

print(f"Number of training sentences: {len(train_tokens)}")
print(f"Number of validation sentences: {len(val_tokens)}")
print(f"Number of test sentences: {len(test_tokens)}")
# Out:
# Number of training sentences: 38219
# Number of validation sentences: 5527
# Number of test sentences: 5462

# %%
import random
import string
from nltk.corpus import wordnet

# Probability settings
SYNONYM_PROB = 0.15      # Now also used to determine how many sentences to augment
NOISE_PROB = 0.05
POS_CONFUSION_PROB = 0.1

def penn_to_wn_pos(tag):
    tag = tag.upper()
    return (wordnet.NOUN if tag.startswith('NN') else
            wordnet.VERB if tag.startswith('VB') else
            wordnet.ADJ  if tag.startswith('JJ') else
            wordnet.ADV  if tag.startswith('RB') else None)

def wn_pos_to_penn(wn_pos):
    """Map a WordNet POS back to a representative Penn Treebank tag."""
    if wn_pos == wordnet.NOUN:
        return "NN"
    elif wn_pos == wordnet.VERB:
        return "VB"
    elif wn_pos == wordnet.ADJ:
        return "JJ"
    elif wn_pos == wordnet.ADV:
        return "RB"
    else:
        return None

def get_pos_synonyms(word, wn_pos):
    """Get a list of synonyms for 'word' that share the given WordNet POS."""
    synsets = wordnet.synsets(word, pos=wn_pos)
    synonyms = set()
    for syn in synsets:
        for lemma in syn.lemmas():
            lemma_name = lemma.name().replace('_', ' ')
            # Exclude the original word itself
            if lemma_name.lower() != word.lower():
                synonyms.add(lemma_name)
    return list(synonyms)

def introduce_typo(word):
    """Introduce a small typo by swapping two adjacent characters."""
    if len(word) < 2:
        return word
    idx = random.randint(0, len(word)-2)
    word_as_list = list(word)
    word_as_list[idx], word_as_list[idx+1] = word_as_list[idx+1], word_as_list[idx]
    return "".join(word_as_list)

def find_alternative_pos(word, original_wn_pos):
    """Find alternative POS categories the given word can appear in, based on all its synsets."""
    all_synsets = wordnet.synsets(word)
    # Collect all possible POS forms for this word
    possible_pos = {s.pos() for s in all_synsets}
    # Remove the original POS from the set
    alternative_pos = possible_pos - {original_wn_pos}
    return alternative_pos

def augment_tokens_for_pos(tokens, labels,
                           synonym_prob=SYNONYM_PROB,
                           noise_prob=NOISE_PROB,
                           pos_confusion_prob=POS_CONFUSION_PROB):
    augmented_tokens = []
    augmented_labels = []

    for (word, label) in zip(tokens, labels):
        wn_pos = penn_to_wn_pos(label)
        original_word = word
        new_label = label  # Default to original label unless we change it

        # Check if we apply synonym replacement to this token
        if wn_pos and random.random() < synonym_prob:
            # Get synonyms for the same POS
            same_pos_synonyms = get_pos_synonyms(word, wn_pos)

            # Check if we should attempt POS confusion
            if random.random() < pos_confusion_prob:
                # Find alternative POS forms for the same lemma
                alternative_pos_list = find_alternative_pos(original_word, wn_pos)

                pos_confused = False
                for alt_pos in alternative_pos_list:
                    alt_synonyms = get_pos_synonyms(original_word, alt_pos)
                    if alt_synonyms:
                        word = random.choice(alt_synonyms)
                        # Update label to reflect the new POS
                        alt_label = wn_pos_to_penn(alt_pos)
                        if alt_label:
                            new_label = alt_label
                        pos_confused = True
                        break

                # If no alternative POS synonyms found, fallback to same POS synonyms
                if not pos_confused:
                    if same_pos_synonyms:
                        word = random.choice(same_pos_synonyms)
                        # Same POS, so keep original label
                        new_label = label
                    else:
                        # No synonyms found, keep original word and label
                        word = original_word
                        new_label = label
            else:
                # No POS confusion, just pick from same POS synonyms if available
                if same_pos_synonyms:
                    word = random.choice(same_pos_synonyms)
                    # Same POS, keep original label
                    new_label = label
                else:
                    # No synonyms found, keep original word and label
                    word = original_word
                    new_label = label

        # Introduce noise (typo) if applicable
        if random.random() < noise_prob:
            word = introduce_typo(word)
            # Noise doesn't change the POS, so no label change

        augmented_tokens.append(word)
        augmented_labels.append(new_label)

    return augmented_tokens, augmented_labels


# Example usage to increase dataset size by ~15% (based on SYNONYM_PROB)
if data_augmentation:
    num_original = len(train_tokens)
    # Determine how many sentences to augment (about synonym_prob * 100%)
    num_to_augment = int(num_original * SYNONYM_PROB)

    # Randomly sample which sentences to augment
    indices_to_augment = random.sample(range(num_original), num_to_augment)

    augmented_tokens_list = []
    augmented_labels_list = []

    for i in indices_to_augment:
        tokens, labels = train_tokens[i], train_labels[i]
        aug_tokens, aug_labels = augment_tokens_for_pos(tokens, labels)
        augmented_tokens_list.append(aug_tokens)
        augmented_labels_list.append(aug_labels)

    # Append augmented data to the original dataset
    train_tokens += augmented_tokens_list
    train_labels += augmented_labels_list

    print(f"Number of original training sentences: {num_original}")
    print(f"Number of augmented training sentences: {len(augmented_tokens_list)}")
    print(f"Total number of training sentences after augmentation: {len(train_tokens)}")

# %%
def tokenize_and_align_labels(tokens_list, labels_list, tokenizer, max_len):
    input_ids = []
    attention_masks = []
    label_ids = []

    for tokens, labels in zip(tokens_list, labels_list):
        tokens_enc = []
        label_enc = []

        tokens_enc.append("[CLS]")
        label_enc.append(tag2idx['<pad>'])

        for token, label in zip(tokens, labels):
            sub_tokens = tokenizer.tokenize(token)
            if not sub_tokens:
                sub_tokens = ['[UNK]']
            tokens_enc.extend(sub_tokens)
            label_enc.append(tag2idx.get(label, tag2idx['<pad>']))
            for _ in sub_tokens[1:]:
                label_enc.append(tag2idx['X'])

        tokens_enc.append("[SEP]")
        label_enc.append(tag2idx['<pad>'])

        input_id = tokenizer.convert_tokens_to_ids(tokens_enc)
        attention_mask = [1] * len(input_id)

        # Trunc
        if len(input_id) > max_len:
            input_id = input_id[:max_len-1] + [tokenizer.convert_tokens_to_ids("[SEP]")]
            attention_mask = attention_mask[:max_len-1] + [1]
            label_enc = label_enc[:max_len-1] + [tag2idx['<pad>']]
        # ideally, we can pad the input
        else:
            padding_length = max_len - len(input_id)
            input_id += [tokenizer.pad_token_id] * padding_length
            attention_mask += [0] * padding_length
            label_enc += [tag2idx['<pad>']] * padding_length

        input_ids.append(input_id)
        attention_masks.append(attention_mask)
        label_ids.append(label_enc)

    return torch.tensor(input_ids), torch.tensor(attention_masks), torch.tensor(label_ids)

# %%
from transformers import BertTokenizer

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-cased', do_lower_case=False)

train_input_ids, train_attention_masks, train_label_ids = tokenize_and_align_labels(
    train_tokens, train_labels, tokenizer, MAX_LEN
)

val_input_ids, val_attention_masks, val_label_ids = tokenize_and_align_labels(
    val_tokens, val_labels, tokenizer, MAX_LEN
)

test_input_ids, test_attention_masks, test_label_ids = tokenize_and_align_labels(
    test_tokens, test_labels, tokenizer, MAX_LEN
)

print(f"Training input IDs shape: {train_input_ids.shape}")
print(f"Validation input IDs shape: {val_input_ids.shape}")
print(f"Test input IDs shape: {test_input_ids.shape}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Training input IDs shape: torch.Size([38219, 128])
# Validation input IDs shape: torch.Size([5527, 128])
# Test input IDs shape: torch.Size([5462, 128])

# %%
class POSDataset(Dataset):
    def __init__(self, input_ids, attention_masks, labels):
        self.input_ids = input_ids
        self.attention_masks = attention_masks
        self.labels = labels

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {
            'input_ids': self.input_ids[idx],
            'attention_mask': self.attention_masks[idx],
            'labels': self.labels[idx]
        }

# Dataset
train_dataset = POSDataset(train_input_ids, train_attention_masks, train_label_ids)
val_dataset = POSDataset(val_input_ids, val_attention_masks, val_label_ids)
test_dataset = POSDataset(test_input_ids, test_attention_masks, test_label_ids)

# DataLoaders
BATCH_SIZE = 16

train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# Update model initializations
import torch
import torch.nn as nn
from transformers import BertModel
from torchcrf import CRF
from transformers import get_linear_schedule_with_warmup
import torch.optim as optim
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
epochs = 3
hidden_size = 768 # Hidden size for BERT-base
num_labels = len(tag2idx)
dropout_rate = 0.1
bert_model_name = 'bert-base-cased'

model = BertCRFTagger(bert_model_name, hidden_size, num_labels, dropout_rate).to(device)

print(f"Using device:{device}")

# Optimizer and scheduler
optimizer = optim.AdamW(model.parameters(), lr=3e-5)
total_steps = len(train_dataloader) * epochs
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)
# Out:
# Using device:cuda

# %%
from sklearn.metrics import f1_score, classification_report, accuracy_score

# train the model
for epoch in range(epochs):
    print(f"\n======== Epoch {epoch + 1} / {epochs} ========")
    print("Training...")

    train_loss = train_epoch(model, train_dataloader, optimizer, scheduler, device)
    print(f"Training loss: {train_loss}")

    print("Evaluating...")
    val_loss, val_preds, val_true = eval_model(model, val_dataloader, device)
    print(f"Validation loss: {val_loss}")

    # # Convert true labels and predictions to tag names
    # val_preds_labels = [[idx2tag[p] for p in seq] for seq in val_preds]
    # val_true_labels = [[idx2tag[t] for t in seq if t != tag2idx['<pad>']] for seq in val_true]

    # f1 = f1_score(val_true_labels, val_preds_labels, average='weighted')
    # print(f"Validation F1 Score: {f1:.4f}")

    # print("Classification Report:")
    # print(classification_report(val_true_labels, val_preds_labels))

    val_preds_labels = []
    val_true_labels = []

    for pred_seq, true_seq in zip(val_preds, val_true):
        filtered_preds = [idx2tag[p] for p, t in zip(pred_seq, true_seq) if t != tag2idx['<pad>']]
        filtered_labels = [idx2tag[t] for t in true_seq if t != tag2idx['<pad>']]

        if len(filtered_preds) == len(filtered_labels):  # Ensure alignment
            val_preds_labels.append(filtered_preds)
            val_true_labels.append(filtered_labels)


    # Flatten the nested lists into one-dimensional lists
    flattened_preds = [label for seq in val_preds_labels for label in seq]
    flattened_true = [label for seq in val_true_labels for label in seq]

    # Compute F1 score
    f1 = f1_score(flattened_true, flattened_preds, average='weighted')
    print(f"Validation F1 Score: {f1:.4f}")


    # Compute accuracy
    accuracy = accuracy_score(flattened_true, flattened_preds)
    print(f"Validation Accuracy: {accuracy:.4f}")


    # Classification report
    print("Classification Report:")
    print(classification_report(flattened_true, flattened_preds))
# Out:
# ======== Epoch 1 / 3 ========
# Training...
# Training:   2%|▏         | 53/2389 [00:10<08:11,  4.75it/s]

# %%
test_preds_labels, test_true_labels, test_accuracy = evaluate_test_set_with_accuracy(
    model=model,
    dataloader=test_dataloader,
    device=device,
    idx2tag=idx2tag,
    tag2idx=tag2idx
)

# %%
# Saving the model

# Directory to save the model
output_dir = './bert-crf-pos-model/'

# Create the directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Save model weights
torch.save(model.state_dict(), os.path.join(output_dir, "model_weights.pth"))

# Save model configuration
with open(os.path.join(output_dir, "config.json"), 'w') as f:
    f.write(model.bert.config.to_json_string())  # Save BERT config

# Save tokenizer
tokenizer.save_pretrained(output_dir)

print(f"Model and related files saved to {output_dir}")
